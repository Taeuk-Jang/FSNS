# %%
#!/usr/bin/env python
# coding: utf-8

#------ Load necessary packages ------#
# %load_ext autoreload
# %autoreload 2
from aif360.datasets import AdultDataset, GermanDataset, BankDataset, CompasDataset, BinaryLabelDataset, CelebADataset, MEPSDataset19
import numpy as np
from plot import plot
import pickle
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
repeat = 5
total_acc = np.zeros((11, repeat))
total_balanced_acc = np.zeros((11, repeat))
total_disimpact = np.zeros((11, repeat))
total_eqopp_diff = np.zeros((11, repeat))

total_aveodds_diff = np.zeros((11, repeat))
total_theil_idx = np.zeros((11, repeat))
stat_parity_diff = np.zeros((11, repeat))

total_tpr = np.zeros((11, repeat))
total_tpr_priv = np.zeros((11, repeat))
total_tpr_unpriv = np.zeros((11, repeat))

total_fpr = np.zeros((11, repeat))
total_fpr_priv = np.zeros((11, repeat))
total_fpr_unpriv = np.zeros((11, repeat))
total_fpr_diff = np.zeros((11, repeat))

total_acc_priv = np.zeros((11, repeat))
total_acc_unpriv = np.zeros((11, repeat))

# %%
x = ['AdvDeb', 'CEOPost', 'DIR', 'MFC', 'ReW', 'Baseline', 'Ours']

# %%
dataset_used = 'german'

# %%
protected_attribute_used = 1

if dataset_used == "adult":
    dataset = AdultDataset()
    # #dataset = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "german":
    dataset = GermanDataset()
    dataset.labels = dataset.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif dataset_used == "compas":
    dataset = CompasDataset()
    # #dataset = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "bank":
    dataset = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif dataset_used == "meps":
    dataset = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

sens_idx = dataset.feature_names.index(sens_attr)

P_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 1)
N_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 0)

P_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 1)
N_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 0)

P_Y1_A1 = P_priv/(P_priv + N_priv)
P_Y1_A0 = P_unpriv/(P_unpriv + N_unpriv)
# Out:
# /home/taeuk/network/NIPS2020_mm/aif360/datasets/standard_dataset.py:121: FutureWarning: outer method for ufunc <ufunc 'equal'> is not implemented on pandas objects. Returning an ndarray, but in the future this will raise a 'NotImplementedError'. Consider explicitly converting the Series to an array with '.array' first.
#   priv = np.logical_or.reduce(np.equal.outer(vals, df[attr]))

# %%
total_tpr = np.load('../AIF360/examples/result_data_t2/{}/total_tpr.npy'.format(dataset_used))
total_tpr_priv = np.load('../AIF360/examples/result_data_t2/{}/total_tpr_priv.npy'.format(dataset_used))
total_tpr_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_tpr_unpriv.npy'.format(dataset_used))
total_eqopp_diff = np.load('../AIF360/examples/result_data_t2/{}/total_eqopp_diff.npy'.format(dataset_used))

total_fpr = np.load('../AIF360/examples/result_data_t2/{}/total_fpr.npy'.format(dataset_used))
total_fpr_priv = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_priv.npy'.format(dataset_used))
total_fpr_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_unpriv.npy'.format(dataset_used))
total_fpr_diff = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_diff.npy'.format(dataset_used))

total_acc = np.load('../AIF360/examples/result_data_t2/{}/total_acc.npy'.format(dataset_used))
total_acc_priv = np.load('../AIF360/examples/result_data_t2/{}/total_acc_priv.npy'.format(dataset_used))
total_acc_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_acc_unpriv.npy'.format(dataset_used))
# abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data_t2/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc = np.load('../AIF360/examples/result_data_t2/{}/total_balanced_acc.npy'.format(dataset_used))
total_disimpact = np.load('../AIF360/examples/result_data_t2/{}/total_disimpact.npy'.format(dataset_used))
total_theil_idx = np.load('../AIF360/examples/result_data_t2/{}/total_theil_idx.npy'.format(dataset_used))
stat_parity_diff = np.load('../AIF360/examples/result_data_t2/{}/stat_parity_diff.npy'.format(dataset_used))



total_tpr[5] = np.load('../AIF360/examples/result_data/{}/total_tpr.npy'.format(dataset_used))[5]
total_tpr_priv[5] = np.load('../AIF360/examples/result_data/{}/total_tpr_priv.npy'.format(dataset_used))[5]
total_tpr_unpriv[5] = np.load('../AIF360/examples/result_data/{}/total_tpr_unpriv.npy'.format(dataset_used))[5]
total_eqopp_diff[5] = np.load('../AIF360/examples/result_data/{}/total_eqopp_diff.npy'.format(dataset_used))[5]

total_fpr[5] = np.load('../AIF360/examples/result_data/{}/total_fpr.npy'.format(dataset_used))[5]
total_fpr_priv[5] = np.load('../AIF360/examples/result_data/{}/total_fpr_priv.npy'.format(dataset_used))[5]
total_fpr_unpriv[5] = np.load('../AIF360/examples/result_data/{}/total_fpr_unpriv.npy'.format(dataset_used))[5]
total_fpr_diff[5] = np.load('../AIF360/examples/result_data/{}/total_fpr_diff.npy'.format(dataset_used))[5]

total_acc[5] = np.load('../AIF360/examples/result_data/{}/total_acc.npy'.format(dataset_used))[5]
total_acc_priv[5] = np.load('../AIF360/examples/result_data/{}/total_acc_priv.npy'.format(dataset_used))[5]
total_acc_unpriv[5] = np.load('../AIF360/examples/result_data/{}/total_acc_unpriv.npy'.format(dataset_used))[5]
# abs(total_acc_unpriv - total_acc_priv)[5] = np.load('../AIF360/examples/result_data/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc[5] = np.load('../AIF360/examples/result_data/{}/total_balanced_acc.npy'.format(dataset_used))[5]
total_disimpact[5] = np.load('../AIF360/examples/result_data/{}/total_disimpact.npy'.format(dataset_used))[5]
total_theil_idx[5] = np.load('../AIF360/examples/result_data/{}/total_theil_idx.npy'.format(dataset_used))[5]
stat_parity_diff[5] = np.load('../AIF360/examples/result_data/{}/stat_parity_diff.npy'.format(dataset_used))[5]

# %%
with open('final_test/save_pickle/{}/tpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[9] =  np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/tpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[9] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[9] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[9] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[9] = (total_tpr[9] + (1-total_fpr[9]))/2
# with open('final_test/save_pickle/{}/balanced_best.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_best.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[9] = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/tpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[10] =  np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/tpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[10] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[10] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[10] = (total_tpr[10] + (1-total_fpr[10]))/2
# with open('final_test/save_pickle/{}/balanced_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[10] = np.array(pickle.load(filehandle))

# %%
    
with open('weighted_test/save_pickle/{}/tpr_overall_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[10] =  np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/tpr_priv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[10] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_unpriv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[10] = np.array(pickle.load(filehandle))  
with open('weighted_test/save_pickle/{}/eq_opp_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[10] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/fpr_overall_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_priv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_unpriv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_diff_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[10] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/acc_overall_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_priv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_unpriv_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[10] = np.array(pickle.load(filehandle))
# with open('weighted_test/save_pickle/{}/acc_diff_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[10] = (total_tpr[10] + (1-total_fpr[10]))/2
# with open('weighted_test/save_pickle/{}/balanced_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/dis_impact_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/theil_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[10] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/stat_abl_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[10] = np.array(pickle.load(filehandle))

# %%
with open('weighted_test/save_pickle/{}/tpr_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[0] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[0] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[0] = np.array(pickle.load(filehandle))  
with open('weighted_test/save_pickle/{}/eq_opp_hist_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/fpr_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_diff_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/acc_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[0] = np.array(pickle.load(filehandle))
# with open('weighted_test/save_pickle/{}/acc_diff_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
with open('weighted_test/save_pickle/{}/balanced_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_balanced_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/dis_impact_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/theil_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/stat_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[0] = np.array(pickle.load(filehandle))
    
total_balanced_acc[0] = (total_tpr[0] + (1-total_fpr[0]))/2
dataset_used = 'German'

# %%
print(dataset_used)
m1 = np.mean(total_tpr_priv, -1)
s1 = np.std(total_tpr_priv, -1)
m2 = np.mean(total_tpr_unpriv, -1)
s2 = np.std(total_tpr_unpriv, -1)
m3 = abs(np.mean(total_eqopp_diff, -1))
s3 = np.std(total_eqopp_diff, -1)




print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('Meta \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
      .format(m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print()

bal_acc_priv = (total_tpr_priv + (1-total_fpr_priv))/2
bal_acc_unpriv = (total_tpr_unpriv + (1-total_fpr_unpriv))/2
bal_acc_overall = (total_tpr + (1-total_fpr))/2

bal_acc_priv_m = np.mean(bal_acc_priv, -1)
bal_acc_priv_s = np.std(bal_acc_priv, -1)
bal_acc_unpriv_m = np.mean(bal_acc_unpriv, -1)
bal_acc_unpriv_s = np.std(bal_acc_unpriv, -1)
bal_acc_diff_m = abs(bal_acc_priv_m - bal_acc_unpriv_m)
bal_acc_diff_s = np.std(total_acc_priv - bal_acc_unpriv, -1)
bal_acc_overall_m = np.mean(bal_acc_overall, -1)
bal_acc_overall_s = np.std(bal_acc_overall, -1)


acc_priv_m = np.mean(total_acc_priv, -1)
acc_priv_s = np.std(total_acc_priv, -1)
acc_unpriv_m = np.mean(total_acc_unpriv, -1)
acc_unpriv_s = np.std(total_acc_unpriv, -1)
acc_diff_m = abs(acc_priv_m - acc_unpriv_m)
acc_diff_s = np.std(total_acc_priv - total_acc_unpriv, -1)

m4 = np.mean(total_acc, -1)
s4 = np.std(total_acc, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f} \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m4[1], s4[1], acc_diff_m[1], acc_diff_s[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m4[2], s4[2], acc_diff_m[2], acc_diff_s[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m4[3], s4[3], acc_diff_m[3], acc_diff_s[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m4[5], s4[5], acc_diff_m[5], acc_diff_s[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m4[6], s4[6], acc_diff_m[6], acc_diff_s[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m4[7], s4[7], acc_diff_m[7], acc_diff_s[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m4[10], s4[10], acc_diff_m[10], acc_diff_s[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[0], bal_acc_overall_s[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m4[0], s4[0], acc_diff_m[0], acc_diff_s[0], m3[0]))
# Out:
# German
# AdvDeb 		 & 0.863 $\pm$ 0.056 	 & 0.858 $\pm$ 0.043 	 & 0.005 $\pm$ 0.070  \\
# CEOPost 	 & 0.810 $\pm$ 0.028 	 & 0.909 $\pm$ 0.016 	 & 0.100 $\pm$ 0.018  \\
# DIR 		 & 1.000 $\pm$ 0.000 	 & 1.000 $\pm$ 0.000 	 & 0.000 $\pm$ 0.000  \\
# Meta 		 & 0.857 $\pm$ 0.031 	 & 0.860 $\pm$ 0.055 	 & 0.003 $\pm$ 0.061  \\ \hhline{=|===}
# ReW 		 & 0.630 $\pm$ 0.123 	 & 0.640 $\pm$ 0.122 	 & 0.010 $\pm$ 0.033  \\
# RejOpt 		 & 0.727 $\pm$ 0.139 	 & 0.650 $\pm$ 0.104 	 & 0.077 $\pm$ 0.051  \\ \hhline{=|===}
# Ours 		 & 0.513 $\pm$ 0.063 	 & 0.545 $\pm$ 0.081 	 & 0.035 $\pm$ 0.032  \\ \hhline{=|===}
# Ours_w 		 & 0.799 $\pm$ 0.042 	 & 0.774 $\pm$ 0.058 	 & 0.036 $\pm$ 0.059  \\ \hhline{=|===}
# Baseline 	 & 0.672 $\pm$ 0.101 	 & 0.737 $\pm$ 0.106 	 & 0.157 $\pm$ 0.075  \\ \hline
#
# AdvDeb 		 & 0.667 $\pm$ 0.033 	 &  0.008 $\pm$ 0.030 	 & 0.745 $\pm$ 0.036  	 & 0.017 $\pm$ 0.019 \\
# CEOPost 	 & 0.629 $\pm$ 0.017 	 &  0.088 $\pm$ 0.035 	 & 0.731 $\pm$ 0.021  	 & 0.012 $\pm$ 0.025  \\
# ...

# %%
print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[0], bal_acc_overall_s[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# Out:
# AdvDeb 		 & 0.667 $\pm$ 0.033 	 &  0.008 $\pm$ 0.030 	 & 0.863 $\pm$ 0.056  	 & 0.858 $\pm$ 0.043  	 & 0.005 $\pm$ 0.070  \\
# CEOPost 	 & 0.629 $\pm$ 0.017 	 &  0.088 $\pm$ 0.035 	 & 0.810 $\pm$ 0.028  	 & 0.909 $\pm$ 0.016  	 & 0.100 $\pm$ 0.018  \\
# DIR 		 & 0.500 $\pm$ 0.000 	 &  0.000 $\pm$ 0.045 	 & 1.000 $\pm$ 0.000  	 & 1.000 $\pm$ 0.000  	 & 0.000 $\pm$ 0.000  \\
# MFC 		 & 0.645 $\pm$ 0.035 	 &  0.043 $\pm$ 0.037 	 & 0.857 $\pm$ 0.031  	 & 0.860 $\pm$ 0.055  	 & 0.003 $\pm$ 0.061  \\
# ReW 		 & 0.685 $\pm$ 0.019 	 &  0.015 $\pm$ 0.054 	 & 0.630 $\pm$ 0.123  	 & 0.640 $\pm$ 0.122  	 & 0.010 $\pm$ 0.033  \\
# RejOpt 		 & 0.688 $\pm$ 0.008 	 &  0.013 $\pm$ 0.025 	 & 0.727 $\pm$ 0.139  	 & 0.650 $\pm$ 0.104  	 & 0.077 $\pm$ 0.051  \\
# Baseline 	 & 0.718 $\pm$ 0.032 	 &  0.016 $\pm$ 0.084 	 & 0.672 $\pm$ 0.101  	 & 0.737 $\pm$ 0.106  	 & 0.157 $\pm$ 0.075  \\ \hhline{=|======}
# ...

# %%
total_aveodds_diff = abs(0.5 * (total_tpr_priv + total_fpr_priv) - 0.5 * (total_tpr_unpriv + total_fpr_unpriv))

# %%
x_pd = [i for i in x for j in range(repeat) ]
metric_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'Abs Balanced ACC Diff']
metric_list_pd = [i for i in metric_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,0]
values = np.array([])

bal_acc_diff = bal_acc_priv - bal_acc_unpriv

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(bal_acc_diff[idx])), -1)
# for idx in method_idx:
#     values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*len(metric_list), metric_list_pd, values), columns=["method", "fair_metric", "value"])

# %%
x_pd = [i for i in x for j in range(repeat) ]
metric_list = ['Balanced Accuracy']
metric_list_pd = [i for i in metric_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,0]
values = np.array([])

for idx in method_idx:
    values = np.concatenate((values,abs(bal_acc_overall[idx])), -1)

df2 = pd.DataFrame(zip(x_pd*len(metric_list), metric_list_pd, values), columns=["method", "performance_metric", "value"])

# %%
sns.color_palette("hls", 8)[-1]
# Out:
# (0.86, 0.33999999999999997, 0.6987999999999996)

# %%
sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2,9]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="fair_metric", y="value", data=df, capsize=.1, errwidth = 1.3, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
tick = ['{:.2f}'.format(i) for i in ax.get_yticks()]
tick[0]=''
ax.set_yticklabels(tick)
ax.get_legend().remove()


ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')
ax2.yaxis.tick_left()
# ax2.tick_params('y', width = 5, length = 2)
# ax2.tick

sns.set(style="ticks", rc={"lines.linewidth": 0.8})

current_palette = np.array(sns.hls_palette(8, l=.3, s=.8))[[-1, -1]]

ax3 = ax.twinx()
ax3 = sns.pointplot(x="method", hue="performance_metric",  y="value", data=df, capsize=.1, errwidth = 1.2, errcolor='.0',\
            palette = current_palette, markers = 'x', scale = 2 )
ax3.set(xlabel= '', ylabel='')
ax3.set_xticklabels(x, fontsize=13)
tick = ['{:.2f}'.format(i) for i in ax3.get_yticks()]
tick[0]=''
ax3.set_yticklabels(tick)
ax3.yaxis.tick_right()
ax3.get_legend().remove()


ax4 = ax.twinx()
ax4.set_yticks(np.arange(2))
ax4.set_yticklabels(['Bad', 'Good'], fontsize=15, color='red')
# ax4.yaxis.tick_left()

pop_a = mpatches.Patch(color='c', label='Positive')
pop_b = mpatches.Patch(color='firebrick', label='Negative')
# #pop_c = mpatches.Arrow(color='black', label='SVM')

plt.legend(handles=[pop_a,pop_b])

plt.tight_layout()
# plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()

# %%
tick = ['{:.2f}'.format(i) for i in ax.get_yticks()]

# %%
tick
# Out:
# ['0.00', '0.05', '0.10', '0.15', '0.20', '0.25']

# %%
tick[0] = ''

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(x_pd = [i for i in x for j in range(repeat) ]
metirc_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'FPR Diff']
metirc_list_pd = [i for i in metirc_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,0]
values = np.array([])

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*3, metirc_list_pd, values), columns=["method", "metric", "data"])


sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="metric", y="data", data=df, capsize=.1, errwidth = 1.5, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')

plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()
), 4, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
# Out:
#   File "<ipython-input-16-bfab0e9bce14>", line 7
#     metirc_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'FPR Diff']
#               ^
# SyntaxError: invalid syntax

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])

# %%
dataset_used = 'compas'

# %%
protected_attribute_used = 1

if dataset_used == "adult":
    dataset = AdultDataset()
    # #dataset = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "german":
    dataset = GermanDataset()
    dataset.labels = dataset.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif dataset_used == "compas":
    dataset = CompasDataset()
    # #dataset = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "bank":
    dataset = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif dataset_used == "meps":
    dataset = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

sens_idx = dataset.feature_names.index(sens_attr)

P_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 1)
N_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 0)

P_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 1)
N_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 0)

P_Y1_A1 = P_priv/(P_priv + N_priv)
P_Y1_A0 = P_unpriv/(P_unpriv + N_unpriv)
# Out:
# WARNING:root:Missing Data: 5 rows removed from CompasDataset.

# %%
# total_tpr = np.load('../AIF360/examples/result_data_t2/{}/total_tpr.npy'.format(dataset_used))
# total_tpr_priv = np.load('../AIF360/examples/result_data_t2/{}/total_tpr_priv.npy'.format(dataset_used))
# total_tpr_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_tpr_unpriv.npy'.format(dataset_used))
# total_eqopp_diff = np.load('../AIF360/examples/result_data_t2/{}/total_eqopp_diff.npy'.format(dataset_used))

# total_fpr = np.load('../AIF360/examples/result_data_t2/{}/total_fpr.npy'.format(dataset_used))
# total_fpr_priv = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_priv.npy'.format(dataset_used))
# total_fpr_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_unpriv.npy'.format(dataset_used))
# total_fpr_diff = np.load('../AIF360/examples/result_data_t2/{}/total_fpr_diff.npy'.format(dataset_used))

# total_acc = np.load('../AIF360/examples/result_data_t2/{}/total_acc.npy'.format(dataset_used))
# total_acc_priv = np.load('../AIF360/examples/result_data_t2/{}/total_acc_priv.npy'.format(dataset_used))
# total_acc_unpriv = np.load('../AIF360/examples/result_data_t2/{}/total_acc_unpriv.npy'.format(dataset_used))
# # abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data_t2/{}/total_acc_diff.npy'.format(dataset_used))

# total_balanced_acc = np.load('../AIF360/examples/result_data_t2/{}/total_balanced_acc.npy'.format(dataset_used))
# total_disimpact = np.load('../AIF360/examples/result_data_t2/{}/total_disimpact.npy'.format(dataset_used))
# total_theil_idx = np.load('../AIF360/examples/result_data_t2/{}/total_theil_idx.npy'.format(dataset_used))
# stat_parity_diff = np.load('../AIF360/examples/result_data_t2/{}/stat_parity_diff.npy'.format(dataset_used))



total_tpr = np.load('../AIF360/examples/result_data/{}/total_tpr.npy'.format(dataset_used))
total_tpr_priv = np.load('../AIF360/examples/result_data/{}/total_tpr_priv.npy'.format(dataset_used))
total_tpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_tpr_unpriv.npy'.format(dataset_used))
total_eqopp_diff = np.load('../AIF360/examples/result_data/{}/total_eqopp_diff.npy'.format(dataset_used))

total_fpr = np.load('../AIF360/examples/result_data/{}/total_fpr.npy'.format(dataset_used))
total_fpr_priv = np.load('../AIF360/examples/result_data/{}/total_fpr_priv.npy'.format(dataset_used))
total_fpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_fpr_unpriv.npy'.format(dataset_used))
total_fpr_diff = np.load('../AIF360/examples/result_data/{}/total_fpr_diff.npy'.format(dataset_used))

total_acc = np.load('../AIF360/examples/result_data/{}/total_acc.npy'.format(dataset_used))
total_acc_priv = np.load('../AIF360/examples/result_data/{}/total_acc_priv.npy'.format(dataset_used))
total_acc_unpriv = np.load('../AIF360/examples/result_data/{}/total_acc_unpriv.npy'.format(dataset_used))
# abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc = np.load('../AIF360/examples/result_data/{}/total_balanced_acc.npy'.format(dataset_used))
total_disimpact = np.load('../AIF360/examples/result_data/{}/total_disimpact.npy'.format(dataset_used))
total_theil_idx = np.load('../AIF360/examples/result_data/{}/total_theil_idx.npy'.format(dataset_used))
stat_parity_diff = np.load('../AIF360/examples/result_data/{}/stat_parity_diff.npy'.format(dataset_used))

# %%
with open('final_test/save_pickle/{}/tpr_overall_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[9] =  np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/tpr_priv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[9] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[9] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[9] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[9] = (total_tpr[9] + (1-total_fpr[9]))/2
# with open('final_test/save_pickle/{}/balanced_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_hist_no_cls_update.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[9] = np.array(pickle.load(filehandle))

# %%
with open('final_test/save_pickle/{}/tpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[10] =  np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/tpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[10] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[10] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[10] = (total_tpr[10] + (1-total_fpr[10]))/2
# with open('final_test/save_pickle/{}/balanced_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[10] = np.array(pickle.load(filehandle))

# %%
dataset_used = 'Compas'

# %%
print(dataset_used)
m1 = np.mean(total_tpr_priv, -1)
s1 = np.std(total_tpr_priv, -1)
m2 = np.mean(total_tpr_unpriv, -1)
s2 = np.std(total_tpr_unpriv, -1)
m3 = abs(np.mean(total_eqopp_diff, -1))
s3 = np.std(total_eqopp_diff, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('Meta \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
      .format(m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print()

bal_acc_priv = (total_tpr_priv + (1-total_fpr_priv))/2
bal_acc_unpriv = (total_tpr_unpriv + (1-total_fpr_unpriv))/2
bal_acc_overall = (total_tpr + (1-total_fpr))/2

bal_acc_priv_m = np.mean(bal_acc_priv, -1)
bal_acc_priv_s = np.std(bal_acc_priv, -1)
bal_acc_unpriv_m = np.mean(bal_acc_unpriv, -1)
bal_acc_unpriv_s = np.std(bal_acc_unpriv, -1)
bal_acc_diff_m = abs(bal_acc_priv_m - bal_acc_unpriv_m)
bal_acc_diff_s = np.std(total_acc_priv - bal_acc_unpriv, -1)
bal_acc_overall_m = np.mean(bal_acc_overall, -1)
bal_acc_overall_s = np.std(bal_acc_overall, -1)


acc_priv_m = np.mean(total_acc_priv, -1)
acc_priv_s = np.std(total_acc_priv, -1)
acc_unpriv_m = np.mean(total_acc_unpriv, -1)
acc_unpriv_s = np.std(total_acc_unpriv, -1)
acc_diff_m = abs(acc_priv_m - acc_unpriv_m)
acc_diff_s = np.std(total_acc_priv - total_acc_unpriv, -1)

# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[1], acc_priv_s[1], acc_unpriv_m[1], acc_unpriv_s[1],acc_diff_m[1], acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[2], acc_priv_s[2], acc_unpriv_m[2], acc_unpriv_s[2],acc_diff_m[2], acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[3], acc_priv_s[3], acc_unpriv_m[3], acc_unpriv_s[3],acc_diff_m[3], acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[5], acc_priv_s[5], acc_unpriv_m[5], acc_unpriv_s[5],acc_diff_m[5], acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(acc_priv_m[6], acc_priv_s[6], acc_unpriv_m[6], acc_unpriv_s[6],acc_diff_m[6], acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[7], acc_priv_s[7], acc_unpriv_m[7], acc_unpriv_s[7],acc_diff_m[7], acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[9], acc_priv_s[9], acc_unpriv_m[9], acc_unpriv_s[9],acc_diff_m[9], acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#     .format(acc_priv_m[0], acc_priv_s[0], acc_unpriv_m[0], acc_unpriv_s[0],acc_diff_m[0], acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(acc_priv_m[10], acc_priv_s[10], acc_unpriv_m[10], acc_unpriv_s[10],acc_diff_m[10], acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))

# print()
# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[3], bal_acc_overall_m[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[5], bal_acc_overall_m[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[6], bal_acc_overall_m[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[7], bal_acc_overall_m[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
#     .format(bal_acc_overall_m[10], bal_acc_overall_m[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[9], bal_acc_overall_m[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(bal_acc_overall_m[0], bal_acc_overall_m[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# print()
# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[3], bal_acc_overall_m[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[5], bal_acc_overall_m[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[6], bal_acc_overall_m[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[7], bal_acc_overall_m[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
#     .format(bal_acc_overall_m[10], bal_acc_overall_m[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[9], bal_acc_overall_m[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(bal_acc_overall_m[0], bal_acc_overall_m[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# Out:
# Compas
# AdvDeb 		 & 0.657 $\pm$ 0.007 	 & 0.846 $\pm$ 0.007 	 & 0.190 $\pm$ 0.014  \\
# CEOPost 	 & 0.569 $\pm$ 0.105 	 & 1.000 $\pm$ 0.000 	 & 0.431 $\pm$ 0.105  \\
# DIR 		 & 0.603 $\pm$ 0.014 	 & 0.925 $\pm$ 0.036 	 & 0.322 $\pm$ 0.022  \\
# Meta 		 & 0.843 $\pm$ 0.023 	 & 0.855 $\pm$ 0.023 	 & 0.012 $\pm$ 0.016  \\ \hhline{=|===}
# ReW 		 & 0.725 $\pm$ 0.027 	 & 0.950 $\pm$ 0.028 	 & 0.225 $\pm$ 0.055  \\
# RejOpt 		 & 0.632 $\pm$ 0.047 	 & 0.618 $\pm$ 0.064 	 & 0.014 $\pm$ 0.017  \\ \hhline{=|===}
# Ours 		 & 0.676 $\pm$ 0.054 	 & 0.745 $\pm$ 0.036 	 & 0.069 $\pm$ 0.019  \\ \hhline{=|===}
# Ours_w 		 & 0.000 $\pm$ 0.000 	 & 0.000 $\pm$ 0.000 	 & 0.327 $\pm$ 0.088  \\ \hhline{=|===}
# Baseline 	 & 0.472 $\pm$ 0.021 	 & 0.626 $\pm$ 0.024 	 & 0.154 $\pm$ 0.025  \\ \hline

# %%
m4 = np.mean(total_acc, -1)
s4 = np.std(total_acc, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f} \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m4[1], s4[1], acc_diff_m[1], acc_diff_s[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m4[2], s4[2], acc_diff_m[2], acc_diff_s[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m4[3], s4[3], acc_diff_m[3], acc_diff_s[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m4[5], s4[5], acc_diff_m[5], acc_diff_s[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m4[6], s4[6], acc_diff_m[6], acc_diff_s[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m4[7], s4[7], acc_diff_m[7], acc_diff_s[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m4[10], s4[10], acc_diff_m[10], acc_diff_s[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[9], bal_acc_overall_s[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m4[9], s4[9], acc_diff_m[9], acc_diff_s[9], m3[9]))
# Out:
# AdvDeb 		 & 0.655 $\pm$ 0.008 	 &  0.035 $\pm$ 0.007 	 & 0.659 $\pm$ 0.007  	 & 0.005 $\pm$ 0.010 \\
# CEOPost 	 & 0.630 $\pm$ 0.014 	 &  0.150 $\pm$ 0.016 	 & 0.632 $\pm$ 0.019  	 & 0.052 $\pm$ 0.016  \\
# DIR 		 & 0.668 $\pm$ 0.008 	 &  0.038 $\pm$ 0.003 	 & 0.668 $\pm$ 0.006  	 & 0.016 $\pm$ 0.006  \\
# MFC 		 & 0.478 $\pm$ 0.011 	 &  0.032 $\pm$ 0.009 	 & 0.509 $\pm$ 0.017  	 & 0.110 $\pm$ 0.027  \\
# ReW 		 & 0.655 $\pm$ 0.007 	 &  0.067 $\pm$ 0.003 	 & 0.665 $\pm$ 0.007  	 & 0.009 $\pm$ 0.016  \\
# RejOpt 		 & 0.660 $\pm$ 0.013 	 &  0.019 $\pm$ 0.006 	 & 0.657 $\pm$ 0.017  	 & 0.018 $\pm$ 0.017  \\
# Baseline 	 & 0.676 $\pm$ 0.005 	 &  0.045 $\pm$ 0.019 	 & 0.684 $\pm$ 0.005  	 & 0.005 $\pm$ 0.018  \\ \hhline{=|======}
# Ours 		 & 0.639 $\pm$ 0.008 	 &  0.016 $\pm$ 0.031 	 & 0.629 $\pm$ 0.009  	 & 0.027 $\pm$ 0.030  \\ \hline

# %%
print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
        .format(bal_acc_overall_m[9], bal_acc_overall_s[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# Out:
# AdvDeb 		 & 0.655 $\pm$ 0.008 	 &  0.035 $\pm$ 0.007 	 & 0.657 $\pm$ 0.007  	 & 0.846 $\pm$ 0.007  	 & 0.190 $\pm$ 0.014  \\
# CEOPost 	 & 0.630 $\pm$ 0.014 	 &  0.150 $\pm$ 0.016 	 & 0.569 $\pm$ 0.105  	 & 1.000 $\pm$ 0.000  	 & 0.431 $\pm$ 0.105  \\
# DIR 		 & 0.668 $\pm$ 0.008 	 &  0.038 $\pm$ 0.003 	 & 0.603 $\pm$ 0.014  	 & 0.925 $\pm$ 0.036  	 & 0.322 $\pm$ 0.022  \\
# MFC 		 & 0.478 $\pm$ 0.011 	 &  0.032 $\pm$ 0.009 	 & 0.843 $\pm$ 0.023  	 & 0.855 $\pm$ 0.023  	 & 0.012 $\pm$ 0.016  \\
# ReW 		 & 0.655 $\pm$ 0.007 	 &  0.067 $\pm$ 0.003 	 & 0.725 $\pm$ 0.027  	 & 0.950 $\pm$ 0.028  	 & 0.225 $\pm$ 0.055  \\
# RejOpt 		 & 0.660 $\pm$ 0.013 	 &  0.019 $\pm$ 0.006 	 & 0.632 $\pm$ 0.047  	 & 0.618 $\pm$ 0.064  	 & 0.014 $\pm$ 0.017  \\
# Baseline 	 & 0.676 $\pm$ 0.005 	 &  0.045 $\pm$ 0.019 	 & 0.472 $\pm$ 0.021  	 & 0.626 $\pm$ 0.024  	 & 0.154 $\pm$ 0.025  \\ \hhline{=|======}
# ...

# %%
total_aveodds_diff = abs(0.5 * (total_tpr_priv + total_fpr_priv) - 0.5 * (total_tpr_unpriv + total_fpr_unpriv))

# %%
x_pd = [i for i in x for j in range(repeat) ]
metric_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'Abs Balanced ACC Diff']
metric_list_pd = [i for i in metirc_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,9]
values = np.array([])

bal_acc_diff = bal_acc_priv - bal_acc_unpriv

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(bal_acc_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*len(metric_list), metirc_list_pd, values), columns=["method", "metric", "data"])

# %%
sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2,9]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="metric", y="data", data=df, capsize=.1, errwidth = 1.5, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')

plt.tight_layout()
plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()

# %%
print(total_eqopp_diff.mean(-1)[10])
print(bal_acc_diff.mean(-1)[10])
print(total_aveodds_diff.mean(-1)[10])
# Out:
# 0.1538431763648987
# -0.04455718249082565
# 0.10928599387407303

# %%
print(total_eqopp_diff.mean(-1)[9])
print(bal_acc_diff.mean(-1)[9])
print(total_aveodds_diff.mean(-1)[9])
# Out:
# 0.06938931941986085
# -0.016108369827270506
# 0.05328094959259033

# %%
0.044557/0.0161
# Out:
# 2.7675155279503105

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,10,9])

# %%
plot(np.abs(1-total_disimpact/(P_Y1_A0/P_Y1_A1)), 9, dataset_used, setting, method_idx = [1,2,3,6,7,9, 10])

# %%
dataset_used = 'bank'

# %%
protected_attribute_used = 1

if dataset_used == "adult":
    dataset = AdultDataset()
    # #dataset = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "german":
    dataset = GermanDataset()
    dataset.labels = dataset.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif dataset_used == "compas":
    dataset = CompasDataset()
    # #dataset = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "bank":
    dataset = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif dataset_used == "meps":
    dataset = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

sens_idx = dataset.feature_names.index(sens_attr)

P_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 1)
N_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 0)

P_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 1)
N_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 0)

P_Y1_A1 = P_priv/(P_priv + N_priv)
P_Y1_A0 = P_unpriv/(P_unpriv + N_unpriv)
# Out:
# WARNING:root:Missing Data: 10700 rows removed from BankDataset.

# %%
total_tpr = np.load('../AIF360/examples/result_data/{}/total_tpr.npy'.format(dataset_used))
total_tpr_priv = np.load('../AIF360/examples/result_data/{}/total_tpr_priv.npy'.format(dataset_used))
total_tpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_tpr_unpriv.npy'.format(dataset_used))
total_eqopp_diff = np.load('../AIF360/examples/result_data/{}/total_eqopp_diff.npy'.format(dataset_used))

total_fpr = np.load('../AIF360/examples/result_data/{}/total_fpr.npy'.format(dataset_used))
total_fpr_priv = np.load('../AIF360/examples/result_data/{}/total_fpr_priv.npy'.format(dataset_used))
total_fpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_fpr_unpriv.npy'.format(dataset_used))
total_fpr_diff = np.load('../AIF360/examples/result_data/{}/total_fpr_diff.npy'.format(dataset_used))

total_acc = np.load('../AIF360/examples/result_data/{}/total_acc.npy'.format(dataset_used))
total_acc_priv = np.load('../AIF360/examples/result_data/{}/total_acc_priv.npy'.format(dataset_used))
total_acc_unpriv = np.load('../AIF360/examples/result_data/{}/total_acc_unpriv.npy'.format(dataset_used))
# abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc = np.load('../AIF360/examples/result_data/{}/total_balanced_acc.npy'.format(dataset_used))
total_disimpact = np.load('../AIF360/examples/result_data/{}/total_disimpact.npy'.format(dataset_used))
total_theil_idx = np.load('../AIF360/examples/result_data/{}/total_theil_idx.npy'.format(dataset_used))
stat_parity_diff = np.load('../AIF360/examples/result_data/{}/stat_parity_diff.npy'.format(dataset_used))

# %%
with open('weighted_test/save_pickle/{}/tpr_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[0] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[0] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[0] = np.array(pickle.load(filehandle))  
with open('weighted_test/save_pickle/{}/eq_opp_hist_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/fpr_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_diff_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/acc_overall_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_priv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_unpriv_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[0] = np.array(pickle.load(filehandle))
# with open('weighted_test/save_pickle/{}/acc_diff_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
with open('weighted_test/save_pickle/{}/balanced_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_balanced_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/dis_impact_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/theil_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/stat_best_weight.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[0] = np.array(pickle.load(filehandle))

# %%
with open('final_test/save_pickle/{}/tpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[9] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[9] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[9] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[9] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/balanced_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_balanced_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_best.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[9] = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/tpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[10] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[10] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/balanced_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_balanced_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[10] = np.array(pickle.load(filehandle))
    
    
dataset_used = 'Bank'

# %%
print(dataset_used)
m1 = np.mean(total_tpr_priv, -1)
s1 = np.std(total_tpr_priv, -1)
m2 = np.mean(total_tpr_unpriv, -1)
s2 = np.std(total_tpr_unpriv, -1)
m3 = abs(np.mean(total_eqopp_diff, -1))
s3 = np.std(total_eqopp_diff, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('Meta \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
      .format(m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print()

bal_acc_priv = (total_tpr_priv + (1-total_fpr_priv))/2
bal_acc_unpriv = (total_tpr_unpriv + (1-total_fpr_unpriv))/2
bal_acc_overall = (total_tpr + (1-total_fpr))/2

bal_acc_priv_m = np.mean(bal_acc_priv, -1)
bal_acc_priv_s = np.std(bal_acc_priv, -1)
bal_acc_unpriv_m = np.mean(bal_acc_unpriv, -1)
bal_acc_unpriv_s = np.std(bal_acc_unpriv, -1)
bal_acc_diff_m = abs(bal_acc_priv_m - bal_acc_unpriv_m)
bal_acc_diff_s = np.std(total_acc_priv - bal_acc_unpriv, -1)
bal_acc_overall_m = np.mean(bal_acc_overall, -1)
bal_acc_overall_s = np.std(bal_acc_overall, -1)


acc_priv_m = np.mean(total_acc_priv, -1)
acc_priv_s = np.std(total_acc_priv, -1)
acc_unpriv_m = np.mean(total_acc_unpriv, -1)
acc_unpriv_s = np.std(total_acc_unpriv, -1)
acc_diff_m = abs(acc_priv_m - acc_unpriv_m)
acc_diff_s = np.std(total_acc_priv - total_acc_unpriv, -1)

# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[1], acc_priv_s[1], acc_unpriv_m[1], acc_unpriv_s[1],acc_diff_m[1], acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[2], acc_priv_s[2], acc_unpriv_m[2], acc_unpriv_s[2],acc_diff_m[2], acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[3], acc_priv_s[3], acc_unpriv_m[3], acc_unpriv_s[3],acc_diff_m[3], acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[5], acc_priv_s[5], acc_unpriv_m[5], acc_unpriv_s[5],acc_diff_m[5], acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(acc_priv_m[6], acc_priv_s[6], acc_unpriv_m[6], acc_unpriv_s[6],acc_diff_m[6], acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[7], acc_priv_s[7], acc_unpriv_m[7], acc_unpriv_s[7],acc_diff_m[7], acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[9], acc_priv_s[9], acc_unpriv_m[9], acc_unpriv_s[9],acc_diff_m[9], acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#     .format(acc_priv_m[0], acc_priv_s[0], acc_unpriv_m[0], acc_unpriv_s[0],acc_diff_m[0], acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(acc_priv_m[10], acc_priv_s[10], acc_unpriv_m[10], acc_unpriv_s[10],acc_diff_m[10], acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))


# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[3], bal_acc_overall_m[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[5], bal_acc_overall_m[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[6], bal_acc_overall_m[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[7], bal_acc_overall_m[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
#     .format(bal_acc_overall_m[10], bal_acc_overall_m[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[9], bal_acc_overall_m[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(bal_acc_overall_m[0], bal_acc_overall_m[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# Out:
# Bank
# AdvDeb 		 & 0.465 $\pm$ 0.010 	 & 0.626 $\pm$ 0.016 	 & 0.161 $\pm$ 0.026  \\
# CEOPost 	 & 0.423 $\pm$ 0.022 	 & 0.612 $\pm$ 0.008 	 & 0.189 $\pm$ 0.030  \\
# DIR 		 & 0.866 $\pm$ 0.033 	 & 0.651 $\pm$ 0.023 	 & 0.215 $\pm$ 0.010  \\
# Meta 		 & 0.975 $\pm$ 0.033 	 & 0.937 $\pm$ 0.030 	 & 0.038 $\pm$ 0.020  \\ \hhline{=|===}
# ReW 		 & 0.898 $\pm$ 0.027 	 & 0.875 $\pm$ 0.001 	 & 0.024 $\pm$ 0.026  \\
# RejOpt 		 & 0.486 $\pm$ 0.087 	 & 0.540 $\pm$ 0.131 	 & 0.055 $\pm$ 0.044  \\ \hhline{=|===}
# Ours 		 & 0.687 $\pm$ 0.033 	 & 0.708 $\pm$ 0.043 	 & 0.033 $\pm$ 0.030  \\ \hhline{=|===}
# Ours_w 		 & 0.797 $\pm$ 0.012 	 & 0.788 $\pm$ 0.045 	 & 0.038 $\pm$ 0.013  \\ \hhline{=|===}
# Baseline 	 & 0.564 $\pm$ 0.068 	 & 0.503 $\pm$ 0.060 	 & 0.084 $\pm$ 0.037  \\ \hline

# %%
m4 = np.mean(total_acc, -1)
s4 = np.std(total_acc, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f} \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m4[1], s4[1], acc_diff_m[1], acc_diff_s[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m4[2], s4[2], acc_diff_m[2], acc_diff_s[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m4[3], s4[3], acc_diff_m[3], acc_diff_s[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m4[5], s4[5], acc_diff_m[5], acc_diff_s[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m4[6], s4[6], acc_diff_m[6], acc_diff_s[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m4[7], s4[7], acc_diff_m[7], acc_diff_s[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m4[10], s4[10], acc_diff_m[10], acc_diff_s[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[0], bal_acc_overall_s[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m4[0], s4[0], acc_diff_m[0], acc_diff_s[0], m3[0]))
# Out:
# AdvDeb 		 & 0.776 $\pm$ 0.006 	 &  0.063 $\pm$ 0.019 	 & 0.895 $\pm$ 0.001  	 & 0.038 $\pm$ 0.012 \\
# CEOPost 	 & 0.774 $\pm$ 0.003 	 &  0.110 $\pm$ 0.014 	 & 0.903 $\pm$ 0.001  	 & 0.098 $\pm$ 0.012  \\
# DIR 		 & 0.740 $\pm$ 0.001 	 &  0.023 $\pm$ 0.038 	 & 0.800 $\pm$ 0.014  	 & 0.175 $\pm$ 0.023  \\
# MFC 		 & 0.846 $\pm$ 0.024 	 &  0.054 $\pm$ 0.054 	 & 0.776 $\pm$ 0.061  	 & 0.081 $\pm$ 0.035  \\
# ReW 		 & 0.863 $\pm$ 0.001 	 &  0.067 $\pm$ 0.009 	 & 0.853 $\pm$ 0.000  	 & 0.117 $\pm$ 0.009  \\
# RejOpt 		 & 0.745 $\pm$ 0.057 	 &  0.062 $\pm$ 0.070 	 & 0.900 $\pm$ 0.006  	 & 0.107 $\pm$ 0.017  \\
# Baseline 	 & 0.752 $\pm$ 0.028 	 &  0.045 $\pm$ 0.030 	 & 0.891 $\pm$ 0.005  	 & 0.116 $\pm$ 0.021  \\ \hhline{=|======}
# Ours 		 & 0.837 $\pm$ 0.009 	 &  0.023 $\pm$ 0.024 	 & 0.867 $\pm$ 0.006  	 & 0.040 $\pm$ 0.023  \\ \hline

# %%
print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[0], bal_acc_overall_s[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# Out:
# AdvDeb 		 & 0.776 $\pm$ 0.006 	 &  0.063 $\pm$ 0.019 	 & 0.465 $\pm$ 0.010  	 & 0.626 $\pm$ 0.016  	 & 0.161 $\pm$ 0.026  \\
# CEOPost 	 & 0.774 $\pm$ 0.003 	 &  0.110 $\pm$ 0.014 	 & 0.423 $\pm$ 0.022  	 & 0.612 $\pm$ 0.008  	 & 0.189 $\pm$ 0.030  \\
# DIR 		 & 0.740 $\pm$ 0.001 	 &  0.023 $\pm$ 0.038 	 & 0.866 $\pm$ 0.033  	 & 0.651 $\pm$ 0.023  	 & 0.215 $\pm$ 0.010  \\
# MFC 		 & 0.846 $\pm$ 0.024 	 &  0.054 $\pm$ 0.054 	 & 0.975 $\pm$ 0.033  	 & 0.937 $\pm$ 0.030  	 & 0.038 $\pm$ 0.020  \\
# ReW 		 & 0.863 $\pm$ 0.001 	 &  0.067 $\pm$ 0.009 	 & 0.898 $\pm$ 0.027  	 & 0.875 $\pm$ 0.001  	 & 0.024 $\pm$ 0.026  \\
# RejOpt 		 & 0.745 $\pm$ 0.057 	 &  0.062 $\pm$ 0.070 	 & 0.486 $\pm$ 0.087  	 & 0.540 $\pm$ 0.131  	 & 0.055 $\pm$ 0.044  \\
# Baseline 	 & 0.752 $\pm$ 0.028 	 &  0.045 $\pm$ 0.030 	 & 0.564 $\pm$ 0.068  	 & 0.503 $\pm$ 0.060  	 & 0.084 $\pm$ 0.037  \\ \hhline{=|======}
# ...

# %%
total_aveodds_diff = abs(0.5 * (total_tpr_priv + total_fpr_priv) - 0.5 * (total_tpr_unpriv +  total_fpr_unpriv))

# %%
x_pd = [i for i in x for j in range(repeat) ]
metirc_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'Abs Balanced ACC Diff']
metirc_list_pd = [i for i in metirc_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,0]
values = np.array([])

bal_acc_diff = bal_acc_priv - bal_acc_unpriv

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(bal_acc_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*len(metric_list), metirc_list_pd, values), columns=["method", "metric", "data"])

# %%
sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2,9]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="metric", y="data", data=df, capsize=.1, errwidth = 1.5, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')

plt.tight_layout()
plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()

# %%
print(total_eqopp_diff.mean(-1)[5])
print(bal_acc_diff.mean(-1)[5])
print(total_aveodds_diff.mean(-1)[5])
# Out:
# 0.038129611774448735
# -0.0543739301218076
# 0.09250354189625627

# %%
print(total_eqopp_diff.mean(-1)[0])
print(bal_acc_diff.mean(-1)[0])
print(total_aveodds_diff.mean(-1)[0])
# Out:
# 0.03796300888061523
# 0.02269398346543312
# 0.025015237182378768

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,7,10,0])

# %%
dataset_used = 'meps'

# %%
protected_attribute_used = 1

if dataset_used == "adult":
    dataset = AdultDataset()
    # #dataset = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "german":
    dataset = GermanDataset()
    dataset.labels = dataset.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif dataset_used == "compas":
    dataset = CompasDataset()
    # #dataset = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "bank":
    dataset = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif dataset_used == "meps":
    dataset = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

sens_idx = dataset.feature_names.index(sens_attr)

P_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 1)
N_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 0)

P_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 1)
N_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 0)

P_Y1_A1 = P_priv/(P_priv + N_priv)
P_Y1_A0 = P_unpriv/(P_unpriv + N_unpriv)

# %%
total_tpr = np.load('../AIF360/examples/result_data/{}/total_tpr.npy'.format(dataset_used))
total_tpr_priv = np.load('../AIF360/examples/result_data/{}/total_tpr_priv.npy'.format(dataset_used))
total_tpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_tpr_unpriv.npy'.format(dataset_used))
total_eqopp_diff = np.load('../AIF360/examples/result_data/{}/total_eqopp_diff.npy'.format(dataset_used))

total_fpr = np.load('../AIF360/examples/result_data/{}/total_fpr.npy'.format(dataset_used))
total_fpr_priv = np.load('../AIF360/examples/result_data/{}/total_fpr_priv.npy'.format(dataset_used))
total_fpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_fpr_unpriv.npy'.format(dataset_used))
total_fpr_diff = np.load('../AIF360/examples/result_data/{}/total_fpr_diff.npy'.format(dataset_used))

total_acc = np.load('../AIF360/examples/result_data/{}/total_acc.npy'.format(dataset_used))
total_acc_priv = np.load('../AIF360/examples/result_data/{}/total_acc_priv.npy'.format(dataset_used))
total_acc_unpriv = np.load('../AIF360/examples/result_data/{}/total_acc_unpriv.npy'.format(dataset_used))
# abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc = np.load('../AIF360/examples/result_data/{}/total_balanced_acc.npy'.format(dataset_used))
total_disimpact = np.load('../AIF360/examples/result_data/{}/total_disimpact.npy'.format(dataset_used))
total_theil_idx = np.load('../AIF360/examples/result_data/{}/total_theil_idx.npy'.format(dataset_used))
stat_parity_diff = np.load('../AIF360/examples/result_data/{}/stat_parity_diff.npy'.format(dataset_used))

# %%
with open('final_test/save_pickle/{}/tpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[9] =  np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/tpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[9] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[9] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[9] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[9] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_best.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[9] = (total_tpr[9] + (1-total_fpr[9]))/2
# with open('final_test/save_pickle/{}/balanced_best.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_best.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[9] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_best.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[9] = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/tpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[10] = np.array(pickle.load(filehandle))    
with open('final_test/save_pickle/{}/tpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[10] = np.array(pickle.load(filehandle))  
with open('final_test/save_pickle/{}/eq_opp_hist_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/fpr_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/fpr_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[10] = np.array(pickle.load(filehandle))
    

with open('final_test/save_pickle/{}/acc_overall_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_priv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/acc_unpriv_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[10] = np.array(pickle.load(filehandle))
# with open('final_test/save_pickle/{}/acc_diff_abl.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
with open('final_test/save_pickle/{}/balanced_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_balanced_acc[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/dis_impact_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/theil_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[10] = np.array(pickle.load(filehandle))
with open('final_test/save_pickle/{}/stat_abl.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[10] = np.array(pickle.load(filehandle))

# %%
with open('weighted_test/save_pickle/{}/tpr_overall_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr[0] =  np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/tpr_priv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_priv[0] = np.array(pickle.load(filehandle))    
with open('weighted_test/save_pickle/{}/tpr_unpriv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_tpr_unpriv[0] = np.array(pickle.load(filehandle))  
with open('weighted_test/save_pickle/{}/eq_opp_hist_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_eqopp_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/fpr_overall_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_priv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_unpriv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_unpriv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/fpr_diff_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_fpr_diff[0] = np.array(pickle.load(filehandle))
    

with open('weighted_test/save_pickle/{}/acc_overall_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_priv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_priv[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/acc_unpriv_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_acc_unpriv[0] = np.array(pickle.load(filehandle))
# with open('weighted_test/save_pickle/{}/acc_diff_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
#      = np.array(pickle.load(filehandle))
    
total_balanced_acc[0] = (total_tpr[0] + (1-total_fpr[0]))/2
# with open('weighted_test/save_pickle/{}/balanced_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
#     total_balanced_acc[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/dis_impact_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_disimpact[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/theil_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    total_theil_idx[0] = np.array(pickle.load(filehandle))
with open('weighted_test/save_pickle/{}/stat_best_weighted.pkl'.format(dataset_used), 'rb') as filehandle:
    stat_parity_diff[0] = np.array(pickle.load(filehandle))
    
dataset_used = 'Meps'

# %%
total_aveodds_diff = abs(0.5 * (total_tpr_priv + total_fpr_priv) - 0.5 * (total_tpr_unpriv + total_fpr_unpriv))

# %%
print(dataset_used)
m1 = np.mean(total_tpr_priv, -1)
s1 = np.std(total_tpr_priv, -1)
m2 = np.mean(total_tpr_unpriv, -1)
s2 = np.std(total_tpr_unpriv, -1)
m3 = abs(np.mean(total_eqopp_diff, -1))
s3 = np.std(total_eqopp_diff, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('Meta \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
      .format(m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print()

bal_acc_priv = (total_tpr_priv + (1-total_fpr_priv))/2
bal_acc_unpriv = (total_tpr_unpriv + (1-total_fpr_unpriv))/2
bal_acc_overall = (total_tpr + (1-total_fpr))/2

bal_acc_priv_m = np.mean(bal_acc_priv, -1)
bal_acc_priv_s = np.std(bal_acc_priv, -1)
bal_acc_unpriv_m = np.mean(bal_acc_unpriv, -1)
bal_acc_unpriv_s = np.std(bal_acc_unpriv, -1)
bal_acc_diff_m = abs(bal_acc_priv_m - bal_acc_unpriv_m)
bal_acc_diff_s = np.std(total_acc_priv - bal_acc_unpriv, -1)
bal_acc_overall_m = np.mean(bal_acc_overall, -1)
bal_acc_overall_s = np.std(bal_acc_overall, -1)


acc_priv_m = np.mean(total_acc_priv, -1)
acc_priv_s = np.std(total_acc_priv, -1)
acc_unpriv_m = np.mean(total_acc_unpriv, -1)
acc_unpriv_s = np.std(total_acc_unpriv, -1)
acc_diff_m = abs(acc_priv_m - acc_unpriv_m)
acc_diff_s = np.std(total_acc_priv - total_acc_unpriv, -1)
# Out:
# Meps
# AdvDeb 		 & 0.320 $\pm$ 0.028 	 & 0.377 $\pm$ 0.040 	 & 0.058 $\pm$ 0.012  \\
# CEOPost 	 & 0.263 $\pm$ 0.004 	 & 0.178 $\pm$ 0.010 	 & 0.085 $\pm$ 0.014  \\
# DIR 		 & 0.672 $\pm$ 0.004 	 & 0.787 $\pm$ 0.029 	 & 0.115 $\pm$ 0.033  \\
# Meta 		 & 0.738 $\pm$ 0.028 	 & 0.868 $\pm$ 0.018 	 & 0.130 $\pm$ 0.043  \\ \hhline{=|===}
# ReW 		 & 0.585 $\pm$ 0.001 	 & 0.768 $\pm$ 0.021 	 & 0.183 $\pm$ 0.019  \\
# RejOpt 		 & 0.708 $\pm$ 0.017 	 & 0.626 $\pm$ 0.014 	 & 0.082 $\pm$ 0.003  \\ \hhline{=|===}
# Ours 		 & 0.705 $\pm$ 0.065 	 & 0.634 $\pm$ 0.058 	 & 0.071 $\pm$ 0.012  \\ \hhline{=|===}
# Ours_w 		 & 0.746 $\pm$ 0.021 	 & 0.665 $\pm$ 0.039 	 & 0.080 $\pm$ 0.024  \\ \hhline{=|===}
# Baseline 	 & 0.768 $\pm$ 0.096 	 & 0.662 $\pm$ 0.095 	 & 0.107 $\pm$ 0.009  \\ \hline

# %%
m4 = np.mean(total_acc, -1)
s4 = np.std(total_acc, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f} \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m4[1], s4[1], acc_diff_m[1], acc_diff_s[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m4[2], s4[2], acc_diff_m[2], acc_diff_s[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m4[3], s4[3], acc_diff_m[3], acc_diff_s[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m4[5], s4[5], acc_diff_m[5], acc_diff_s[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m4[6], s4[6], acc_diff_m[6], acc_diff_s[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m4[7], s4[7], acc_diff_m[7], acc_diff_s[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m4[10], s4[10], acc_diff_m[10], acc_diff_s[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[9], bal_acc_overall_s[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m4[9], s4[9], acc_diff_m[9], acc_diff_s[9], m3[9]))
# Out:
# AdvDeb 		 & 0.655 $\pm$ 0.015 	 &  0.007 $\pm$ 0.017 	 & 0.814 $\pm$ 0.008  	 & 0.112 $\pm$ 0.012 \\
# CEOPost 	 & 0.587 $\pm$ 0.001 	 &  0.047 $\pm$ 0.004 	 & 0.799 $\pm$ 0.008  	 & 0.137 $\pm$ 0.009  \\
# DIR 		 & 0.763 $\pm$ 0.003 	 &  0.014 $\pm$ 0.018 	 & 0.765 $\pm$ 0.008  	 & 0.095 $\pm$ 0.008  \\
# MFC 		 & 0.755 $\pm$ 0.006 	 &  0.070 $\pm$ 0.032 	 & 0.710 $\pm$ 0.012  	 & 0.173 $\pm$ 0.044  \\
# ReW 		 & 0.752 $\pm$ 0.004 	 &  0.015 $\pm$ 0.007 	 & 0.767 $\pm$ 0.005  	 & 0.146 $\pm$ 0.000  \\
# RejOpt 		 & 0.733 $\pm$ 0.005 	 &  0.034 $\pm$ 0.004 	 & 0.780 $\pm$ 0.000  	 & 0.029 $\pm$ 0.008  \\
# Baseline 	 & 0.746 $\pm$ 0.025 	 &  0.003 $\pm$ 0.051 	 & 0.765 $\pm$ 0.036  	 & 0.076 $\pm$ 0.006  \\ \hhline{=|======}
# Ours 		 & 0.744 $\pm$ 0.013 	 &  0.010 $\pm$ 0.041 	 & 0.790 $\pm$ 0.039  	 & 0.080 $\pm$ 0.006  \\ \hline

# %%
m4 = np.mean(total_acc, -1)
s4 = np.std(total_acc, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f} \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m4[1], s4[1], acc_diff_m[1], acc_diff_s[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m4[2], s4[2], acc_diff_m[2], acc_diff_s[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m4[3], s4[3], acc_diff_m[3], acc_diff_s[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m4[5], s4[5], acc_diff_m[5], acc_diff_s[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m4[6], s4[6], acc_diff_m[6], acc_diff_s[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m4[7], s4[7], acc_diff_m[7], acc_diff_s[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m4[10], s4[10], acc_diff_m[10], acc_diff_s[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
    .format(bal_acc_overall_m[9], bal_acc_overall_s[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m4[9], s4[9], acc_diff_m[9], acc_diff_s[9], m3[9]))
# Out:
# AdvDeb 		 & 0.655 $\pm$ 0.015 	 &  0.007 $\pm$ 0.017 	 & 0.814 $\pm$ 0.008  	 & 0.112 $\pm$ 0.012 \\
# CEOPost 	 & 0.587 $\pm$ 0.001 	 &  0.047 $\pm$ 0.004 	 & 0.799 $\pm$ 0.008  	 & 0.137 $\pm$ 0.009  \\
# DIR 		 & 0.763 $\pm$ 0.003 	 &  0.014 $\pm$ 0.018 	 & 0.765 $\pm$ 0.008  	 & 0.095 $\pm$ 0.008  \\
# MFC 		 & 0.755 $\pm$ 0.006 	 &  0.070 $\pm$ 0.032 	 & 0.710 $\pm$ 0.012  	 & 0.173 $\pm$ 0.044  \\
# ReW 		 & 0.752 $\pm$ 0.004 	 &  0.015 $\pm$ 0.007 	 & 0.767 $\pm$ 0.005  	 & 0.146 $\pm$ 0.000  \\
# RejOpt 		 & 0.733 $\pm$ 0.005 	 &  0.034 $\pm$ 0.004 	 & 0.780 $\pm$ 0.000  	 & 0.029 $\pm$ 0.008  \\
# Baseline 	 & 0.746 $\pm$ 0.025 	 &  0.003 $\pm$ 0.051 	 & 0.765 $\pm$ 0.036  	 & 0.076 $\pm$ 0.006  \\ \hhline{=|======}
# Ours 		 & 0.744 $\pm$ 0.013 	 &  0.010 $\pm$ 0.041 	 & 0.790 $\pm$ 0.039  	 & 0.080 $\pm$ 0.006  \\ \hline

# %%
x_pd = [i for i in x for j in range(repeat) ]
metirc_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'Abs Balanced ACC Diff']
metirc_list_pd = [i for i in metirc_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,9]
values = np.array([])

bal_acc_diff = bal_acc_priv - bal_acc_unpriv

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(bal_acc_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*len(metric_list), metirc_list_pd, values), columns=["method", "metric", "data"])

# %%
sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2,9]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="metric", y="data", data=df, capsize=.1, errwidth = 1.5, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')

plt.tight_layout()
plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()

# %%
x_pd = [i for i in x for j in range(repeat) ]
metirc_list = ['Abs Eq.Opp Diff', 'Abs Avg.Odds Diff', 'FPR Diff']
metirc_list_pd = [i for i in metirc_list for j in range(len(x_pd))]


method_idx = [1,2,3,5,6,10,9]
values = np.array([])

for idx in method_idx:
    values = np.concatenate((values,abs(total_eqopp_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_aveodds_diff[idx])), -1)
for idx in method_idx:
    values = np.concatenate((values,abs(total_fpr_diff[idx])), -1)

df = pd.DataFrame(zip(x_pd*3, metirc_list_pd, values), columns=["method", "metric", "data"])

# %%
sns.set_style("ticks")


current_palette = np.array(sns.color_palette('colorblind'))[[0,3,2]]
sns.palplot(current_palette)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="method", hue="metric", y="data", data=df, capsize=.1, errwidth = 1.5, errcolor='.0',\
            palette = current_palette, )
ax.set(xlabel= '', ylabel='')
ax.set_xticklabels(x, fontsize=13)
ax2 = ax.twinx()
ax2.set_yticks(np.arange(2))
ax2.set_yticklabels(['Fair', 'Bias'], fontsize=15, color='red')

plt.tight_layout()
plt.savefig('./plot_fig/'+dataset_used+'.png')
plt.show()

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,5,6,10,0])

# %%
print(dataset_used)
m1 = np.mean(total_tpr_priv, -1)
s1 = np.std(total_tpr_priv, -1)
m2 = np.mean(total_tpr_unpriv, -1)
s2 = np.std(total_tpr_unpriv, -1)
m3 = abs(np.mean(total_eqopp_diff, -1))
s3 = np.std(total_eqopp_diff, -1)

print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('Meta \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ '\
      .format(m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
      .format(m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
      .format(m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print()

bal_acc_priv = (total_tpr_priv + (1-total_fpr_priv))/2
bal_acc_unpriv = (total_tpr_unpriv + (1-total_fpr_unpriv))/2
bal_acc_overall = (total_tpr + (1-total_fpr))/2

bal_acc_priv_m = np.mean(bal_acc_priv, -1)
bal_acc_priv_s = np.std(bal_acc_priv, -1)
bal_acc_unpriv_m = np.mean(bal_acc_unpriv, -1)
bal_acc_unpriv_s = np.std(bal_acc_unpriv, -1)
bal_acc_diff_m = abs(bal_acc_priv_m - bal_acc_unpriv_m)
bal_acc_diff_s = np.std(total_acc_priv - bal_acc_unpriv, -1)
bal_acc_overall_m = np.mean(bal_acc_overall, -1)
bal_acc_overall_s = np.std(bal_acc_overall, -1)


acc_priv_m = np.mean(total_acc_priv, -1)
acc_priv_s = np.std(total_acc_priv, -1)
acc_unpriv_m = np.mean(total_acc_unpriv, -1)
acc_unpriv_s = np.std(total_acc_unpriv, -1)
acc_diff_m = abs(acc_priv_m - acc_unpriv_m)
acc_diff_s = np.std(total_acc_priv - total_acc_unpriv, -1)

# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[1], acc_priv_s[1], acc_unpriv_m[1], acc_unpriv_s[1],acc_diff_m[1], acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[2], acc_priv_s[2], acc_unpriv_m[2], acc_unpriv_s[2],acc_diff_m[2], acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(acc_priv_m[3], acc_priv_s[3], acc_unpriv_m[3], acc_unpriv_s[3],acc_diff_m[3], acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[5], acc_priv_s[5], acc_unpriv_m[5], acc_unpriv_s[5],acc_diff_m[5], acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(acc_priv_m[6], acc_priv_s[6], acc_unpriv_m[6], acc_unpriv_s[6],acc_diff_m[6], acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[7], acc_priv_s[7], acc_unpriv_m[7], acc_unpriv_s[7],acc_diff_m[7], acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#         .format(acc_priv_m[9], acc_priv_s[9], acc_unpriv_m[9], acc_unpriv_s[9],acc_diff_m[9], acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|===}}'\
#     .format(acc_priv_m[0], acc_priv_s[0], acc_unpriv_m[0], acc_unpriv_s[0],acc_diff_m[0], acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(acc_priv_m[10], acc_priv_s[10], acc_unpriv_m[10], acc_unpriv_s[10],acc_diff_m[10], acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))


# print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
# print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
# print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#           .format(bal_acc_overall_m[3], bal_acc_overall_m[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
# print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[5], bal_acc_overall_m[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
# print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[6], bal_acc_overall_m[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
# print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[7], bal_acc_overall_m[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
# print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
#     .format(bal_acc_overall_m[10], bal_acc_overall_m[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
# print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
#         .format(bal_acc_overall_m[9], bal_acc_overall_m[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# print('Ours_w \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
#     .format(bal_acc_overall_m[0], bal_acc_overall_m[0],bal_acc_diff_m[0], bal_acc_diff_s[0], m1[0], s1[0], m2[0], s2[0], m3[0], s3[0]))
# Out:
# Meps
# AdvDeb 		 & 0.320 $\pm$ 0.028 	 & 0.377 $\pm$ 0.040 	 & 0.058 $\pm$ 0.012  \\
# CEOPost 	 & 0.263 $\pm$ 0.004 	 & 0.178 $\pm$ 0.010 	 & 0.085 $\pm$ 0.014  \\
# DIR 		 & 0.672 $\pm$ 0.004 	 & 0.787 $\pm$ 0.029 	 & 0.115 $\pm$ 0.033  \\
# Meta 		 & 0.738 $\pm$ 0.028 	 & 0.868 $\pm$ 0.018 	 & 0.130 $\pm$ 0.043  \\ \hhline{=|===}
# ReW 		 & 0.585 $\pm$ 0.001 	 & 0.768 $\pm$ 0.021 	 & 0.183 $\pm$ 0.019  \\
# RejOpt 		 & 0.708 $\pm$ 0.017 	 & 0.626 $\pm$ 0.014 	 & 0.082 $\pm$ 0.003  \\ \hhline{=|===}
# Ours 		 & 0.705 $\pm$ 0.065 	 & 0.634 $\pm$ 0.058 	 & 0.071 $\pm$ 0.012  \\ \hhline{=|===}
# Ours_w 		 & 0.746 $\pm$ 0.021 	 & 0.665 $\pm$ 0.039 	 & 0.080 $\pm$ 0.024  \\ \hhline{=|===}
# Baseline 	 & 0.768 $\pm$ 0.096 	 & 0.662 $\pm$ 0.095 	 & 0.107 $\pm$ 0.009  \\ \hline

# %%
print('AdvDeb \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[1], bal_acc_overall_s[1],bal_acc_diff_m[1], bal_acc_diff_s[1], m1[1], s1[1], m2[1], s2[1], m3[1], s3[1]))
print('CEOPost \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[2], bal_acc_overall_s[2],bal_acc_diff_m[2], bal_acc_diff_s[2], m1[2], s1[2], m2[2], s2[2], m3[2], s3[2]))
print('DIR \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
          .format(bal_acc_overall_m[3], bal_acc_overall_s[3],bal_acc_diff_m[3], bal_acc_diff_s[3], m1[3], s1[3], m2[3], s2[3], m3[3], s3[3]))
print('MFC \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[5], bal_acc_overall_s[5],bal_acc_diff_m[5], bal_acc_diff_s[5], m1[5], s1[5], m2[5], s2[5], m3[5], s3[5]))
print('ReW \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[6], bal_acc_overall_s[6],bal_acc_diff_m[6], bal_acc_diff_s[6], m1[6], s1[6], m2[6], s2[6], m3[6], s3[6]))
print('RejOpt \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ '\
        .format(bal_acc_overall_m[7], bal_acc_overall_s[7],bal_acc_diff_m[7], bal_acc_diff_s[7], m1[7], s1[7], m2[7], s2[7], m3[7], s3[7]))
print('Baseline \t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hhline{{=|======}}'\
    .format(bal_acc_overall_m[10], bal_acc_overall_s[10],bal_acc_diff_m[10], bal_acc_diff_s[10], m1[10], s1[10], m2[10], s2[10], m3[10], s3[10]))
print('Ours \t\t & {:.3f} $\pm$ {:.3f} \t &  {:.3f} $\pm$ {:.3f} \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \t & {:.3f} $\pm$ {:.3f}  \\\ \hline'\
        .format(bal_acc_overall_m[9], bal_acc_overall_s[9],bal_acc_diff_m[9], bal_acc_diff_s[9], m1[9], s1[9], m2[9], s2[9], m3[9], s3[9]))
# Out:
# AdvDeb 		 & 0.655 $\pm$ 0.015 	 &  0.007 $\pm$ 0.017 	 & 0.320 $\pm$ 0.028  	 & 0.377 $\pm$ 0.040  	 & 0.058 $\pm$ 0.012  \\
# CEOPost 	 & 0.587 $\pm$ 0.001 	 &  0.047 $\pm$ 0.004 	 & 0.263 $\pm$ 0.004  	 & 0.178 $\pm$ 0.010  	 & 0.085 $\pm$ 0.014  \\
# DIR 		 & 0.763 $\pm$ 0.003 	 &  0.014 $\pm$ 0.018 	 & 0.672 $\pm$ 0.004  	 & 0.787 $\pm$ 0.029  	 & 0.115 $\pm$ 0.033  \\
# MFC 		 & 0.755 $\pm$ 0.006 	 &  0.070 $\pm$ 0.032 	 & 0.738 $\pm$ 0.028  	 & 0.868 $\pm$ 0.018  	 & 0.130 $\pm$ 0.043  \\
# ReW 		 & 0.752 $\pm$ 0.004 	 &  0.015 $\pm$ 0.007 	 & 0.585 $\pm$ 0.001  	 & 0.768 $\pm$ 0.021  	 & 0.183 $\pm$ 0.019  \\
# RejOpt 		 & 0.733 $\pm$ 0.005 	 &  0.034 $\pm$ 0.004 	 & 0.708 $\pm$ 0.017  	 & 0.626 $\pm$ 0.014  	 & 0.082 $\pm$ 0.003  \\
# Baseline 	 & 0.746 $\pm$ 0.025 	 &  0.003 $\pm$ 0.051 	 & 0.768 $\pm$ 0.096  	 & 0.662 $\pm$ 0.095  	 & 0.107 $\pm$ 0.009  \\ \hhline{=|======}
# ...

# %%
dataset_used = 'adult'

# %%
protected_attribute_used = 1

if dataset_used == "adult":
    dataset = AdultDataset()
    # #dataset = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "german":
    dataset = GermanDataset()
    dataset.labels = dataset.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif dataset_used == "compas":
    dataset = CompasDataset()
    # #dataset = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif dataset_used == "bank":
    dataset = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif dataset_used == "meps":
    dataset = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

sens_idx = dataset.feature_names.index(sens_attr)

P_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 1)
N_unpriv = sum(dataset.labels[dataset.features[:, sens_idx] == 0] == 0)

P_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 1)
N_priv = sum(dataset.labels[dataset.features[:, sens_idx] == 1] == 0)

P_Y1_A1 = P_priv/(P_priv + N_priv)
P_Y1_A0 = P_unpriv/(P_unpriv + N_unpriv)
# Out:
# WARNING:root:Missing Data: 3620 rows removed from AdultDataset.

# %%
total_tpr = np.load('../AIF360/examples/result_data/{}/total_tpr.npy'.format(dataset_used))
total_tpr_priv = np.load('../AIF360/examples/result_data/{}/total_tpr_priv.npy'.format(dataset_used))
total_tpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_tpr_unpriv.npy'.format(dataset_used))
total_eqopp_diff = np.load('../AIF360/examples/result_data/{}/total_eqopp_diff.npy'.format(dataset_used))

total_fpr = np.load('../AIF360/examples/result_data/{}/total_fpr.npy'.format(dataset_used))
total_fpr_priv = np.load('../AIF360/examples/result_data/{}/total_fpr_priv.npy'.format(dataset_used))
total_fpr_unpriv = np.load('../AIF360/examples/result_data/{}/total_fpr_unpriv.npy'.format(dataset_used))
total_fpr_diff = np.load('../AIF360/examples/result_data/{}/total_fpr_diff.npy'.format(dataset_used))

total_acc = np.load('../AIF360/examples/result_data/{}/total_acc.npy'.format(dataset_used))
total_acc_priv = np.load('../AIF360/examples/result_data/{}/total_acc_priv.npy'.format(dataset_used))
total_acc_unpriv = np.load('../AIF360/examples/result_data/{}/total_acc_unpriv.npy'.format(dataset_used))
# abs(total_acc_unpriv - total_acc_priv) = np.load('../AIF360/examples/result_data/{}/total_acc_diff.npy'.format(dataset_used))

total_balanced_acc = np.load('../AIF360/examples/result_data/{}/total_balanced_acc.npy'.format(dataset_used))
total_disimpact = np.load('../AIF360/examples/result_data/{}/total_disimpact.npy'.format(dataset_used))
total_theil_idx = np.load('../AIF360/examples/result_data/{}/total_theil_idx.npy'.format(dataset_used))
stat_parity_diff = np.load('../AIF360/examples/result_data/{}/stat_parity_diff.npy'.format(dataset_used))

# %%
setting = 'best/' + dataset_used + '/' 
plot(total_acc, 0, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [1,2,3,6,7,9])
plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [1,2,3,6,7,9])
