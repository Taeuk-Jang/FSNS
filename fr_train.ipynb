# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
import numpy as np
import math

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch
import torch.utils.data as data

import math
import matplotlib.pyplot as plt

from argparse import Namespace

from fr_train import Generator, DiscriminatorF, DiscriminatorR, weights_init_normal, test_model
import pickle
import warnings
warnings.filterwarnings("ignore")

from aif360.datasets import AdultDataset, GermanDataset, BankDataset, CompasDataset, BinaryLabelDataset, CelebADataset
from aif360.metrics import ClassificationMetric
import pandas

from sklearn.preprocessing import scale, StandardScaler, MaxAbsScaler

min_max_scaler = MaxAbsScaler()
std_scaler = StandardScaler()

# %%
def train_model(train_tensors, val_tensors, test_tensors, train_opt, lambda_f, lambda_r, seed):
    """
      Trains FR-Train by using the classes in FRTrain_arch.py.
      
      Args:
        train_tensors: Training data.
        val_tensors: Clean validation data.
        test_tensors: Test data.
        train_opt: Options for the training. It currently contains size of validation set, 
                number of epochs, generator/discriminator update ratio, and learning rates.
        lambda_f: The tuning knob for L_2 (ref: FR-Train paper, Section 3.3).
        lambda_r: The tuning knob for L_3 (ref: FR-Train paper, Section 3.3).
        seed: An integer value for specifying torch random seed.
        
      Returns:
        Information about the tuning knobs (lambda_f, lambda_r),
        the test accuracy of the trained model, and disparate impact of the trained model.
    """
    
    XS_train = train_tensors.XS_train
    y_train = train_tensors.y_train
    s1_train = train_tensors.s1_train
    
    XS_val = val_tensors.XS_val
    y_val = val_tensors.y_val
    s1_val = val_tensors.s1_val
    
    XS_test = test_tensors.XS_test
    y_test = test_tensors.y_test
    s1_test = test_tensors.s1_test
    
    # Saves return values here
    test_result = [] 
    
    val = train_opt.val # Number of data points in validation set
    k = train_opt.k     # Update ratio of generator and discriminator (1:k training).
    n_epochs = train_opt.n_epochs  # Number of training epoch
    
    # Changes the input validation data to an appropriate shape for the training
    XSY_val = torch.cat([XS_val, y_val.reshape((y_val.shape[0], 1))], dim=1)  

    # The loss values of each component will be saved in the following lists. 
    # We can draw epoch-loss graph by the following lists, if necessary.
    g_losses =[]
    d_f_losses = []
    d_r_losses = []
    clean_test_result = []

    bce_loss = torch.nn.BCELoss()

    # Initializes generator and discriminator
    generator = Generator(input_size, latent_size)
    discriminator_F = DiscriminatorF()
    discriminator_R = DiscriminatorR(input_size, latent_size)

    # Initializes weights
    torch.manual_seed(seed)
    generator.apply(weights_init_normal)
    discriminator_F.apply(weights_init_normal)
    discriminator_R.apply(weights_init_normal)

    optimizer_G = torch.optim.Adam(generator.parameters(), lr=train_opt.lr_g)
    optimizer_D_F = torch.optim.SGD(discriminator_F.parameters(), lr=train_opt.lr_f)
    optimizer_D_R = torch.optim.SGD(discriminator_R.parameters(), lr=train_opt.lr_r)

    XSY_val_data = XSY_val[:val]

    train_len = XS_train.shape[0]
    val_len = XSY_val.shape[0]

    # Ground truths using in Disriminator_R
    Tensor = torch.FloatTensor
    valid = Variable(Tensor(train_len, 1).fill_(1.0), requires_grad=False)
    generated = Variable(Tensor(train_len, 1).fill_(0.0), requires_grad=False)
    fake = Variable(Tensor(train_len, 1).fill_(0.0), requires_grad=False)
    clean = Variable(Tensor(val_len, 1).fill_(1.0), requires_grad=False)
    

    r_weight = torch.ones_like(y_train, requires_grad=False).float()
    r_ones = torch.ones_like(y_train, requires_grad=False).float()

    for epoch in range(n_epochs):

        # -------------------
        #  Forwards Generator
        # -------------------
        if epoch % k == 0 or epoch < 500:
            optimizer_G.zero_grad()

        gen_y = generator(XS_train)
        gen_data = torch.cat([XS_train, gen_y.reshape((gen_y.shape[0], 1))], dim=1)


        # -------------------------------
        #  Trains Fairness Discriminator
        # -------------------------------

        optimizer_D_F.zero_grad()
        
        # Discriminator_F tries to distinguish the sensitive groups by using the output of the generator.
        d_f_loss = bce_loss(discriminator_F(gen_y.detach()), s1_train)
        d_f_loss.backward()
        d_f_losses.append(d_f_loss)
        optimizer_D_F.step()
            
            
        # ---------------------------------
        #  Trains Robustness Discriminator
        # ---------------------------------

        optimizer_D_R.zero_grad()

        # Discriminator_R tries to distinguish whether the input is from the validation data or the generated data from generator.
        clean_loss =  bce_loss(discriminator_R(XSY_val_data), clean)
        poison_loss = bce_loss(discriminator_R(gen_data.detach()), fake)
        d_r_loss = 0.5 * (clean_loss + poison_loss)

        d_r_loss.backward()
        d_r_losses.append(d_r_loss)
        optimizer_D_R.step()

        
        # ---------------------
        #  Updates Generator
        # ---------------------


        if epoch < 500 :
            g_loss = 0.1 * bce_loss((F.tanh(gen_y)+1)/2, (y_train+1)/2)
            g_loss.backward()
            g_losses.append(g_loss)
            optimizer_G.step()
        elif epoch % k == 0:
            r_decision = discriminator_R(gen_data)
            r_gen = bce_loss(r_decision, generated)
            
            # ---------------------------------
            #  Re-weights using output of D_R
            # ---------------------------------
            if epoch % 100 == 0:
                loss_ratio = (g_losses[-1]/d_r_losses[-1]).detach()
                a = 1/(1+torch.exp(-(loss_ratio-3)))
                b = 1-a
                r_weight_tmp = r_decision.detach().squeeze()
                r_weight = a * r_weight_tmp + b * r_ones

            f_cost = F.binary_cross_entropy(discriminator_F(gen_y), s1_train, reduction="none").squeeze()
            g_cost = F.binary_cross_entropy_with_logits(gen_y.squeeze(), (y_train.squeeze()+1)/2, reduction="none").squeeze()

            f_gen = torch.mean(f_cost*r_weight)
            g_loss = (1-lambda_f-lambda_r) * torch.mean(g_cost*r_weight) - lambda_f * f_gen -  lambda_r * r_gen 

            g_loss.backward()
            optimizer_G.step()


        g_losses.append(g_loss)

        if epoch % 200 == 0:
            print(
                    "[Lambda: %1f] [Epoch %d/%d] [D_F loss: %f] [D_R loss: %f] [G loss: %f]"
                    % (lambda_f, epoch, n_epochs, d_f_losses[-1], d_r_losses[-1], g_losses[-1])
                )

#     torch.save(generator.state_dict(), './FR-Train_on_poi_synthetic.pth')
    tmp = test_model(generator, XS_test, y_test, s1_test)
    test_result.append([lambda_f, lambda_r, tmp[0].item(), tmp[1]])
    
    
    
    # TEST
    tp_priv, tn_priv, fp_priv, fn_priv, \
    tp_unpriv, tn_unpriv, fp_unpriv, fn_unpriv = 0, 0, 0, 0, 0, 0, 0, 0

    gen_y = generator(XS_train)
    
    priv_idx = (s1_test==1).squeeze()
    positive_idx = y_val==1

    latent_val = (H(x_val))
    pred_test = W(latent_val)

    h_priv = (H(x_val[priv_idx]))
    h_unpriv = (H(x_val[~priv_idx]))

    h_positive = (H(x_val[positive_idx]))

    test_lb_priv = y_val[priv_idx]
    test_lb_unpriv = y_val[~priv_idx]

    pred_priv = W(h_priv)
    pred_unpriv = W(h_unpriv)

    y_val = y_val.cpu().detach().numpy()
    test_lb_priv = test_lb_priv.cpu().detach().numpy()
    test_lb_unpriv = test_lb_unpriv.cpu().detach().numpy()

    try:
        pred_priv = pred_priv.argmax(1)
    except:
        pass
    try:
        pred_unpriv = pred_unpriv.argmax(1)
    except:
        pass


    tp_priv += sum(pred_priv[test_lb_priv == 1] == 1)
    fp_priv += sum(pred_priv[test_lb_priv == 0] == 1)
    tn_priv += sum(pred_priv[test_lb_priv == 0] == 0)
    fn_priv += sum(pred_priv[test_lb_priv == 1] == 0)

    tp_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 1)
    fp_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 1)
    tn_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 0)
    fn_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 0)

    tpr_overall = (tp_priv + tp_unpriv)/(tp_priv + tp_unpriv + fn_priv + fn_unpriv).float().item()
    tpr_priv = (tp_unpriv)/(tp_unpriv + fn_unpriv).float().item()
    tpr_unpriv = (tp_priv)/(tp_priv + fn_priv).float().item()

    fpr_overall = (fp_priv + fp_unpriv)/(tn_priv + tn_unpriv + fp_priv + fp_unpriv).float().item()
    fpr_unpriv = (fp_unpriv)/(tn_unpriv + fp_unpriv).float().item()
    fpr_priv = (fp_priv)/(tn_priv + fp_priv).float().item()

    acc_overall = (tp_priv + tn_priv + tp_unpriv + tn_unpriv)/(tp_priv + tn_priv + tp_unpriv + tn_unpriv + \
                                                              fp_priv + fn_priv + fp_unpriv + fn_unpriv).float().item()
    acc_priv = (tp_priv + tn_priv)/(tp_priv + tn_priv + fp_priv + fn_priv).float().item()
    acc_unpriv = (tp_unpriv + tn_unpriv)/(tp_unpriv + tn_unpriv + fp_unpriv + fn_unpriv).float().item()


    print()
    print('overall TPR : {0:.3f}'.format( tpr_overall))
    print('priv TPR : {0:.3f}'.format( tpr_priv))
    print('unpriv TPR : {0:.3f}'.format( tpr_unpriv))
    print('Eq. Opp : {0:.3f}'.format( abs(tpr_unpriv - tpr_priv)))
    print()
    print('overall FPR : {0:.3f}'.format( fpr_overall))
    print('priv FPR : {0:.3f}'.format( fpr_priv))
    print('unpriv FPR : {0:.3f}'.format( fpr_unpriv))
    print('diff FPR : {0:.3f}'.format( abs(fpr_unpriv-fpr_priv)))
    print()
    print('overall ACC : {0:.3f}'.format( acc_overall))
    print('priv ACC : {0:.3f}'.format( acc_priv))
    print('unpriv ACC : {0:.3f}'.format( acc_unpriv)) 
    print('diff ACC : {0:.3f}\n\n\n'.format( abs(acc_unpriv-acc_priv)))

    valid_pred = data_valid.copy(deepcopy=True)
    feature_size = valid_pred.features.shape[1]
    sens_loc = np.zeros(feature_size).astype(bool)
    sens_loc[sens_idx] = 1

    feature = valid_pred.features[:,~sens_loc] #data without sensitive
    feature = min_max_scaler.fit_transform(feature)

    valid_pred.labels = W((H(torch.tensor(feature).to(device)))).argmax(-1).cpu().numpy().reshape(-1,1)

    classified_metric = ClassificationMetric(data_valid,
                                                     valid_pred,
                                                     unprivileged_groups=unprivileged_groups,
                                                     privileged_groups=privileged_groups)


    print('balanced acc :' ,1/2*(classified_metric.true_positive_rate() + classified_metric.true_negative_rate()))
    print('disparate_impact :' ,classified_metric.disparate_impact())
    print('theil_index :' ,classified_metric.theil_index())
    print('statistical_parity_difference :' ,classified_metric.statistical_parity_difference())
    print('generalized_entropy_index : ', classified_metric.generalized_entropy_index())

    return test_result

# %%
np.random.seed(0)
#dataset = {'adult' : AdultDataset(), 'german' : GermanDataset(),'bank': BankDataset(),'compas' : CompasDataset(),'celeb': CelebADataset()}
dataset = {'adult' : AdultDataset(), 'german' : GermanDataset(),'bank': BankDataset(),'compas' : CompasDataset()}
dataset['german'].labels -= 1
sens_attr_dict = {'adult': ['sex', 'race'], 'german' : ['sex', 'age'], 'compas' : ['sex', 'race'], 'bank' : ['age'], 'celeb' : ['gender']}
# Out:
# WARNING:root:Missing Data: 3620 rows removed from AdultDataset.
# WARNING:root:Missing Data: 10700 rows removed from BankDataset.
# WARNING:root:Missing Data: 5 rows removed from CompasDataset.

# %%
data_name = 'adult'
protected_attribute_used = 1

# %%
if data_name == "adult":
    #dataset_orig = AdultDataset()
    # #dataset_orig = load_preproc_data_adult()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif data_name == "german":
    #dataset_orig = GermanDataset()
    # #dataset_orig.labels = #dataset_orig.labels-1
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'

elif data_name == "compas":
    #dataset_orig = CompasDataset()
    # #dataset_orig = load_preproc_data_compas()
    if protected_attribute_used == 1:
        privileged_groups = [{'sex': 1}]
        unprivileged_groups = [{'sex': 0}]
        sens_attr = 'sex'
    else:
        privileged_groups = [{'race': 1}]
        unprivileged_groups = [{'race': 0}]
        sens_attr = 'race'

elif data_name == "bank":
    #dataset_orig = BankDataset()
    if protected_attribute_used == 1:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
    else:
        privileged_groups = [{'age': 1}]
        unprivileged_groups = [{'age': 0}]
        sens_attr = 'age'
        
elif data_name == "meps":
    #dataset_orig = MEPSDataset19()
    privileged_groups = [{'RACE': 1}]
    unprivileged_groups = [{'RACE': 0}]
    sens_attr = 'RACE'

# %%
min_max_scaler = MaxAbsScaler()
std_scaler = StandardScaler()

# %%
sens_idx = dataset[data_name].feature_names.index(sens_attr)
num_sens = len(np.unique(dataset[data_name].features[:, sens_idx]))

#bs = 4000
workers = 16
device = 'cuda:2'
os.environ['CUDA_VISIBLE_DEVICES']='2'
hist = {'loss':[], 'acc':[], 'val_loss':[], 'val_acc':[]}


feature_size = dataset[data_name].features.shape[1]
sens_loc = np.zeros(feature_size).astype(bool)
sens_loc[sens_idx] = 1

feature = dataset[data_name].features[:,~sens_loc] #data without sensitive
feature = min_max_scaler.fit_transform(feature)
# feature = std_scaler.fit_transform(feature)
dataset[data_name].features[:,~sens_loc] = feature

#self.sensitive = dataset[data_name].features[:,sens_loc].reshape(-1).astype(int)
#n_values = int(np.max(self.label) + 1)
#self.label = np.eye(n_values)[self.label.astype(int)].squeeze(1)
# dataset[data_name], _ = dataset[data_name].split([0.5], shuffle=True)
data_train, data_vt = dataset[data_name].split([0.7], shuffle=True)
data_valid, data_test = data_vt.split([0.5], shuffle=True)

# %%
sens_attr
# Out:
# 'sex'

# %%
class Dataset(data.Dataset):
    def __init__(self, X, s, y):
        self.label = y
        self.feature = torch.cat([X, s], dim = 1)
        self.sensitive = s
        
    def __getitem__(self, idx):
        y = self.label[idx]
        x = self.feature[idx]
        a = self.sensitive[idx]
        
        return x, a, y
    
    def __len__(self):
        return len(self.label)

# %% [markdown]
# #### Poisoning

# %%
idx = np.where(data_train.features[:, sens_idx] == 1)[0]
poison_idx = np.random.permutation(idx)[:int(len(idx)/10)]

#label poisoning
data_train.labels[poison_idx] = 1 - data_train.labels[poison_idx]

# %%
# a namespace object which contains some of the hyperparameters
opt = Namespace(num_train=2000, num_val1=200, num_val2=500, num_test=1000)

# num_train = opt.num_train
# num_val1 = opt.num_val1
# num_val2 = opt.num_val2
# num_test = opt.num_test

# X = np.load('X_synthetic.npy') # Input features
# y = np.load('y_synthetic.npy') # Original labels
# y_poi = np.load('y_poi.npy') # Poisoned train labels
# s1 = np.load('s1_synthetic.npy') # Sensitive features

# %%
X_train = torch.FloatTensor(data_train.features[:, ~sens_loc])
y_train = torch.FloatTensor(data_train.labels)
s1_train = torch.FloatTensor(data_train.features[:, sens_idx]).view(-1,1)

X_val = torch.FloatTensor(data_valid.features[:, ~sens_loc])
y_val = torch.FloatTensor(data_valid.labels)
s1_val = torch.FloatTensor(data_valid.features[:, sens_idx]).view(-1,1)

X_test = torch.FloatTensor(data_test.features[:, ~sens_loc])
y_test = torch.FloatTensor(data_test.labels)
s1_test = torch.FloatTensor(data_test.features[:, sens_idx]).view(-1,1)

# %%
XS_train = torch.cat([X_train, s1_train.reshape((s1_train.shape[0], 1))], dim=1)
XS_val = torch.cat([X_val, s1_val.reshape((s1_val.shape[0], 1))], dim=1)
XS_test = torch.cat([X_test, s1_test.reshape((s1_test.shape[0], 1))], dim=1)

# %%
data_train = Dataset(X_train, s1_train, y_train)
data_valid = Dataset(X_val, s1_val, y_val)
data_test = Dataset(X_test, s1_test, y_test)

trainloader = torch.utils.data.DataLoader(
    data_train,
    batch_size=128,
    shuffle=True,
    )
validloader = torch.utils.data.DataLoader(
    data_valid,
    batch_size=128,
    shuffle=True,
    drop_last = True
    )
testloader = torch.utils.data.DataLoader(
    data_test,
    batch_size=128,
    shuffle=True,
    drop_last = True
    )

# %%
input_size = XS_train.shape[-1]
latent_size = 512
hidden_size = 512

# %%
#COMPAS setup
results_dict = {}

for poi_ratio in np.linspace(0.1, 0.5, 5):
    results_dict[poi_ratio] = {}
    results_dict[poi_ratio]['EqOdds'] =[]
    results_dict[poi_ratio]['Acc'] = []
    results_dict[poi_ratio]['DISP'] = []
    results_dict[poi_ratio]['EqOpp']= []
    results_dict[poi_ratio]['Acc_diff'] = []

    results_dict[poi_ratio]['total_tpr'] =[]
    results_dict[poi_ratio]['total_fpr'] =[]

    results_dict[poi_ratio]['total_tpr_priv'] =[]
    results_dict[poi_ratio]['total_tpr_unpriv'] =[]
    results_dict[poi_ratio]['total_fpr_priv'] =[]
    results_dict[poi_ratio]['total_fpr_unpriv'] =[]
    
    for repeat in range(5):
        data_train, data_vt = dataset[data_name].split([0.7], shuffle=True)
        data_valid, data_test = data_vt.split([0.5], shuffle=True)

        idx = np.where(data_train.features[:, sens_idx] == 1)[0]
        poison_idx = np.random.permutation(idx)[:int(len(idx) * poi_ratio)]

        #label poisoning
        data_train.labels[poison_idx] = 1 - data_train.labels[poison_idx]

        X_train = torch.FloatTensor(data_train.features[:, ~sens_loc])
        y_train = torch.FloatTensor(data_train.labels)
        s1_train = torch.FloatTensor(data_train.features[:, sens_idx]).view(-1,1)

        X_val = torch.FloatTensor(data_valid.features[:, ~sens_loc])
        y_val = torch.FloatTensor(data_valid.labels)
        s1_val = torch.FloatTensor(data_valid.features[:, sens_idx]).view(-1,1)

        X_test = torch.FloatTensor(data_test.features[:, ~sens_loc])
        y_test = torch.FloatTensor(data_test.labels)
        s1_test = torch.FloatTensor(data_test.features[:, sens_idx]).view(-1,1)

        XS_train = torch.cat([X_train, s1_train.reshape((s1_train.shape[0], 1))], dim=1)
        XS_val = torch.cat([X_val, s1_val.reshape((s1_val.shape[0], 1))], dim=1)
        XS_test = torch.cat([X_test, s1_test.reshape((s1_test.shape[0], 1))], dim=1)

        train_result = []
        train_tensors = Namespace(XS_train = XS_train, y_train = y_train, s1_train = s1_train)
        val_tensors = Namespace(XS_val = XS_val, y_val = y_val, s1_val = s1_val) 
        test_tensors = Namespace(XS_test = XS_test, y_test = y_test, s1_test = s1_test)

        train_opt = Namespace(val=len(y_val), n_epochs=50, k=1, lr_g=1e-3, lr_f=1e-4, lr_r=1e-4)
        seed = 1

        lambda_f_set = [0.1] # Lambda value for the fairness discriminator of FR-Train.
        lambda_r = 0.1 # Lambda value for the robustness discriminator of FR-Train.

        data_train = Dataset(X_train, s1_train, y_train)
        data_valid = Dataset(X_val, s1_val, y_val)
        data_test = Dataset(X_test, s1_test, y_test)

        trainloader = torch.utils.data.DataLoader(
            data_train,
            batch_size=128,
            shuffle=True,
            )
        validloader = torch.utils.data.DataLoader(
            data_valid,
            batch_size=128,
            shuffle=True,
            drop_last = True
            )
        testloader = torch.utils.data.DataLoader(
            data_test,
            batch_size=128,
            shuffle=True,
            drop_last = True
            )


        for lambda_f in lambda_f_set:
            train_model_adult(results_dict[poi_ratio], train_tensors, val_tensors, test_tensors, train_opt, lambda_f = lambda_f, lambda_r = lambda_r, seed = seed)
# Out:
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.579390] [D_R loss: 0.224440] [G loss: 31.413197]
# VALID DATA
# overall TPR : 0.005
# priv TPR : 0.000
# unpriv TPR : 0.017
# Eq. Opp : 0.017
#
# overall FPR : 0.010
# priv FPR : 0.021
# unpriv FPR : 0.003
# diff FPR : 0.018
#
# overall ACC : 0.533
# priv ACC : 0.608
# unpriv ACC : 0.495
# diff ACC : 0.113
#
#
#
# TEST DATA
# overall TPR : 0.010
# priv TPR : 0.003
# unpriv TPR : 0.031
# Eq. Opp : 0.027
#
# overall FPR : 0.010
# priv FPR : 0.021
# unpriv FPR : 0.003
# diff FPR : 0.018
#
# overall ACC : 0.552
# priv ACC : 0.655
# unpriv ACC : 0.504
# diff ACC : 0.151
#
#
#
# DIMP : 0.135
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.649528] [D_R loss: 0.812184] [G loss: 3.676873]
# VALID DATA
# overall TPR : 0.494
# priv TPR : 0.532
# unpriv TPR : 0.397
# Eq. Opp : 0.136
#
# overall FPR : 0.313
# priv FPR : 0.291
# unpriv FPR : 0.328
# diff FPR : 0.037
#
# overall ACC : 0.598
# priv ACC : 0.590
# unpriv ACC : 0.602
# diff ACC : 0.012
#
#
#
# TEST DATA
# overall TPR : 0.519
# priv TPR : 0.545
# unpriv TPR : 0.440
# Eq. Opp : 0.105
#
# overall FPR : 0.253
# priv FPR : 0.209
# unpriv FPR : 0.279
# diff FPR : 0.071
#
# overall ACC : 0.645
# priv ACC : 0.669
# unpriv ACC : 0.634
# diff ACC : 0.035
#
#
#
# DIMP : 0.704
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.684892] [D_R loss: 0.691385] [G loss: 0.379192]
# VALID DATA
# overall TPR : 0.554
# priv TPR : 0.561
# unpriv TPR : 0.535
# Eq. Opp : 0.026
#
# overall FPR : 0.377
# priv FPR : 0.432
# unpriv FPR : 0.340
# diff FPR : 0.092
#
# overall ACC : 0.592
# priv ACC : 0.556
# unpriv ACC : 0.610
# diff ACC : 0.055
#
#
#
# TEST DATA
# overall TPR : 0.558
# priv TPR : 0.577
# unpriv TPR : 0.500
# Eq. Opp : 0.077
#
# overall FPR : 0.314
# priv FPR : 0.371
# unpriv FPR : 0.279
# diff FPR : 0.092
#
# overall ACC : 0.628
# priv ACC : 0.584
# unpriv ACC : 0.649
# diff ACC : 0.065
#
#
#
# DIMP : 0.972
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.685701] [D_R loss: 0.870841] [G loss: 0.914287]
# VALID DATA
# overall TPR : 0.604
# priv TPR : 0.622
# unpriv TPR : 0.557
# Eq. Opp : 0.066
#
# overall FPR : 0.398
# priv FPR : 0.469
# unpriv FPR : 0.353
# diff FPR : 0.116
#
# overall ACC : 0.603
# priv ACC : 0.541
# unpriv ACC : 0.635
# diff ACC : 0.094
#
#
#
# TEST DATA
# overall TPR : 0.585
# priv TPR : 0.603
# unpriv TPR : 0.526
# Eq. Opp : 0.076
#
# overall FPR : 0.348
# priv FPR : 0.438
# unpriv FPR : 0.291
# diff FPR : 0.146
#
# overall ACC : 0.622
# priv ACC : 0.551
# unpriv ACC : 0.655
# diff ACC : 0.105
#
#
#
# DIMP : 0.960
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.687091] [D_R loss: 0.682078] [G loss: 1.083838]
# VALID DATA
# overall TPR : 0.611
# priv TPR : 0.639
# unpriv TPR : 0.538
# Eq. Opp : 0.101
#
# overall FPR : 0.404
# priv FPR : 0.407
# unpriv FPR : 0.402
# diff FPR : 0.005
#
# overall ACC : 0.603
# priv ACC : 0.572
# unpriv ACC : 0.619
# diff ACC : 0.046
#
#
#
# TEST DATA
# overall TPR : 0.617
# priv TPR : 0.635
# unpriv TPR : 0.560
# Eq. Opp : 0.075
#
# overall FPR : 0.372
# priv FPR : 0.400
# unpriv FPR : 0.355
# diff FPR : 0.045
#
# overall ACC : 0.623
# priv ACC : 0.586
# unpriv ACC : 0.640
# diff ACC : 0.054
#
#
#
# DIMP : 0.923
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.667748] [D_R loss: 0.580634] [G loss: 0.224531]
# VALID DATA
# overall TPR : 0.236
# priv TPR : 0.246
# unpriv TPR : 0.214
# Eq. Opp : 0.033
#
# overall FPR : 0.135
# priv FPR : 0.137
# unpriv FPR : 0.134
# diff FPR : 0.002
#
# overall ACC : 0.574
# priv ACC : 0.592
# unpriv ACC : 0.564
# diff ACC : 0.029
#
#
#
# TEST DATA
# overall TPR : 0.245
# priv TPR : 0.222
# unpriv TPR : 0.311
# Eq. Opp : 0.089
#
# overall FPR : 0.145
# priv FPR : 0.140
# unpriv FPR : 0.148
# diff FPR : 0.008
#
# overall ACC : 0.575
# priv ACC : 0.661
# unpriv ACC : 0.533
# diff ACC : 0.128
#
#
#
# DIMP : 0.918
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.685725] [D_R loss: 1.123247] [G loss: 0.234605]
# VALID DATA
# overall TPR : 0.530
# priv TPR : 0.535
# unpriv TPR : 0.519
# Eq. Opp : 0.017
#
# overall FPR : 0.374
# priv FPR : 0.489
# unpriv FPR : 0.303
# diff FPR : 0.186
#
# overall ACC : 0.581
# priv ACC : 0.514
# unpriv ACC : 0.618
# diff ACC : 0.104
#
#
#
# TEST DATA
# overall TPR : 0.472
# priv TPR : 0.455
# unpriv TPR : 0.525
# Eq. Opp : 0.070
#
# overall FPR : 0.366
# priv FPR : 0.449
# unpriv FPR : 0.315
# diff FPR : 0.134
#
# overall ACC : 0.560
# priv ACC : 0.542
# unpriv ACC : 0.569
# diff ACC : 0.027
#
#
#
# DIMP : 0.810
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.690550] [D_R loss: 0.844824] [G loss: 0.255019]
# VALID DATA
# overall TPR : 0.641
# priv TPR : 0.698
# unpriv TPR : 0.519
# Eq. Opp : 0.179
#
# overall FPR : 0.413
# priv FPR : 0.386
# unpriv FPR : 0.430
# diff FPR : 0.044
#
# overall ACC : 0.613
# priv ACC : 0.574
# unpriv ACC : 0.634
# diff ACC : 0.060
#
#
#
# TEST DATA
# overall TPR : 0.635
# priv TPR : 0.673
# unpriv TPR : 0.520
# Eq. Opp : 0.154
#
# overall FPR : 0.452
# priv FPR : 0.364
# unpriv FPR : 0.505
# diff FPR : 0.141
#
# overall ACC : 0.587
# priv ACC : 0.594
# unpriv ACC : 0.584
# diff ACC : 0.011
#
#
#
# DIMP : 0.713
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.686402] [D_R loss: 0.928974] [G loss: 0.186068]
# VALID DATA
# overall TPR : 0.590
# priv TPR : 0.634
# unpriv TPR : 0.492
# Eq. Opp : 0.142
#
# overall FPR : 0.336
# priv FPR : 0.375
# unpriv FPR : 0.312
# diff FPR : 0.063
#
# overall ACC : 0.629
# priv ACC : 0.570
# unpriv ACC : 0.662
# diff ACC : 0.091
#
#
#
# TEST DATA
# overall TPR : 0.534
# priv TPR : 0.531
# unpriv TPR : 0.544
# Eq. Opp : 0.013
#
# overall FPR : 0.352
# priv FPR : 0.321
# unpriv FPR : 0.372
# diff FPR : 0.051
#
# overall ACC : 0.596
# priv ACC : 0.631
# unpriv ACC : 0.579
# diff ACC : 0.052
#
#
#
# DIMP : 0.885
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.689035] [D_R loss: 0.815654] [G loss: 0.306808]
# VALID DATA
# overall TPR : 0.505
# priv TPR : 0.565
# unpriv TPR : 0.374
# Eq. Opp : 0.191
#
# overall FPR : 0.244
# priv FPR : 0.228
# unpriv FPR : 0.253
# diff FPR : 0.026
#
# overall ACC : 0.640
# priv ACC : 0.605
# unpriv ACC : 0.658
# diff ACC : 0.054
#
#
#
# TEST DATA
# overall TPR : 0.468
# priv TPR : 0.516
# unpriv TPR : 0.324
# Eq. Opp : 0.193
#
# overall FPR : 0.286
# priv FPR : 0.255
# unpriv FPR : 0.305
# diff FPR : 0.050
#
# overall ACC : 0.602
# priv ACC : 0.597
# unpriv ACC : 0.604
# diff ACC : 0.007
#
#
#
# DIMP : 0.677
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.627169] [D_R loss: 1.259840] [G loss: 7.285642]
# VALID DATA
# overall TPR : 0.409
# priv TPR : 0.353
# unpriv TPR : 0.549
# Eq. Opp : 0.196
#
# overall FPR : 0.266
# priv FPR : 0.381
# unpriv FPR : 0.191
# diff FPR : 0.190
#
# overall ACC : 0.589
# priv ACC : 0.593
# unpriv ACC : 0.587
# diff ACC : 0.005
#
#
#
# TEST DATA
# overall TPR : 0.404
# priv TPR : 0.394
# unpriv TPR : 0.426
# Eq. Opp : 0.032
#
# overall FPR : 0.282
# priv FPR : 0.344
# unpriv FPR : 0.244
# diff FPR : 0.100
#
# overall ACC : 0.574
# priv ACC : 0.565
# unpriv ACC : 0.578
# diff ACC : 0.013
#
#
#
# DIMP : 0.844
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.682860] [D_R loss: 0.860653] [G loss: 1.178443]
# VALID DATA
# overall TPR : 0.598
# priv TPR : 0.608
# unpriv TPR : 0.573
# Eq. Opp : 0.035
#
# overall FPR : 0.412
# priv FPR : 0.513
# unpriv FPR : 0.347
# diff FPR : 0.166
#
# overall ACC : 0.593
# priv ACC : 0.518
# unpriv ACC : 0.631
# diff ACC : 0.113
#
#
#
# TEST DATA
# overall TPR : 0.633
# priv TPR : 0.641
# unpriv TPR : 0.615
# Eq. Opp : 0.026
#
# overall FPR : 0.405
# priv FPR : 0.559
# unpriv FPR : 0.315
# diff FPR : 0.245
#
# overall ACC : 0.613
# priv ACC : 0.512
# unpriv ACC : 0.663
# diff ACC : 0.152
#
#
#
# DIMP : 0.817
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.692041] [D_R loss: 0.846364] [G loss: 0.240577]
# VALID DATA
# overall TPR : 0.596
# priv TPR : 0.647
# unpriv TPR : 0.464
# Eq. Opp : 0.183
#
# overall FPR : 0.358
# priv FPR : 0.381
# unpriv FPR : 0.342
# diff FPR : 0.039
#
# overall ACC : 0.622
# priv ACC : 0.562
# unpriv ACC : 0.653
# diff ACC : 0.090
#
#
#
# TEST DATA
# overall TPR : 0.609
# priv TPR : 0.652
# unpriv TPR : 0.508
# Eq. Opp : 0.144
#
# overall FPR : 0.320
# priv FPR : 0.335
# unpriv FPR : 0.311
# diff FPR : 0.024
#
# overall ACC : 0.647
# priv ACC : 0.603
# unpriv ACC : 0.671
# diff ACC : 0.068
#
#
#
# DIMP : 0.844
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.690395] [D_R loss: 0.840792] [G loss: 0.223870]
# VALID DATA
# overall TPR : 0.524
# priv TPR : 0.611
# unpriv TPR : 0.304
# Eq. Opp : 0.307
#
# overall FPR : 0.268
# priv FPR : 0.228
# unpriv FPR : 0.293
# diff FPR : 0.065
#
# overall ACC : 0.638
# priv ACC : 0.597
# unpriv ACC : 0.660
# diff ACC : 0.062
#
#
#
# TEST DATA
# overall TPR : 0.544
# priv TPR : 0.608
# unpriv TPR : 0.395
# Eq. Opp : 0.212
#
# overall FPR : 0.250
# priv FPR : 0.182
# unpriv FPR : 0.290
# diff FPR : 0.108
#
# overall ACC : 0.655
# priv ACC : 0.646
# unpriv ACC : 0.660
# diff ACC : 0.014
#
#
#
# DIMP : 0.604
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688750] [D_R loss: 0.785624] [G loss: 0.317667]
# VALID DATA
# overall TPR : 0.519
# priv TPR : 0.575
# unpriv TPR : 0.375
# Eq. Opp : 0.200
#
# overall FPR : 0.269
# priv FPR : 0.286
# unpriv FPR : 0.257
# diff FPR : 0.028
#
# overall ACC : 0.637
# priv ACC : 0.591
# unpriv ACC : 0.662
# diff ACC : 0.071
#
#
#
# TEST DATA
# overall TPR : 0.532
# priv TPR : 0.564
# unpriv TPR : 0.454
# Eq. Opp : 0.111
#
# overall FPR : 0.237
# priv FPR : 0.233
# unpriv FPR : 0.239
# diff FPR : 0.006
#
# overall ACC : 0.658
# priv ACC : 0.646
# unpriv ACC : 0.665
# diff ACC : 0.019
#
#
#
# DIMP : 0.800
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.646568] [D_R loss: 0.375611] [G loss: 9.439654]
# VALID DATA
# overall TPR : 0.323
# priv TPR : 0.286
# unpriv TPR : 0.403
# Eq. Opp : 0.117
#
# overall FPR : 0.244
# priv FPR : 0.379
# unpriv FPR : 0.163
# diff FPR : 0.216
#
# overall ACC : 0.551
# priv ACC : 0.527
# unpriv ACC : 0.564
# diff ACC : 0.037
#
#
#
# TEST DATA
# overall TPR : 0.329
# priv TPR : 0.257
# unpriv TPR : 0.496
# Eq. Opp : 0.239
#
# overall FPR : 0.188
# priv FPR : 0.279
# unpriv FPR : 0.128
# diff FPR : 0.151
#
# overall ACC : 0.599
# priv ACC : 0.636
# unpriv ACC : 0.579
# diff ACC : 0.057
#
#
#
# DIMP : 0.526
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.693814] [D_R loss: 1.033258] [G loss: 0.202464]
# VALID DATA
# overall TPR : 0.703
# priv TPR : 0.740
# unpriv TPR : 0.622
# Eq. Opp : 0.118
#
# overall FPR : 0.496
# priv FPR : 0.525
# unpriv FPR : 0.478
# diff FPR : 0.047
#
# overall ACC : 0.598
# priv ACC : 0.538
# unpriv ACC : 0.630
# diff ACC : 0.092
#
#
#
# TEST DATA
# overall TPR : 0.669
# priv TPR : 0.681
# unpriv TPR : 0.642
# Eq. Opp : 0.039
#
# overall FPR : 0.534
# priv FPR : 0.604
# unpriv FPR : 0.488
# diff FPR : 0.116
#
# overall ACC : 0.556
# priv ACC : 0.489
# unpriv ACC : 0.592
# diff ACC : 0.103
#
#
#
# DIMP : 0.939
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.690413] [D_R loss: 0.914729] [G loss: 0.317027]
# VALID DATA
# overall TPR : 0.647
# priv TPR : 0.689
# unpriv TPR : 0.556
# Eq. Opp : 0.132
#
# overall FPR : 0.440
# priv FPR : 0.403
# unpriv FPR : 0.463
# diff FPR : 0.060
#
# overall ACC : 0.600
# priv ACC : 0.580
# unpriv ACC : 0.612
# diff ACC : 0.032
#
#
#
# TEST DATA
# overall TPR : 0.621
# priv TPR : 0.649
# unpriv TPR : 0.556
# Eq. Opp : 0.093
#
# overall FPR : 0.508
# priv FPR : 0.543
# unpriv FPR : 0.485
# diff FPR : 0.058
#
# overall ACC : 0.549
# priv ACC : 0.494
# unpriv ACC : 0.579
# diff ACC : 0.086
#
#
#
# DIMP : 0.971
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.688985] [D_R loss: 1.010609] [G loss: 0.621369]
# VALID DATA
# overall TPR : 0.631
# priv TPR : 0.693
# unpriv TPR : 0.496
# Eq. Opp : 0.197
#
# overall FPR : 0.350
# priv FPR : 0.341
# unpriv FPR : 0.356
# diff FPR : 0.015
#
# overall ACC : 0.641
# priv ACC : 0.589
# unpriv ACC : 0.668
# diff ACC : 0.079
#
#
#
# TEST DATA
# overall TPR : 0.572
# priv TPR : 0.582
# unpriv TPR : 0.548
# Eq. Opp : 0.034
#
# overall FPR : 0.415
# priv FPR : 0.447
# unpriv FPR : 0.394
# diff FPR : 0.053
#
# overall ACC : 0.579
# priv ACC : 0.551
# unpriv ACC : 0.595
# diff ACC : 0.044
#
#
#
# DIMP : 0.999
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.690872] [D_R loss: 0.908127] [G loss: 0.723372]
# VALID DATA
# overall TPR : 0.571
# priv TPR : 0.606
# unpriv TPR : 0.496
# Eq. Opp : 0.109
#
# overall FPR : 0.331
# priv FPR : 0.417
# unpriv FPR : 0.279
# diff FPR : 0.138
#
# overall ACC : 0.623
# priv ACC : 0.546
# unpriv ACC : 0.664
# diff ACC : 0.117
#
#
#
# TEST DATA
# overall TPR : 0.570
# priv TPR : 0.560
# unpriv TPR : 0.593
# Eq. Opp : 0.034
#
# overall FPR : 0.367
# priv FPR : 0.475
# unpriv FPR : 0.296
# diff FPR : 0.179
#
# overall ACC : 0.605
# priv ACC : 0.550
# unpriv ACC : 0.635
# diff ACC : 0.085
#
#
#
# DIMP : 0.814
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.632944] [D_R loss: 1.183396] [G loss: 13.161451]
# VALID DATA
# overall TPR : 0.302
# priv TPR : 0.235
# unpriv TPR : 0.439
# Eq. Opp : 0.204
#
# overall FPR : 0.297
# priv FPR : 0.429
# unpriv FPR : 0.219
# diff FPR : 0.209
#
# overall ACC : 0.522
# priv ACC : 0.516
# unpriv ACC : 0.526
# diff ACC : 0.010
#
#
#
# TEST DATA
# overall TPR : 0.295
# priv TPR : 0.205
# unpriv TPR : 0.517
# Eq. Opp : 0.312
#
# overall FPR : 0.271
# priv FPR : 0.418
# unpriv FPR : 0.171
# diff FPR : 0.248
#
# overall ACC : 0.529
# priv ACC : 0.557
# unpriv ACC : 0.514
# diff ACC : 0.043
#
#
#
# DIMP : 0.412
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.693894] [D_R loss: 0.929215] [G loss: 0.598083]
# VALID DATA
# overall TPR : 0.558
# priv TPR : 0.591
# unpriv TPR : 0.489
# Eq. Opp : 0.103
#
# overall FPR : 0.470
# priv FPR : 0.439
# unpriv FPR : 0.487
# diff FPR : 0.048
#
# overall ACC : 0.542
# priv ACC : 0.531
# unpriv ACC : 0.549
# diff ACC : 0.018
#
#
#
# TEST DATA
# overall TPR : 0.569
# priv TPR : 0.564
# unpriv TPR : 0.583
# Eq. Opp : 0.020
#
# overall FPR : 0.476
# priv FPR : 0.561
# unpriv FPR : 0.418
# diff FPR : 0.142
#
# overall ACC : 0.545
# priv ACC : 0.494
# unpriv ACC : 0.573
# diff ACC : 0.079
#
#
#
# DIMP : 0.863
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.689969] [D_R loss: 0.835876] [G loss: 0.257832]
# VALID DATA
# overall TPR : 0.502
# priv TPR : 0.539
# unpriv TPR : 0.430
# Eq. Opp : 0.109
#
# overall FPR : 0.353
# priv FPR : 0.372
# unpriv FPR : 0.342
# diff FPR : 0.030
#
# overall ACC : 0.581
# priv ACC : 0.543
# unpriv ACC : 0.602
# diff ACC : 0.060
#
#
#
# TEST DATA
# overall TPR : 0.512
# priv TPR : 0.527
# unpriv TPR : 0.475
# Eq. Opp : 0.052
#
# overall FPR : 0.378
# priv FPR : 0.390
# unpriv FPR : 0.369
# diff FPR : 0.020
#
# overall ACC : 0.571
# priv ACC : 0.558
# unpriv ACC : 0.579
# diff ACC : 0.020
#
#
#
# DIMP : 0.941
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.690938] [D_R loss: 0.902836] [G loss: 0.249607]
# VALID DATA
# overall TPR : 0.637
# priv TPR : 0.639
# unpriv TPR : 0.631
# Eq. Opp : 0.009
#
# overall FPR : 0.475
# priv FPR : 0.500
# unpriv FPR : 0.461
# diff FPR : 0.039
#
# overall ACC : 0.575
# priv ACC : 0.555
# unpriv ACC : 0.585
# diff ACC : 0.030
#
#
#
# TEST DATA
# overall TPR : 0.654
# priv TPR : 0.653
# unpriv TPR : 0.658
# Eq. Opp : 0.006
#
# overall FPR : 0.463
# priv FPR : 0.505
# unpriv FPR : 0.434
# diff FPR : 0.071
#
# overall ACC : 0.590
# priv ACC : 0.557
# unpriv ACC : 0.609
# diff ACC : 0.052
#
#
#
# DIMP : 0.965
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.692491] [D_R loss: 0.968289] [G loss: 0.185384]
# VALID DATA
# overall TPR : 0.617
# priv TPR : 0.613
# unpriv TPR : 0.624
# Eq. Opp : 0.011
#
# overall FPR : 0.462
# priv FPR : 0.536
# unpriv FPR : 0.418
# diff FPR : 0.118
#
# overall ACC : 0.574
# priv ACC : 0.532
# unpriv ACC : 0.597
# diff ACC : 0.065
#
#
#
# TEST DATA
# overall TPR : 0.609
# priv TPR : 0.583
# unpriv TPR : 0.672
# Eq. Opp : 0.090
#
# overall FPR : 0.441
# priv FPR : 0.538
# unpriv FPR : 0.375
# diff FPR : 0.163
#
# overall ACC : 0.581
# priv ACC : 0.541
# unpriv ACC : 0.604
# diff ACC : 0.063
#
#
#
# DIMP : 0.815
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 61.028118] [D_R loss: 0.118634] [G loss: 30.800922]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.567
# priv ACC : 0.624
# unpriv ACC : 0.534
# diff ACC : 0.090
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.538
# priv ACC : 0.622
# unpriv ACC : 0.498
# diff ACC : 0.124
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.666858] [D_R loss: 0.530800] [G loss: 10.095846]
# VALID DATA
# overall TPR : 0.339
# priv TPR : 0.360
# unpriv TPR : 0.293
# Eq. Opp : 0.067
#
# overall FPR : 0.314
# priv FPR : 0.260
# unpriv FPR : 0.351
# diff FPR : 0.091
#
# overall ACC : 0.536
# priv ACC : 0.572
# unpriv ACC : 0.515
# diff ACC : 0.057
#
#
#
# TEST DATA
# overall TPR : 0.351
# priv TPR : 0.405
# unpriv TPR : 0.202
# Eq. Opp : 0.203
#
# overall FPR : 0.263
# priv FPR : 0.240
# unpriv FPR : 0.277
# diff FPR : 0.036
#
# overall ACC : 0.559
# priv ACC : 0.551
# unpriv ACC : 0.563
# diff ACC : 0.012
#
#
#
# DIMP : 0.663
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.672123] [D_R loss: 0.686110] [G loss: 0.280861]
# VALID DATA
# overall TPR : 0.472
# priv TPR : 0.476
# unpriv TPR : 0.461
# Eq. Opp : 0.015
#
# overall FPR : 0.443
# priv FPR : 0.490
# unpriv FPR : 0.412
# diff FPR : 0.078
#
# overall ACC : 0.520
# priv ACC : 0.492
# unpriv ACC : 0.536
# diff ACC : 0.043
#
#
#
# TEST DATA
# overall TPR : 0.489
# priv TPR : 0.478
# unpriv TPR : 0.518
# Eq. Opp : 0.039
#
# overall FPR : 0.402
# priv FPR : 0.440
# unpriv FPR : 0.378
# diff FPR : 0.062
#
# overall ACC : 0.548
# priv ACC : 0.544
# unpriv ACC : 0.550
# diff ACC : 0.006
#
#
#
# DIMP : 0.912
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.690655] [D_R loss: 0.690619] [G loss: 0.983506]
# VALID DATA
# overall TPR : 0.503
# priv TPR : 0.496
# unpriv TPR : 0.517
# Eq. Opp : 0.020
#
# overall FPR : 0.418
# priv FPR : 0.536
# unpriv FPR : 0.338
# diff FPR : 0.198
#
# overall ACC : 0.548
# priv ACC : 0.483
# unpriv ACC : 0.586
# diff ACC : 0.102
#
#
#
# TEST DATA
# overall TPR : 0.578
# priv TPR : 0.560
# unpriv TPR : 0.625
# Eq. Opp : 0.065
#
# overall FPR : 0.403
# priv FPR : 0.497
# unpriv FPR : 0.344
# diff FPR : 0.153
#
# overall ACC : 0.588
# priv ACC : 0.549
# unpriv ACC : 0.608
# diff ACC : 0.059
#
#
#
# DIMP : 0.829
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.684816] [D_R loss: 0.781322] [G loss: 0.340575]
# VALID DATA
# overall TPR : 0.417
# priv TPR : 0.423
# unpriv TPR : 0.405
# Eq. Opp : 0.018
#
# overall FPR : 0.276
# priv FPR : 0.273
# unpriv FPR : 0.279
# diff FPR : 0.006
#
# overall ACC : 0.592
# priv ACC : 0.609
# unpriv ACC : 0.581
# diff ACC : 0.028
#
#
#
# TEST DATA
# overall TPR : 0.441
# priv TPR : 0.465
# unpriv TPR : 0.375
# Eq. Opp : 0.090
#
# overall FPR : 0.269
# priv FPR : 0.220
# unpriv FPR : 0.300
# diff FPR : 0.079
#
# overall ACC : 0.597
# priv ACC : 0.628
# unpriv ACC : 0.582
# diff ACC : 0.046
#
#
#
# DIMP : 0.727
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.693330] [D_R loss: 0.461384] [G loss: 13.017981]
# VALID DATA
# overall TPR : 0.103
# priv TPR : 0.114
# unpriv TPR : 0.076
# Eq. Opp : 0.038
#
# overall FPR : 0.079
# priv FPR : 0.045
# unpriv FPR : 0.100
# diff FPR : 0.055
#
# overall ACC : 0.532
# priv ACC : 0.604
# unpriv ACC : 0.497
# diff ACC : 0.107
#
#
#
# TEST DATA
# overall TPR : 0.073
# priv TPR : 0.091
# unpriv TPR : 0.033
# Eq. Opp : 0.058
#
# overall FPR : 0.064
# priv FPR : 0.043
# unpriv FPR : 0.074
# diff FPR : 0.031
#
# overall ACC : 0.554
# priv ACC : 0.563
# unpriv ACC : 0.549
# diff ACC : 0.014
#
#
#
# DIMP : 0.474
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.691833] [D_R loss: 0.894497] [G loss: 1.051980]
# VALID DATA
# overall TPR : 0.581
# priv TPR : 0.594
# unpriv TPR : 0.546
# Eq. Opp : 0.048
#
# overall FPR : 0.412
# priv FPR : 0.424
# unpriv FPR : 0.404
# diff FPR : 0.020
#
# overall ACC : 0.585
# priv ACC : 0.564
# unpriv ACC : 0.595
# diff ACC : 0.031
#
#
#
# TEST DATA
# overall TPR : 0.541
# priv TPR : 0.560
# unpriv TPR : 0.496
# Eq. Opp : 0.064
#
# overall FPR : 0.403
# priv FPR : 0.435
# unpriv FPR : 0.387
# diff FPR : 0.048
#
# overall ACC : 0.573
# priv ACC : 0.537
# unpriv ACC : 0.589
# diff ACC : 0.052
#
#
#
# DIMP : 0.989
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.690271] [D_R loss: 0.977279] [G loss: 0.222906]
# VALID DATA
# overall TPR : 0.687
# priv TPR : 0.702
# unpriv TPR : 0.650
# Eq. Opp : 0.052
#
# overall FPR : 0.450
# priv FPR : 0.508
# unpriv FPR : 0.414
# diff FPR : 0.094
#
# overall ACC : 0.615
# priv ACC : 0.555
# unpriv ACC : 0.645
# diff ACC : 0.091
#
#
#
# TEST DATA
# overall TPR : 0.635
# priv TPR : 0.664
# unpriv TPR : 0.568
# Eq. Opp : 0.096
#
# overall FPR : 0.449
# priv FPR : 0.534
# unpriv FPR : 0.409
# diff FPR : 0.125
#
# overall ACC : 0.588
# priv ACC : 0.509
# unpriv ACC : 0.624
# diff ACC : 0.115
#
#
#
# DIMP : 0.955
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.691168] [D_R loss: 0.802572] [G loss: 0.376619]
# VALID DATA
# overall TPR : 0.644
# priv TPR : 0.638
# unpriv TPR : 0.658
# Eq. Opp : 0.020
#
# overall FPR : 0.390
# priv FPR : 0.456
# unpriv FPR : 0.349
# diff FPR : 0.106
#
# overall ACC : 0.626
# priv ACC : 0.590
# unpriv ACC : 0.644
# diff ACC : 0.054
#
#
#
# TEST DATA
# overall TPR : 0.577
# priv TPR : 0.571
# unpriv TPR : 0.590
# Eq. Opp : 0.019
#
# overall FPR : 0.385
# priv FPR : 0.491
# unpriv FPR : 0.333
# diff FPR : 0.158
#
# overall ACC : 0.598
# priv ACC : 0.544
# unpriv ACC : 0.624
# diff ACC : 0.080
#
#
#
# DIMP : 0.825
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688490] [D_R loss: 0.785449] [G loss: 0.248291]
# VALID DATA
# overall TPR : 0.660
# priv TPR : 0.646
# unpriv TPR : 0.695
# Eq. Opp : 0.049
#
# overall FPR : 0.445
# priv FPR : 0.539
# unpriv FPR : 0.387
# diff FPR : 0.152
#
# overall ACC : 0.605
# priv ACC : 0.554
# unpriv ACC : 0.630
# diff ACC : 0.076
#
#
#
# TEST DATA
# overall TPR : 0.616
# priv TPR : 0.605
# unpriv TPR : 0.642
# Eq. Opp : 0.037
#
# overall FPR : 0.428
# priv FPR : 0.533
# unpriv FPR : 0.376
# diff FPR : 0.157
#
# overall ACC : 0.592
# priv ACC : 0.540
# unpriv ACC : 0.615
# diff ACC : 0.075
#
#
#
# DIMP : 0.828
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.699765] [D_R loss: 0.205427] [G loss: 33.962566]
# VALID DATA
# overall TPR : 0.051
# priv TPR : 0.075
# unpriv TPR : 0.000
# Eq. Opp : 0.075
#
# overall FPR : 0.017
# priv FPR : 0.000
# unpriv FPR : 0.029
# diff FPR : 0.029
#
# overall ACC : 0.536
# priv ACC : 0.587
# unpriv ACC : 0.506
# diff ACC : 0.081
#
#
#
# TEST DATA
# overall TPR : 0.051
# priv TPR : 0.070
# unpriv TPR : 0.000
# Eq. Opp : 0.070
#
# overall FPR : 0.023
# priv FPR : 0.000
# unpriv FPR : 0.036
# diff FPR : 0.036
#
# overall ACC : 0.552
# priv ACC : 0.618
# unpriv ACC : 0.520
# diff ACC : 0.098
#
#
#
# DIMP : 0.000
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.692314] [D_R loss: 0.969023] [G loss: 1.431074]
# VALID DATA
# overall TPR : 0.568
# priv TPR : 0.625
# unpriv TPR : 0.449
# Eq. Opp : 0.175
#
# overall FPR : 0.428
# priv FPR : 0.421
# unpriv FPR : 0.433
# diff FPR : 0.012
#
# overall ACC : 0.570
# priv ACC : 0.524
# unpriv ACC : 0.597
# diff ACC : 0.072
#
#
#
# TEST DATA
# overall TPR : 0.557
# priv TPR : 0.589
# unpriv TPR : 0.473
# Eq. Opp : 0.116
#
# overall FPR : 0.470
# priv FPR : 0.414
# unpriv FPR : 0.505
# diff FPR : 0.091
#
# overall ACC : 0.542
# priv ACC : 0.544
# unpriv ACC : 0.542
# diff ACC : 0.002
#
#
#
# DIMP : 0.797
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.690699] [D_R loss: 1.041511] [G loss: 0.944765]
# VALID DATA
# overall TPR : 0.583
# priv TPR : 0.595
# unpriv TPR : 0.556
# Eq. Opp : 0.039
#
# overall FPR : 0.435
# priv FPR : 0.562
# unpriv FPR : 0.347
# diff FPR : 0.216
#
# overall ACC : 0.574
# priv ACC : 0.486
# unpriv ACC : 0.623
# diff ACC : 0.137
#
#
#
# TEST DATA
# overall TPR : 0.583
# priv TPR : 0.560
# unpriv TPR : 0.640
# Eq. Opp : 0.080
#
# overall FPR : 0.419
# priv FPR : 0.538
# unpriv FPR : 0.347
# diff FPR : 0.191
#
# overall ACC : 0.581
# priv ACC : 0.530
# unpriv ACC : 0.607
# diff ACC : 0.077
#
#
#
# DIMP : 0.785
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.689738] [D_R loss: 0.940417] [G loss: 0.234942]
# VALID DATA
# overall TPR : 0.590
# priv TPR : 0.624
# unpriv TPR : 0.518
# Eq. Opp : 0.106
#
# overall FPR : 0.366
# priv FPR : 0.400
# unpriv FPR : 0.343
# diff FPR : 0.057
#
# overall ACC : 0.613
# priv ACC : 0.565
# unpriv ACC : 0.640
# diff ACC : 0.075
#
#
#
# TEST DATA
# overall TPR : 0.571
# priv TPR : 0.592
# unpriv TPR : 0.518
# Eq. Opp : 0.074
#
# overall FPR : 0.381
# priv FPR : 0.400
# unpriv FPR : 0.370
# diff FPR : 0.030
#
# overall ACC : 0.597
# priv ACC : 0.569
# unpriv ACC : 0.611
# diff ACC : 0.043
#
#
#
# DIMP : 0.929
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.689271] [D_R loss: 0.799591] [G loss: 0.644716]
# VALID DATA
# overall TPR : 0.521
# priv TPR : 0.570
# unpriv TPR : 0.412
# Eq. Opp : 0.159
#
# overall FPR : 0.314
# priv FPR : 0.378
# unpriv FPR : 0.270
# diff FPR : 0.108
#
# overall ACC : 0.606
# priv ACC : 0.534
# unpriv ACC : 0.647
# diff ACC : 0.113
#
#
#
# TEST DATA
# overall TPR : 0.494
# priv TPR : 0.505
# unpriv TPR : 0.464
# Eq. Opp : 0.041
#
# overall FPR : 0.306
# priv FPR : 0.299
# unpriv FPR : 0.310
# diff FPR : 0.011
#
# overall ACC : 0.603
# priv ACC : 0.611
# unpriv ACC : 0.598
# diff ACC : 0.013
#
#
#
# DIMP : 0.889
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.607015] [D_R loss: 0.251838] [G loss: 18.381561]
# VALID DATA
# overall TPR : 0.118
# priv TPR : 0.128
# unpriv TPR : 0.092
# Eq. Opp : 0.037
#
# overall FPR : 0.074
# priv FPR : 0.081
# unpriv FPR : 0.069
# diff FPR : 0.012
#
# overall ACC : 0.558
# priv ACC : 0.593
# unpriv ACC : 0.540
# diff ACC : 0.054
#
#
#
# TEST DATA
# overall TPR : 0.081
# priv TPR : 0.063
# unpriv TPR : 0.116
# Eq. Opp : 0.053
#
# overall FPR : 0.070
# priv FPR : 0.086
# unpriv FPR : 0.060
# diff FPR : 0.026
#
# overall ACC : 0.544
# priv ACC : 0.574
# unpriv ACC : 0.526
# diff ACC : 0.048
#
#
#
# DIMP : 0.620
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.696528] [D_R loss: 0.643177] [G loss: 1.863271]
# VALID DATA
# overall TPR : 0.533
# priv TPR : 0.540
# unpriv TPR : 0.517
# Eq. Opp : 0.023
#
# overall FPR : 0.364
# priv FPR : 0.404
# unpriv FPR : 0.339
# diff FPR : 0.065
#
# overall ACC : 0.589
# priv ACC : 0.565
# unpriv ACC : 0.602
# diff ACC : 0.036
#
#
#
# TEST DATA
# overall TPR : 0.531
# priv TPR : 0.526
# unpriv TPR : 0.541
# Eq. Opp : 0.015
#
# overall FPR : 0.369
# priv FPR : 0.457
# unpriv FPR : 0.315
# diff FPR : 0.143
#
# overall ACC : 0.586
# priv ACC : 0.542
# unpriv ACC : 0.611
# diff ACC : 0.069
#
#
#
# DIMP : 0.840
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.676139] [D_R loss: 0.890409] [G loss: 1.019500]
# VALID DATA
# overall TPR : 0.646
# priv TPR : 0.647
# unpriv TPR : 0.644
# Eq. Opp : 0.003
#
# overall FPR : 0.472
# priv FPR : 0.529
# unpriv FPR : 0.436
# diff FPR : 0.093
#
# overall ACC : 0.581
# priv ACC : 0.537
# unpriv ACC : 0.604
# diff ACC : 0.067
#
#
#
# TEST DATA
# overall TPR : 0.613
# priv TPR : 0.641
# unpriv TPR : 0.556
# Eq. Opp : 0.085
#
# overall FPR : 0.451
# priv FPR : 0.473
# unpriv FPR : 0.438
# diff FPR : 0.035
#
# overall ACC : 0.578
# priv ACC : 0.539
# unpriv ACC : 0.600
# diff ACC : 0.060
#
#
#
# DIMP : 0.951
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.685170] [D_R loss: 0.908706] [G loss: 0.792438]
# VALID DATA
# overall TPR : 0.565
# priv TPR : 0.572
# unpriv TPR : 0.546
# Eq. Opp : 0.026
#
# overall FPR : 0.394
# priv FPR : 0.438
# unpriv FPR : 0.368
# diff FPR : 0.070
#
# overall ACC : 0.587
# priv ACC : 0.556
# unpriv ACC : 0.603
# diff ACC : 0.047
#
#
#
# TEST DATA
# overall TPR : 0.600
# priv TPR : 0.621
# unpriv TPR : 0.558
# Eq. Opp : 0.063
#
# overall FPR : 0.389
# priv FPR : 0.413
# unpriv FPR : 0.374
# diff FPR : 0.039
#
# overall ACC : 0.606
# priv ACC : 0.575
# unpriv ACC : 0.624
# diff ACC : 0.049
#
#
#
# DIMP : 0.971
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688837] [D_R loss: 0.737252] [G loss: 0.701038]
# VALID DATA
# overall TPR : 0.525
# priv TPR : 0.597
# unpriv TPR : 0.347
# Eq. Opp : 0.249
#
# overall FPR : 0.301
# priv FPR : 0.206
# unpriv FPR : 0.361
# diff FPR : 0.155
#
# overall ACC : 0.619
# priv ACC : 0.622
# unpriv ACC : 0.618
# diff ACC : 0.004
#
#
#
# TEST DATA
# overall TPR : 0.515
# priv TPR : 0.615
# unpriv TPR : 0.316
# Eq. Opp : 0.299
#
# overall FPR : 0.269
# priv FPR : 0.160
# unpriv FPR : 0.338
# diff FPR : 0.178
#
# overall ACC : 0.633
# priv ACC : 0.620
# unpriv ACC : 0.640
# diff ACC : 0.019
#
#
#
# DIMP : 0.481
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.623766] [D_R loss: 0.677797] [G loss: 12.309790]
# VALID DATA
# overall TPR : 0.153
# priv TPR : 0.099
# unpriv TPR : 0.285
# Eq. Opp : 0.186
#
# overall FPR : 0.215
# priv FPR : 0.398
# unpriv FPR : 0.099
# diff FPR : 0.299
#
# overall ACC : 0.491
# priv ACC : 0.476
# unpriv ACC : 0.499
# diff ACC : 0.023
#
#
#
# TEST DATA
# overall TPR : 0.125
# priv TPR : 0.062
# unpriv TPR : 0.301
# Eq. Opp : 0.238
#
# overall FPR : 0.138
# priv FPR : 0.259
# unpriv FPR : 0.066
# diff FPR : 0.193
#
# overall ACC : 0.506
# priv ACC : 0.568
# unpriv ACC : 0.476
# diff ACC : 0.092
#
#
#
# DIMP : 0.233
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.663357] [D_R loss: 0.721814] [G loss: 2.840676]
# VALID DATA
# overall TPR : 0.476
# priv TPR : 0.476
# unpriv TPR : 0.475
# Eq. Opp : 0.001
#
# overall FPR : 0.310
# priv FPR : 0.314
# unpriv FPR : 0.307
# diff FPR : 0.007
#
# overall ACC : 0.590
# priv ACC : 0.599
# unpriv ACC : 0.586
# diff ACC : 0.013
#
#
#
# TEST DATA
# overall TPR : 0.519
# priv TPR : 0.521
# unpriv TPR : 0.513
# Eq. Opp : 0.008
#
# overall FPR : 0.326
# priv FPR : 0.380
# unpriv FPR : 0.293
# diff FPR : 0.087
#
# overall ACC : 0.599
# priv ACC : 0.578
# unpriv ACC : 0.610
# diff ACC : 0.032
#
#
#
# DIMP : 0.952
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.698533] [D_R loss: 0.800792] [G loss: 1.155803]
# VALID DATA
# overall TPR : 0.591
# priv TPR : 0.606
# unpriv TPR : 0.556
# Eq. Opp : 0.050
#
# overall FPR : 0.435
# priv FPR : 0.481
# unpriv FPR : 0.407
# diff FPR : 0.074
#
# overall ACC : 0.577
# priv ACC : 0.534
# unpriv ACC : 0.600
# diff ACC : 0.066
#
#
#
# TEST DATA
# overall TPR : 0.627
# priv TPR : 0.633
# unpriv TPR : 0.612
# Eq. Opp : 0.021
#
# overall FPR : 0.478
# priv FPR : 0.514
# unpriv FPR : 0.456
# diff FPR : 0.058
#
# overall ACC : 0.573
# priv ACC : 0.536
# unpriv ACC : 0.590
# diff ACC : 0.055
#
#
#
# DIMP : 0.993
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.688653] [D_R loss: 0.881041] [G loss: 0.355069]
# VALID DATA
# overall TPR : 0.619
# priv TPR : 0.605
# unpriv TPR : 0.653
# Eq. Opp : 0.047
#
# overall FPR : 0.422
# priv FPR : 0.495
# unpriv FPR : 0.378
# diff FPR : 0.117
#
# overall ACC : 0.597
# priv ACC : 0.564
# unpriv ACC : 0.614
# diff ACC : 0.049
#
#
#
# TEST DATA
# overall TPR : 0.640
# priv TPR : 0.633
# unpriv TPR : 0.658
# Eq. Opp : 0.025
#
# overall FPR : 0.430
# priv FPR : 0.514
# unpriv FPR : 0.378
# diff FPR : 0.136
#
# overall ACC : 0.604
# priv ACC : 0.555
# unpriv ACC : 0.627
# diff ACC : 0.073
#
#
#
# DIMP : 0.895
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688887] [D_R loss: 0.797001] [G loss: 0.283558]
# VALID DATA
# overall TPR : 0.623
# priv TPR : 0.594
# unpriv TPR : 0.694
# Eq. Opp : 0.100
#
# overall FPR : 0.489
# priv FPR : 0.554
# unpriv FPR : 0.449
# diff FPR : 0.106
#
# overall ACC : 0.562
# priv ACC : 0.544
# unpriv ACC : 0.572
# diff ACC : 0.028
#
#
#
# TEST DATA
# overall TPR : 0.692
# priv TPR : 0.674
# unpriv TPR : 0.743
# Eq. Opp : 0.069
#
# overall FPR : 0.495
# priv FPR : 0.579
# unpriv FPR : 0.443
# diff FPR : 0.136
#
# overall ACC : 0.595
# priv ACC : 0.546
# unpriv ACC : 0.618
# diff ACC : 0.072
#
#
#
# DIMP : 0.877
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 51.319443] [D_R loss: 0.220065] [G loss: 29.180717]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.564
# priv ACC : 0.661
# unpriv ACC : 0.510
# diff ACC : 0.151
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.556
# priv ACC : 0.577
# unpriv ACC : 0.545
# diff ACC : 0.031
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.519778] [D_R loss: 0.650186] [G loss: 6.516735]
# VALID DATA
# overall TPR : 0.314
# priv TPR : 0.271
# unpriv TPR : 0.423
# Eq. Opp : 0.152
#
# overall FPR : 0.224
# priv FPR : 0.373
# unpriv FPR : 0.121
# diff FPR : 0.251
#
# overall ACC : 0.573
# priv ACC : 0.556
# unpriv ACC : 0.582
# diff ACC : 0.026
#
#
#
# TEST DATA
# overall TPR : 0.303
# priv TPR : 0.218
# unpriv TPR : 0.492
# Eq. Opp : 0.274
#
# overall FPR : 0.239
# priv FPR : 0.431
# unpriv FPR : 0.136
# diff FPR : 0.295
#
# overall ACC : 0.557
# priv ACC : 0.537
# unpriv ACC : 0.567
# diff ACC : 0.030
#
#
#
# DIMP : 0.381
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.608126] [D_R loss: 0.806821] [G loss: 4.010815]
# VALID DATA
# overall TPR : 0.409
# priv TPR : 0.408
# unpriv TPR : 0.412
# Eq. Opp : 0.004
#
# overall FPR : 0.284
# priv FPR : 0.359
# unpriv FPR : 0.231
# diff FPR : 0.128
#
# overall ACC : 0.580
# priv ACC : 0.559
# unpriv ACC : 0.592
# diff ACC : 0.033
#
#
#
# TEST DATA
# overall TPR : 0.403
# priv TPR : 0.394
# unpriv TPR : 0.422
# Eq. Opp : 0.028
#
# overall FPR : 0.267
# priv FPR : 0.287
# unpriv FPR : 0.256
# diff FPR : 0.031
#
# overall ACC : 0.585
# priv ACC : 0.589
# unpriv ACC : 0.582
# diff ACC : 0.007
#
#
#
# DIMP : 0.929
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.621522] [D_R loss: 0.964041] [G loss: 2.227334]
# VALID DATA
# overall TPR : 0.566
# priv TPR : 0.547
# unpriv TPR : 0.615
# Eq. Opp : 0.067
#
# overall FPR : 0.414
# priv FPR : 0.536
# unpriv FPR : 0.329
# diff FPR : 0.207
#
# overall ACC : 0.577
# priv ACC : 0.516
# unpriv ACC : 0.610
# diff ACC : 0.095
#
#
#
# TEST DATA
# overall TPR : 0.526
# priv TPR : 0.540
# unpriv TPR : 0.496
# Eq. Opp : 0.044
#
# overall FPR : 0.388
# priv FPR : 0.480
# unpriv FPR : 0.339
# diff FPR : 0.141
#
# overall ACC : 0.574
# priv ACC : 0.510
# unpriv ACC : 0.606
# diff ACC : 0.096
#
#
#
# DIMP : 0.885
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.729065] [D_R loss: 0.707146] [G loss: 0.852480]
# VALID DATA
# overall TPR : 0.593
# priv TPR : 0.649
# unpriv TPR : 0.450
# Eq. Opp : 0.198
#
# overall FPR : 0.416
# priv FPR : 0.411
# unpriv FPR : 0.419
# diff FPR : 0.008
#
# overall ACC : 0.588
# priv ACC : 0.541
# unpriv ACC : 0.614
# diff ACC : 0.073
#
#
#
# TEST DATA
# overall TPR : 0.547
# priv TPR : 0.590
# unpriv TPR : 0.457
# Eq. Opp : 0.132
#
# overall FPR : 0.405
# priv FPR : 0.360
# unpriv FPR : 0.428
# diff FPR : 0.068
#
# overall ACC : 0.574
# priv ACC : 0.561
# unpriv ACC : 0.580
# diff ACC : 0.018
#
#
#
# DIMP : 0.803
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.685674] [D_R loss: 0.592443] [G loss: 0.134866]
# VALID DATA
# overall TPR : 0.341
# priv TPR : 0.347
# unpriv TPR : 0.325
# Eq. Opp : 0.022
#
# overall FPR : 0.205
# priv FPR : 0.214
# unpriv FPR : 0.199
# diff FPR : 0.016
#
# overall ACC : 0.574
# priv ACC : 0.608
# unpriv ACC : 0.557
# diff ACC : 0.051
#
#
#
# TEST DATA
# overall TPR : 0.324
# priv TPR : 0.337
# unpriv TPR : 0.295
# Eq. Opp : 0.041
#
# overall FPR : 0.208
# priv FPR : 0.217
# unpriv FPR : 0.202
# diff FPR : 0.015
#
# overall ACC : 0.573
# priv ACC : 0.583
# unpriv ACC : 0.567
# diff ACC : 0.016
#
#
#
# DIMP : 0.925
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.690156] [D_R loss: 0.923102] [G loss: 0.290533]
# VALID DATA
# overall TPR : 0.625
# priv TPR : 0.646
# unpriv TPR : 0.565
# Eq. Opp : 0.081
#
# overall FPR : 0.369
# priv FPR : 0.397
# unpriv FPR : 0.350
# diff FPR : 0.047
#
# overall ACC : 0.628
# priv ACC : 0.589
# unpriv ACC : 0.648
# diff ACC : 0.059
#
#
#
# TEST DATA
# overall TPR : 0.570
# priv TPR : 0.617
# unpriv TPR : 0.466
# Eq. Opp : 0.152
#
# overall FPR : 0.442
# priv FPR : 0.444
# unpriv FPR : 0.441
# diff FPR : 0.004
#
# overall ACC : 0.564
# priv ACC : 0.519
# unpriv ACC : 0.589
# diff ACC : 0.070
#
#
#
# DIMP : 0.856
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.691123] [D_R loss: 0.754664] [G loss: 0.253421]
# VALID DATA
# overall TPR : 0.696
# priv TPR : 0.664
# unpriv TPR : 0.788
# Eq. Opp : 0.124
#
# overall FPR : 0.430
# priv FPR : 0.629
# unpriv FPR : 0.297
# diff FPR : 0.332
#
# overall ACC : 0.631
# priv ACC : 0.528
# unpriv ACC : 0.682
# diff ACC : 0.153
#
#
#
# TEST DATA
# overall TPR : 0.662
# priv TPR : 0.615
# unpriv TPR : 0.765
# Eq. Opp : 0.151
#
# overall FPR : 0.519
# priv FPR : 0.753
# unpriv FPR : 0.369
# diff FPR : 0.384
#
# overall ACC : 0.566
# priv ACC : 0.462
# unpriv ACC : 0.623
# diff ACC : 0.161
#
#
#
# DIMP : 0.648
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.691736] [D_R loss: 1.146465] [G loss: 0.287522]
# VALID DATA
# overall TPR : 0.677
# priv TPR : 0.689
# unpriv TPR : 0.646
# Eq. Opp : 0.043
#
# overall FPR : 0.402
# priv FPR : 0.467
# unpriv FPR : 0.359
# diff FPR : 0.108
#
# overall ACC : 0.636
# priv ACC : 0.576
# unpriv ACC : 0.666
# diff ACC : 0.090
#
#
#
# TEST DATA
# overall TPR : 0.613
# priv TPR : 0.616
# unpriv TPR : 0.606
# Eq. Opp : 0.010
#
# overall FPR : 0.479
# priv FPR : 0.544
# unpriv FPR : 0.438
# diff FPR : 0.106
#
# overall ACC : 0.565
# priv ACC : 0.519
# unpriv ACC : 0.589
# diff ACC : 0.070
#
#
#
# DIMP : 0.925
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.689116] [D_R loss: 0.752594] [G loss: 0.206800]
# VALID DATA
# overall TPR : 0.670
# priv TPR : 0.656
# unpriv TPR : 0.708
# Eq. Opp : 0.052
#
# overall FPR : 0.467
# priv FPR : 0.574
# unpriv FPR : 0.395
# diff FPR : 0.179
#
# overall ACC : 0.598
# priv ACC : 0.532
# unpriv ACC : 0.632
# diff ACC : 0.100
#
#
#
# TEST DATA
# overall TPR : 0.663
# priv TPR : 0.628
# unpriv TPR : 0.744
# Eq. Opp : 0.117
#
# overall FPR : 0.520
# priv FPR : 0.660
# unpriv FPR : 0.429
# diff FPR : 0.231
#
# overall ACC : 0.566
# priv ACC : 0.505
# unpriv ACC : 0.599
# diff ACC : 0.095
#
#
#
# DIMP : 0.762
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.690773] [D_R loss: 0.319238] [G loss: 32.307858]
# VALID DATA
# overall TPR : 0.079
# priv TPR : 0.110
# unpriv TPR : 0.000
# Eq. Opp : 0.110
#
# overall FPR : 0.050
# priv FPR : 0.000
# unpriv FPR : 0.078
# diff FPR : 0.078
#
# overall ACC : 0.541
# priv ACC : 0.584
# unpriv ACC : 0.521
# diff ACC : 0.064
#
#
#
# TEST DATA
# overall TPR : 0.062
# priv TPR : 0.091
# unpriv TPR : 0.000
# Eq. Opp : 0.091
#
# overall FPR : 0.042
# priv FPR : 0.000
# unpriv FPR : 0.067
# diff FPR : 0.067
#
# overall ACC : 0.588
# priv ACC : 0.624
# unpriv ACC : 0.569
# diff ACC : 0.055
#
#
#
# DIMP : 0.000
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.693501] [D_R loss: 0.734635] [G loss: 3.019167]
# VALID DATA
# overall TPR : 0.494
# priv TPR : 0.567
# unpriv TPR : 0.317
# Eq. Opp : 0.250
#
# overall FPR : 0.332
# priv FPR : 0.249
# unpriv FPR : 0.378
# diff FPR : 0.130
#
# overall ACC : 0.588
# priv ACC : 0.573
# unpriv ACC : 0.595
# diff ACC : 0.022
#
#
#
# TEST DATA
# overall TPR : 0.476
# priv TPR : 0.528
# unpriv TPR : 0.367
# Eq. Opp : 0.161
#
# overall FPR : 0.349
# priv FPR : 0.234
# unpriv FPR : 0.416
# diff FPR : 0.181
#
# overall ACC : 0.578
# priv ACC : 0.612
# unpriv ACC : 0.560
# diff ACC : 0.052
#
#
#
# DIMP : 0.615
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.687419] [D_R loss: 0.757392] [G loss: 1.038826]
# VALID DATA
# overall TPR : 0.548
# priv TPR : 0.557
# unpriv TPR : 0.526
# Eq. Opp : 0.031
#
# overall FPR : 0.369
# priv FPR : 0.451
# unpriv FPR : 0.324
# diff FPR : 0.127
#
# overall ACC : 0.593
# priv ACC : 0.540
# unpriv ACC : 0.618
# diff ACC : 0.078
#
#
#
# TEST DATA
# overall TPR : 0.473
# priv TPR : 0.452
# unpriv TPR : 0.517
# Eq. Opp : 0.065
#
# overall FPR : 0.378
# priv FPR : 0.449
# unpriv FPR : 0.336
# diff FPR : 0.113
#
# overall ACC : 0.560
# priv ACC : 0.538
# unpriv ACC : 0.572
# diff ACC : 0.034
#
#
#
# DIMP : 0.814
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.687633] [D_R loss: 0.768051] [G loss: 0.209570]
# VALID DATA
# overall TPR : 0.553
# priv TPR : 0.559
# unpriv TPR : 0.538
# Eq. Opp : 0.021
#
# overall FPR : 0.373
# priv FPR : 0.379
# unpriv FPR : 0.370
# diff FPR : 0.009
#
# overall ACC : 0.593
# priv ACC : 0.588
# unpriv ACC : 0.595
# diff ACC : 0.007
#
#
#
# TEST DATA
# overall TPR : 0.526
# priv TPR : 0.565
# unpriv TPR : 0.441
# Eq. Opp : 0.125
#
# overall FPR : 0.375
# priv FPR : 0.366
# unpriv FPR : 0.381
# diff FPR : 0.015
#
# overall ACC : 0.584
# priv ACC : 0.561
# unpriv ACC : 0.596
# diff ACC : 0.035
#
#
#
# DIMP : 0.856
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.689973] [D_R loss: 0.786437] [G loss: 0.265762]
# VALID DATA
# overall TPR : 0.542
# priv TPR : 0.566
# unpriv TPR : 0.483
# Eq. Opp : 0.083
#
# overall FPR : 0.360
# priv FPR : 0.427
# unpriv FPR : 0.323
# diff FPR : 0.104
#
# overall ACC : 0.595
# priv ACC : 0.536
# unpriv ACC : 0.623
# diff ACC : 0.086
#
#
#
# TEST DATA
# overall TPR : 0.508
# priv TPR : 0.531
# unpriv TPR : 0.458
# Eq. Opp : 0.074
#
# overall FPR : 0.359
# priv FPR : 0.369
# unpriv FPR : 0.353
# diff FPR : 0.017
#
# overall ACC : 0.586
# priv ACC : 0.565
# unpriv ACC : 0.597
# diff ACC : 0.031
#
#
#
# DIMP : 0.935
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.676122] [D_R loss: 0.979240] [G loss: 26.418261]
# VALID DATA
# overall TPR : 0.147
# priv TPR : 0.154
# unpriv TPR : 0.125
# Eq. Opp : 0.029
#
# overall FPR : 0.190
# priv FPR : 0.107
# unpriv FPR : 0.243
# diff FPR : 0.135
#
# overall ACC : 0.518
# priv ACC : 0.640
# unpriv ACC : 0.459
# diff ACC : 0.182
#
#
#
# TEST DATA
# overall TPR : 0.116
# priv TPR : 0.139
# unpriv TPR : 0.070
# Eq. Opp : 0.069
#
# overall FPR : 0.161
# priv FPR : 0.090
# unpriv FPR : 0.208
# diff FPR : 0.118
#
# overall ACC : 0.498
# priv ACC : 0.548
# unpriv ACC : 0.468
# diff ACC : 0.080
#
#
#
# DIMP : 0.468
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.690366] [D_R loss: 0.680270] [G loss: 0.289672]
# VALID DATA
# overall TPR : 0.507
# priv TPR : 0.500
# unpriv TPR : 0.531
# Eq. Opp : 0.031
#
# overall FPR : 0.321
# priv FPR : 0.398
# unpriv FPR : 0.270
# diff FPR : 0.128
#
# overall ACC : 0.602
# priv ACC : 0.578
# unpriv ACC : 0.613
# diff ACC : 0.035
#
#
#
# TEST DATA
# overall TPR : 0.518
# priv TPR : 0.522
# unpriv TPR : 0.511
# Eq. Opp : 0.011
#
# overall FPR : 0.333
# priv FPR : 0.435
# unpriv FPR : 0.264
# diff FPR : 0.171
#
# overall ACC : 0.597
# priv ACC : 0.542
# unpriv ACC : 0.630
# diff ACC : 0.088
#
#
#
# DIMP : 0.838
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.690848] [D_R loss: 1.146845] [G loss: 0.236234]
# VALID DATA
# overall TPR : 0.602
# priv TPR : 0.603
# unpriv TPR : 0.598
# Eq. Opp : 0.005
#
# overall FPR : 0.413
# priv FPR : 0.515
# unpriv FPR : 0.344
# diff FPR : 0.171
#
# overall ACC : 0.594
# priv ACC : 0.522
# unpriv ACC : 0.629
# diff ACC : 0.107
#
#
#
# TEST DATA
# overall TPR : 0.620
# priv TPR : 0.628
# unpriv TPR : 0.603
# Eq. Opp : 0.025
#
# overall FPR : 0.425
# priv FPR : 0.513
# unpriv FPR : 0.365
# diff FPR : 0.148
#
# overall ACC : 0.596
# priv ACC : 0.536
# unpriv ACC : 0.632
# diff ACC : 0.096
#
#
#
# DIMP : 0.898
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.688456] [D_R loss: 0.945884] [G loss: 0.268160]
# VALID DATA
# overall TPR : 0.582
# priv TPR : 0.587
# unpriv TPR : 0.566
# Eq. Opp : 0.022
#
# overall FPR : 0.399
# priv FPR : 0.523
# unpriv FPR : 0.318
# diff FPR : 0.205
#
# overall ACC : 0.593
# priv ACC : 0.507
# unpriv ACC : 0.635
# diff ACC : 0.128
#
#
#
# TEST DATA
# overall TPR : 0.584
# priv TPR : 0.582
# unpriv TPR : 0.589
# Eq. Opp : 0.007
#
# overall FPR : 0.421
# priv FPR : 0.510
# unpriv FPR : 0.359
# diff FPR : 0.151
#
# overall ACC : 0.581
# priv ACC : 0.532
# unpriv ACC : 0.611
# diff ACC : 0.079
#
#
#
# DIMP : 0.866
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688719] [D_R loss: 0.924065] [G loss: 0.108533]
# VALID DATA
# overall TPR : 0.549
# priv TPR : 0.580
# unpriv TPR : 0.455
# Eq. Opp : 0.125
#
# overall FPR : 0.382
# priv FPR : 0.464
# unpriv FPR : 0.329
# diff FPR : 0.135
#
# overall ACC : 0.587
# priv ACC : 0.508
# unpriv ACC : 0.626
# diff ACC : 0.117
#
#
#
# TEST DATA
# overall TPR : 0.543
# priv TPR : 0.554
# unpriv TPR : 0.521
# Eq. Opp : 0.032
#
# overall FPR : 0.378
# priv FPR : 0.438
# unpriv FPR : 0.337
# diff FPR : 0.101
#
# overall ACC : 0.585
# priv ACC : 0.545
# unpriv ACC : 0.609
# diff ACC : 0.064
#
#
#
# DIMP : 0.940
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.591190] [D_R loss: 0.214648] [G loss: 21.641088]
# VALID DATA
# overall TPR : 0.035
# priv TPR : 0.014
# unpriv TPR : 0.083
# Eq. Opp : 0.069
#
# overall FPR : 0.038
# priv FPR : 0.061
# unpriv FPR : 0.025
# diff FPR : 0.036
#
# overall ACC : 0.551
# priv ACC : 0.595
# unpriv ACC : 0.529
# diff ACC : 0.066
#
#
#
# TEST DATA
# overall TPR : 0.018
# priv TPR : 0.000
# unpriv TPR : 0.064
# Eq. Opp : 0.064
#
# overall FPR : 0.028
# priv FPR : 0.062
# unpriv FPR : 0.007
# diff FPR : 0.055
#
# overall ACC : 0.549
# priv ACC : 0.623
# unpriv ACC : 0.511
# diff ACC : 0.112
#
#
#
# DIMP : 0.054
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.655355] [D_R loss: 0.726238] [G loss: 0.338722]
# VALID DATA
# overall TPR : 0.609
# priv TPR : 0.598
# unpriv TPR : 0.636
# Eq. Opp : 0.038
#
# overall FPR : 0.429
# priv FPR : 0.497
# unpriv FPR : 0.390
# diff FPR : 0.107
#
# overall ACC : 0.588
# priv ACC : 0.556
# unpriv ACC : 0.604
# diff ACC : 0.048
#
#
#
# TEST DATA
# overall TPR : 0.616
# priv TPR : 0.602
# unpriv TPR : 0.651
# Eq. Opp : 0.049
#
# overall FPR : 0.412
# priv FPR : 0.450
# unpriv FPR : 0.388
# diff FPR : 0.063
#
# overall ACC : 0.600
# priv ACC : 0.587
# unpriv ACC : 0.607
# diff ACC : 0.021
#
#
#
# DIMP : 0.939
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.717916] [D_R loss: 0.957304] [G loss: 1.104181]
# VALID DATA
# overall TPR : 0.586
# priv TPR : 0.599
# unpriv TPR : 0.554
# Eq. Opp : 0.046
#
# overall FPR : 0.450
# priv FPR : 0.525
# unpriv FPR : 0.408
# diff FPR : 0.117
#
# overall ACC : 0.566
# priv ACC : 0.507
# unpriv ACC : 0.595
# diff ACC : 0.089
#
#
#
# TEST DATA
# overall TPR : 0.637
# priv TPR : 0.644
# unpriv TPR : 0.619
# Eq. Opp : 0.024
#
# overall FPR : 0.385
# priv FPR : 0.437
# unpriv FPR : 0.352
# diff FPR : 0.085
#
# overall ACC : 0.625
# priv ACC : 0.584
# unpriv ACC : 0.646
# diff ACC : 0.062
#
#
#
# DIMP : 0.979
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.687810] [D_R loss: 1.007450] [G loss: 0.797959]
# VALID DATA
# overall TPR : 0.606
# priv TPR : 0.601
# unpriv TPR : 0.617
# Eq. Opp : 0.015
#
# overall FPR : 0.456
# priv FPR : 0.586
# unpriv FPR : 0.382
# diff FPR : 0.203
#
# overall ACC : 0.571
# priv ACC : 0.495
# unpriv ACC : 0.610
# diff ACC : 0.115
#
#
#
# TEST DATA
# overall TPR : 0.639
# priv TPR : 0.615
# unpriv TPR : 0.703
# Eq. Opp : 0.088
#
# overall FPR : 0.477
# priv FPR : 0.592
# unpriv FPR : 0.405
# diff FPR : 0.186
#
# overall ACC : 0.575
# priv ACC : 0.517
# unpriv ACC : 0.604
# diff ACC : 0.088
#
#
#
# DIMP : 0.801
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.691099] [D_R loss: 0.847971] [G loss: 0.450386]
# VALID DATA
# overall TPR : 0.603
# priv TPR : 0.649
# unpriv TPR : 0.500
# Eq. Opp : 0.149
#
# overall FPR : 0.404
# priv FPR : 0.385
# unpriv FPR : 0.414
# diff FPR : 0.028
#
# overall ACC : 0.599
# priv ACC : 0.568
# unpriv ACC : 0.615
# diff ACC : 0.047
#
#
#
# TEST DATA
# overall TPR : 0.610
# priv TPR : 0.625
# unpriv TPR : 0.569
# Eq. Opp : 0.057
#
# overall FPR : 0.363
# priv FPR : 0.380
# unpriv FPR : 0.352
# diff FPR : 0.028
#
# overall ACC : 0.625
# priv ACC : 0.601
# unpriv ACC : 0.637
# diff ACC : 0.036
#
#
#
# DIMP : 0.923
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.606798] [D_R loss: 2.057556] [G loss: 15.360923]
# VALID DATA
# overall TPR : 0.213
# priv TPR : 0.096
# unpriv TPR : 0.518
# Eq. Opp : 0.422
#
# overall FPR : 0.201
# priv FPR : 0.422
# unpriv FPR : 0.081
# diff FPR : 0.341
#
# overall ACC : 0.536
# priv ACC : 0.554
# unpriv ACC : 0.527
# diff ACC : 0.027
#
#
#
# TEST DATA
# overall TPR : 0.221
# priv TPR : 0.117
# unpriv TPR : 0.491
# Eq. Opp : 0.375
#
# overall FPR : 0.200
# priv FPR : 0.422
# unpriv FPR : 0.067
# diff FPR : 0.356
#
# overall ACC : 0.531
# priv ACC : 0.544
# unpriv ACC : 0.525
# diff ACC : 0.019
#
#
#
# DIMP : 0.204
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.771739] [D_R loss: 0.810952] [G loss: 1.150196]
# VALID DATA
# overall TPR : 0.620
# priv TPR : 0.624
# unpriv TPR : 0.609
# Eq. Opp : 0.015
#
# overall FPR : 0.436
# priv FPR : 0.549
# unpriv FPR : 0.374
# diff FPR : 0.175
#
# overall ACC : 0.589
# priv ACC : 0.512
# unpriv ACC : 0.625
# diff ACC : 0.112
#
#
#
# TEST DATA
# overall TPR : 0.606
# priv TPR : 0.604
# unpriv TPR : 0.610
# Eq. Opp : 0.006
#
# overall FPR : 0.442
# priv FPR : 0.542
# unpriv FPR : 0.383
# diff FPR : 0.160
#
# overall ACC : 0.580
# priv ACC : 0.519
# unpriv ACC : 0.611
# diff ACC : 0.092
#
#
#
# DIMP : 0.868
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.704717] [D_R loss: 0.859967] [G loss: 0.352483]
# VALID DATA
# overall TPR : 0.605
# priv TPR : 0.598
# unpriv TPR : 0.625
# Eq. Opp : 0.027
#
# overall FPR : 0.396
# priv FPR : 0.560
# unpriv FPR : 0.305
# diff FPR : 0.255
#
# overall ACC : 0.605
# priv ACC : 0.512
# unpriv ACC : 0.649
# diff ACC : 0.136
#
#
#
# TEST DATA
# overall TPR : 0.579
# priv TPR : 0.595
# unpriv TPR : 0.539
# Eq. Opp : 0.056
#
# overall FPR : 0.383
# priv FPR : 0.564
# unpriv FPR : 0.276
# diff FPR : 0.288
#
# overall ACC : 0.599
# priv ACC : 0.476
# unpriv ACC : 0.659
# diff ACC : 0.183
#
#
#
# DIMP : 0.785
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.691089] [D_R loss: 0.878625] [G loss: 0.660292]
# VALID DATA
# overall TPR : 0.600
# priv TPR : 0.592
# unpriv TPR : 0.622
# Eq. Opp : 0.030
#
# overall FPR : 0.403
# priv FPR : 0.561
# unpriv FPR : 0.318
# diff FPR : 0.243
#
# overall ACC : 0.598
# priv ACC : 0.511
# unpriv ACC : 0.639
# diff ACC : 0.128
#
#
#
# TEST DATA
# overall TPR : 0.581
# priv TPR : 0.587
# unpriv TPR : 0.565
# Eq. Opp : 0.022
#
# overall FPR : 0.383
# priv FPR : 0.589
# unpriv FPR : 0.261
# diff FPR : 0.328
#
# overall ACC : 0.600
# priv ACC : 0.471
# unpriv ACC : 0.664
# diff ACC : 0.193
#
#
#
# DIMP : 0.729
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.687817] [D_R loss: 0.845642] [G loss: 0.248542]
# VALID DATA
# overall TPR : 0.431
# priv TPR : 0.473
# unpriv TPR : 0.321
# Eq. Opp : 0.152
#
# overall FPR : 0.265
# priv FPR : 0.257
# unpriv FPR : 0.269
# diff FPR : 0.012
#
# overall ACC : 0.599
# priv ACC : 0.581
# unpriv ACC : 0.608
# diff ACC : 0.027
#
#
#
# TEST DATA
# overall TPR : 0.449
# priv TPR : 0.527
# unpriv TPR : 0.250
# Eq. Opp : 0.277
#
# overall FPR : 0.251
# priv FPR : 0.274
# unpriv FPR : 0.238
# diff FPR : 0.036
#
# overall ACC : 0.610
# priv ACC : 0.539
# unpriv ACC : 0.646
# diff ACC : 0.107
#
#
#
# DIMP : 0.694
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.609173] [D_R loss: 0.357524] [G loss: 8.671043]
# VALID DATA
# overall TPR : 0.229
# priv TPR : 0.181
# unpriv TPR : 0.344
# Eq. Opp : 0.163
#
# overall FPR : 0.216
# priv FPR : 0.329
# unpriv FPR : 0.150
# diff FPR : 0.179
#
# overall ACC : 0.522
# priv ACC : 0.534
# unpriv ACC : 0.517
# diff ACC : 0.017
#
#
#
# TEST DATA
# overall TPR : 0.203
# priv TPR : 0.138
# unpriv TPR : 0.361
# Eq. Opp : 0.223
#
# overall FPR : 0.199
# priv FPR : 0.318
# unpriv FPR : 0.115
# diff FPR : 0.203
#
# overall ACC : 0.529
# priv ACC : 0.562
# unpriv ACC : 0.510
# diff ACC : 0.052
#
#
#
# DIMP : 0.379
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.691776] [D_R loss: 1.073154] [G loss: 0.252564]
# VALID DATA
# overall TPR : 0.496
# priv TPR : 0.477
# unpriv TPR : 0.546
# Eq. Opp : 0.069
#
# overall FPR : 0.379
# priv FPR : 0.506
# unpriv FPR : 0.303
# diff FPR : 0.203
#
# overall ACC : 0.562
# priv ACC : 0.515
# unpriv ACC : 0.586
# diff ACC : 0.071
#
#
#
# TEST DATA
# overall TPR : 0.527
# priv TPR : 0.526
# unpriv TPR : 0.529
# Eq. Opp : 0.003
#
# overall FPR : 0.362
# priv FPR : 0.417
# unpriv FPR : 0.321
# diff FPR : 0.096
#
# overall ACC : 0.587
# priv ACC : 0.563
# unpriv ACC : 0.601
# diff ACC : 0.038
#
#
#
# DIMP : 0.927
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.694269] [D_R loss: 1.220577] [G loss: 0.260448]
# VALID DATA
# overall TPR : 0.616
# priv TPR : 0.570
# unpriv TPR : 0.728
# Eq. Opp : 0.158
#
# overall FPR : 0.475
# priv FPR : 0.625
# unpriv FPR : 0.386
# diff FPR : 0.239
#
# overall ACC : 0.568
# priv ACC : 0.522
# unpriv ACC : 0.592
# diff ACC : 0.070
#
#
#
# TEST DATA
# overall TPR : 0.640
# priv TPR : 0.635
# unpriv TPR : 0.653
# Eq. Opp : 0.017
#
# overall FPR : 0.476
# priv FPR : 0.592
# unpriv FPR : 0.391
# diff FPR : 0.201
#
# overall ACC : 0.577
# priv ACC : 0.497
# unpriv ACC : 0.622
# diff ACC : 0.125
#
#
#
# DIMP : 0.837
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.688393] [D_R loss: 1.029066] [G loss: 0.259230]
# VALID DATA
# overall TPR : 0.664
# priv TPR : 0.611
# unpriv TPR : 0.792
# Eq. Opp : 0.181
#
# overall FPR : 0.579
# priv FPR : 0.754
# unpriv FPR : 0.474
# diff FPR : 0.280
#
# overall ACC : 0.537
# priv ACC : 0.473
# unpriv ACC : 0.569
# diff ACC : 0.095
#
#
#
# TEST DATA
# ...
# VALID DATA
# overall TPR : 0.587
# priv TPR : 0.588
# unpriv TPR : 0.587
# Eq. Opp : 0.001
#
# overall FPR : 0.387
# priv FPR : 0.438
# unpriv FPR : 0.354
# diff FPR : 0.084
#
# overall ACC : 0.602
# priv ACC : 0.571
# unpriv ACC : 0.618
# diff ACC : 0.046
#
#
#
# TEST DATA
# overall TPR : 0.623
# priv TPR : 0.603
# unpriv TPR : 0.682
# Eq. Opp : 0.079
#
# overall FPR : 0.420
# priv FPR : 0.558
# unpriv FPR : 0.334
# diff FPR : 0.224
#
# overall ACC : 0.600
# priv ACC : 0.531
# unpriv ACC : 0.633
# diff ACC : 0.102
#
#
#
# DIMP : 0.784
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.692903] [D_R loss: 0.920030] [G loss: 0.368629]
# VALID DATA
# overall TPR : 0.513
# priv TPR : 0.507
# unpriv TPR : 0.525
# Eq. Opp : 0.017
#
# overall FPR : 0.382
# priv FPR : 0.485
# unpriv FPR : 0.315
# diff FPR : 0.170
#
# overall ACC : 0.571
# priv ACC : 0.519
# unpriv ACC : 0.601
# diff ACC : 0.082
#
#
#
# TEST DATA
# overall TPR : 0.511
# priv TPR : 0.506
# unpriv TPR : 0.523
# Eq. Opp : 0.017
#
# overall FPR : 0.341
# priv FPR : 0.511
# unpriv FPR : 0.235
# diff FPR : 0.275
#
# overall ACC : 0.589
# priv ACC : 0.502
# unpriv ACC : 0.631
# diff ACC : 0.130
#
#
#
# DIMP : 0.728
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688313] [D_R loss: 1.021678] [G loss: 0.218626]
# VALID DATA
# overall TPR : 0.667
# priv TPR : 0.658
# unpriv TPR : 0.686
# Eq. Opp : 0.028
#
# overall FPR : 0.455
# priv FPR : 0.490
# unpriv FPR : 0.433
# diff FPR : 0.057
#
# overall ACC : 0.598
# priv ACC : 0.577
# unpriv ACC : 0.610
# diff ACC : 0.033
#
#
#
# TEST DATA
# overall TPR : 0.656
# priv TPR : 0.652
# unpriv TPR : 0.667
# Eq. Opp : 0.015
#
# overall FPR : 0.479
# priv FPR : 0.617
# unpriv FPR : 0.394
# diff FPR : 0.223
#
# overall ACC : 0.585
# priv ACC : 0.491
# unpriv ACC : 0.630
# diff ACC : 0.138
#
#
#
# DIMP : 0.829
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.715178] [D_R loss: 0.560377] [G loss: 21.963142]
# VALID DATA
# overall TPR : 0.087
# priv TPR : 0.084
# unpriv TPR : 0.094
# Eq. Opp : 0.010
#
# overall FPR : 0.168
# priv FPR : 0.196
# unpriv FPR : 0.151
# diff FPR : 0.045
#
# overall ACC : 0.498
# priv ACC : 0.503
# unpriv ACC : 0.495
# diff ACC : 0.008
#
#
#
# TEST DATA
# overall TPR : 0.075
# priv TPR : 0.079
# unpriv TPR : 0.062
# Eq. Opp : 0.017
#
# overall FPR : 0.146
# priv FPR : 0.139
# unpriv FPR : 0.150
# diff FPR : 0.011
#
# overall ACC : 0.493
# priv ACC : 0.555
# unpriv ACC : 0.464
# diff ACC : 0.091
#
#
#
# DIMP : 0.959
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.686601] [D_R loss: 0.878016] [G loss: 0.436729]
# VALID DATA
# overall TPR : 0.650
# priv TPR : 0.645
# unpriv TPR : 0.660
# Eq. Opp : 0.014
#
# overall FPR : 0.524
# priv FPR : 0.636
# unpriv FPR : 0.455
# diff FPR : 0.181
#
# overall ACC : 0.555
# priv ACC : 0.491
# unpriv ACC : 0.592
# diff ACC : 0.101
#
#
#
# TEST DATA
# overall TPR : 0.646
# priv TPR : 0.661
# unpriv TPR : 0.605
# Eq. Opp : 0.056
#
# overall FPR : 0.481
# priv FPR : 0.624
# unpriv FPR : 0.397
# diff FPR : 0.227
#
# overall ACC : 0.578
# priv ACC : 0.466
# unpriv ACC : 0.632
# diff ACC : 0.167
#
#
#
# DIMP : 0.859
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.689428] [D_R loss: 1.002970] [G loss: 0.465306]
# VALID DATA
# overall TPR : 0.673
# priv TPR : 0.673
# unpriv TPR : 0.674
# Eq. Opp : 0.001
#
# overall FPR : 0.543
# priv FPR : 0.639
# unpriv FPR : 0.485
# diff FPR : 0.154
#
# overall ACC : 0.555
# priv ACC : 0.498
# unpriv ACC : 0.587
# diff ACC : 0.089
#
#
#
# TEST DATA
# overall TPR : 0.710
# priv TPR : 0.723
# unpriv TPR : 0.675
# Eq. Opp : 0.048
#
# overall FPR : 0.512
# priv FPR : 0.614
# unpriv FPR : 0.452
# diff FPR : 0.162
#
# overall ACC : 0.593
# priv ACC : 0.500
# unpriv ACC : 0.637
# diff ACC : 0.137
#
#
#
# DIMP : 0.923
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.690958] [D_R loss: 0.915064] [G loss: 0.279938]
# VALID DATA
# overall TPR : 0.430
# priv TPR : 0.460
# unpriv TPR : 0.376
# Eq. Opp : 0.084
#
# overall FPR : 0.304
# priv FPR : 0.340
# unpriv FPR : 0.281
# diff FPR : 0.060
#
# overall ACC : 0.577
# priv ACC : 0.539
# unpriv ACC : 0.599
# diff ACC : 0.060
#
#
#
# TEST DATA
# overall TPR : 0.461
# priv TPR : 0.508
# unpriv TPR : 0.330
# Eq. Opp : 0.178
#
# overall FPR : 0.243
# priv FPR : 0.258
# unpriv FPR : 0.234
# diff FPR : 0.025
#
# overall ACC : 0.622
# priv ACC : 0.588
# unpriv ACC : 0.638
# diff ACC : 0.050
#
#
#
# DIMP : 0.770
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688653] [D_R loss: 0.860867] [G loss: 0.214796]
# VALID DATA
# overall TPR : 0.490
# priv TPR : 0.492
# unpriv TPR : 0.486
# Eq. Opp : 0.007
#
# overall FPR : 0.390
# priv FPR : 0.495
# unpriv FPR : 0.326
# diff FPR : 0.169
#
# overall ACC : 0.556
# priv ACC : 0.497
# unpriv ACC : 0.590
# diff ACC : 0.093
#
#
#
# TEST DATA
# overall TPR : 0.477
# priv TPR : 0.480
# unpriv TPR : 0.469
# Eq. Opp : 0.011
#
# overall FPR : 0.328
# priv FPR : 0.438
# unpriv FPR : 0.264
# diff FPR : 0.174
#
# overall ACC : 0.581
# priv ACC : 0.526
# unpriv ACC : 0.608
# diff ACC : 0.082
#
#
#
# DIMP : 0.826
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.691020] [D_R loss: 0.208459] [G loss: 30.432570]
# VALID DATA
# overall TPR : 0.002
# priv TPR : 0.003
# unpriv TPR : 0.000
# Eq. Opp : 0.003
#
# overall FPR : 0.006
# priv FPR : 0.000
# unpriv FPR : 0.010
# diff FPR : 0.010
#
# overall ACC : 0.537
# priv ACC : 0.626
# unpriv ACC : 0.492
# diff ACC : 0.134
#
#
#
# TEST DATA
# overall TPR : 0.002
# priv TPR : 0.003
# unpriv TPR : 0.000
# Eq. Opp : 0.003
#
# overall FPR : 0.002
# priv FPR : 0.000
# unpriv FPR : 0.003
# diff FPR : 0.003
#
# overall ACC : 0.549
# priv ACC : 0.617
# unpriv ACC : 0.514
# diff ACC : 0.103
#
#
#
# DIMP : 0.000
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.704079] [D_R loss: 0.999902] [G loss: 2.284444]
# VALID DATA
# overall TPR : 0.623
# priv TPR : 0.635
# unpriv TPR : 0.591
# Eq. Opp : 0.044
#
# overall FPR : 0.483
# priv FPR : 0.641
# unpriv FPR : 0.379
# diff FPR : 0.261
#
# overall ACC : 0.566
# priv ACC : 0.446
# unpriv ACC : 0.628
# diff ACC : 0.182
#
#
#
# TEST DATA
# overall TPR : 0.608
# priv TPR : 0.597
# unpriv TPR : 0.635
# Eq. Opp : 0.038
#
# overall FPR : 0.508
# priv FPR : 0.601
# unpriv FPR : 0.449
# diff FPR : 0.152
#
# overall ACC : 0.544
# priv ACC : 0.487
# unpriv ACC : 0.573
# diff ACC : 0.086
#
#
#
# DIMP : 0.848
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.692333] [D_R loss: 0.984224] [G loss: 0.905855]
# VALID DATA
# overall TPR : 0.691
# priv TPR : 0.708
# unpriv TPR : 0.645
# Eq. Opp : 0.063
#
# overall FPR : 0.533
# priv FPR : 0.654
# unpriv FPR : 0.457
# diff FPR : 0.198
#
# overall ACC : 0.569
# priv ACC : 0.454
# unpriv ACC : 0.626
# diff ACC : 0.171
#
#
#
# TEST DATA
# overall TPR : 0.662
# priv TPR : 0.654
# unpriv TPR : 0.681
# Eq. Opp : 0.028
#
# overall FPR : 0.584
# priv FPR : 0.637
# unpriv FPR : 0.548
# diff FPR : 0.088
#
# overall ACC : 0.525
# priv ACC : 0.478
# unpriv ACC : 0.550
# diff ACC : 0.072
#
#
#
# DIMP : 0.918
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.688144] [D_R loss: 0.721156] [G loss: 0.379500]
# VALID DATA
# overall TPR : 0.679
# priv TPR : 0.679
# unpriv TPR : 0.679
# Eq. Opp : 0.001
#
# overall FPR : 0.509
# priv FPR : 0.670
# unpriv FPR : 0.407
# diff FPR : 0.263
#
# overall ACC : 0.576
# priv ACC : 0.459
# unpriv ACC : 0.636
# diff ACC : 0.177
#
#
#
# TEST DATA
# overall TPR : 0.661
# priv TPR : 0.653
# unpriv TPR : 0.681
# Eq. Opp : 0.028
#
# overall FPR : 0.576
# priv FPR : 0.706
# unpriv FPR : 0.490
# diff FPR : 0.216
#
# overall ACC : 0.530
# priv ACC : 0.438
# unpriv ACC : 0.580
# diff ACC : 0.142
#
#
#
# DIMP : 0.818
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.691032] [D_R loss: 0.847664] [G loss: 0.243166]
# VALID DATA
# overall TPR : 0.650
# priv TPR : 0.648
# unpriv TPR : 0.654
# Eq. Opp : 0.006
#
# overall FPR : 0.490
# priv FPR : 0.670
# unpriv FPR : 0.377
# diff FPR : 0.294
#
# overall ACC : 0.574
# priv ACC : 0.447
# unpriv ACC : 0.636
# diff ACC : 0.188
#
#
#
# TEST DATA
# overall TPR : 0.636
# priv TPR : 0.631
# unpriv TPR : 0.649
# Eq. Opp : 0.018
#
# overall FPR : 0.518
# priv FPR : 0.662
# unpriv FPR : 0.421
# diff FPR : 0.240
#
# overall ACC : 0.550
# priv ACC : 0.451
# unpriv ACC : 0.604
# diff ACC : 0.153
#
#
#
# DIMP : 0.796
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.696284] [D_R loss: 0.218674] [G loss: 31.724720]
# VALID DATA
# overall TPR : 0.056
# priv TPR : 0.079
# unpriv TPR : 0.000
# Eq. Opp : 0.079
#
# overall FPR : 0.047
# priv FPR : 0.000
# unpriv FPR : 0.075
# diff FPR : 0.075
#
# overall ACC : 0.528
# priv ACC : 0.597
# unpriv ACC : 0.493
# diff ACC : 0.104
#
#
#
# TEST DATA
# overall TPR : 0.081
# priv TPR : 0.115
# unpriv TPR : 0.000
# Eq. Opp : 0.115
#
# overall FPR : 0.037
# priv FPR : 0.000
# unpriv FPR : 0.062
# diff FPR : 0.062
#
# overall ACC : 0.585
# priv ACC : 0.644
# unpriv ACC : 0.552
# diff ACC : 0.092
#
#
#
# DIMP : 0.000
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.690769] [D_R loss: 0.755610] [G loss: 3.980839]
# VALID DATA
# overall TPR : 0.485
# priv TPR : 0.495
# unpriv TPR : 0.459
# Eq. Opp : 0.036
#
# overall FPR : 0.324
# priv FPR : 0.303
# unpriv FPR : 0.337
# diff FPR : 0.034
#
# overall ACC : 0.585
# priv ACC : 0.599
# unpriv ACC : 0.578
# diff ACC : 0.022
#
#
#
# TEST DATA
# overall TPR : 0.447
# priv TPR : 0.504
# unpriv TPR : 0.310
# Eq. Opp : 0.194
#
# overall FPR : 0.319
# priv FPR : 0.325
# unpriv FPR : 0.315
# diff FPR : 0.010
#
# overall ACC : 0.580
# priv ACC : 0.544
# unpriv ACC : 0.600
# diff ACC : 0.056
#
#
#
# DIMP : 0.792
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.689186] [D_R loss: 0.800539] [G loss: 0.253563]
# VALID DATA
# overall TPR : 0.619
# priv TPR : 0.606
# unpriv TPR : 0.653
# Eq. Opp : 0.047
#
# overall FPR : 0.490
# priv FPR : 0.549
# unpriv FPR : 0.456
# diff FPR : 0.092
#
# overall ACC : 0.561
# priv ACC : 0.534
# unpriv ACC : 0.575
# diff ACC : 0.041
#
#
#
# TEST DATA
# overall TPR : 0.648
# priv TPR : 0.673
# unpriv TPR : 0.591
# Eq. Opp : 0.082
#
# overall FPR : 0.510
# priv FPR : 0.519
# unpriv FPR : 0.503
# diff FPR : 0.016
#
# overall ACC : 0.558
# priv ACC : 0.520
# unpriv ACC : 0.579
# diff ACC : 0.059
#
#
#
# DIMP : 0.936
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.689005] [D_R loss: 0.887985] [G loss: 0.232662]
# VALID DATA
# overall TPR : 0.566
# priv TPR : 0.535
# unpriv TPR : 0.645
# Eq. Opp : 0.110
#
# overall FPR : 0.430
# priv FPR : 0.576
# unpriv FPR : 0.343
# diff FPR : 0.233
#
# overall ACC : 0.568
# priv ACC : 0.513
# unpriv ACC : 0.595
# diff ACC : 0.082
#
#
#
# TEST DATA
# overall TPR : 0.598
# priv TPR : 0.615
# unpriv TPR : 0.558
# Eq. Opp : 0.057
#
# overall FPR : 0.470
# priv FPR : 0.556
# unpriv FPR : 0.413
# diff FPR : 0.144
#
# overall ACC : 0.559
# priv ACC : 0.484
# unpriv ACC : 0.600
# diff ACC : 0.116
#
#
#
# DIMP : 0.914
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.687361] [D_R loss: 0.811833] [G loss: 0.291541]
# VALID DATA
# overall TPR : 0.606
# priv TPR : 0.607
# unpriv TPR : 0.603
# Eq. Opp : 0.003
#
# overall FPR : 0.432
# priv FPR : 0.567
# unpriv FPR : 0.350
# diff FPR : 0.217
#
# overall ACC : 0.586
# priv ACC : 0.502
# unpriv ACC : 0.628
# diff ACC : 0.126
#
#
#
# TEST DATA
# overall TPR : 0.609
# priv TPR : 0.644
# unpriv TPR : 0.523
# Eq. Opp : 0.122
#
# overall FPR : 0.445
# priv FPR : 0.541
# unpriv FPR : 0.380
# diff FPR : 0.161
#
# overall ACC : 0.578
# priv ACC : 0.481
# unpriv ACC : 0.631
# diff ACC : 0.150
#
#
#
# DIMP : 0.942
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.653042] [D_R loss: 0.164774] [G loss: 17.345537]
# VALID DATA
# overall TPR : 0.024
# priv TPR : 0.034
# unpriv TPR : 0.000
# Eq. Opp : 0.034
#
# overall FPR : 0.035
# priv FPR : 0.000
# unpriv FPR : 0.060
# diff FPR : 0.060
#
# overall ACC : 0.528
# priv ACC : 0.621
# unpriv ACC : 0.478
# diff ACC : 0.143
#
#
#
# TEST DATA
# overall TPR : 0.042
# priv TPR : 0.060
# unpriv TPR : 0.000
# Eq. Opp : 0.060
#
# overall FPR : 0.045
# priv FPR : 0.000
# unpriv FPR : 0.070
# diff FPR : 0.070
#
# overall ACC : 0.540
# priv ACC : 0.581
# unpriv ACC : 0.519
# diff ACC : 0.062
#
#
#
# DIMP : 0.000
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.719983] [D_R loss: 0.753223] [G loss: 6.332395]
# VALID DATA
# overall TPR : 0.371
# priv TPR : 0.383
# unpriv TPR : 0.344
# Eq. Opp : 0.038
#
# overall FPR : 0.334
# priv FPR : 0.389
# unpriv FPR : 0.297
# diff FPR : 0.092
#
# overall ACC : 0.528
# priv ACC : 0.506
# unpriv ACC : 0.539
# diff ACC : 0.033
#
#
#
# TEST DATA
# overall TPR : 0.424
# priv TPR : 0.441
# unpriv TPR : 0.385
# Eq. Opp : 0.056
#
# overall FPR : 0.339
# priv FPR : 0.363
# unpriv FPR : 0.325
# diff FPR : 0.038
#
# overall ACC : 0.555
# priv ACC : 0.535
# unpriv ACC : 0.565
# diff ACC : 0.030
#
#
#
# DIMP : 0.980
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.681840] [D_R loss: 0.769424] [G loss: 2.276685]
# VALID DATA
# overall TPR : 0.571
# priv TPR : 0.580
# unpriv TPR : 0.549
# Eq. Opp : 0.031
#
# overall FPR : 0.470
# priv FPR : 0.562
# unpriv FPR : 0.408
# diff FPR : 0.155
#
# overall ACC : 0.549
# priv ACC : 0.481
# unpriv ACC : 0.586
# diff ACC : 0.105
#
#
#
# TEST DATA
# overall TPR : 0.561
# priv TPR : 0.550
# unpriv TPR : 0.585
# Eq. Opp : 0.035
#
# overall FPR : 0.430
# priv FPR : 0.542
# unpriv FPR : 0.366
# diff FPR : 0.176
#
# overall ACC : 0.566
# priv ACC : 0.510
# unpriv ACC : 0.594
# diff ACC : 0.084
#
#
#
# DIMP : 0.809
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.689141] [D_R loss: 0.733316] [G loss: 0.354226]
# VALID DATA
# overall TPR : 0.618
# priv TPR : 0.617
# unpriv TPR : 0.622
# Eq. Opp : 0.005
#
# overall FPR : 0.407
# priv FPR : 0.458
# unpriv FPR : 0.373
# diff FPR : 0.085
#
# overall ACC : 0.605
# priv ACC : 0.573
# unpriv ACC : 0.622
# diff ACC : 0.049
#
#
#
# TEST DATA
# overall TPR : 0.577
# priv TPR : 0.556
# unpriv TPR : 0.624
# Eq. Opp : 0.068
#
# overall FPR : 0.343
# priv FPR : 0.410
# unpriv FPR : 0.306
# diff FPR : 0.104
#
# overall ACC : 0.621
# priv ACC : 0.604
# unpriv ACC : 0.629
# diff ACC : 0.025
#
#
#
# DIMP : 0.849
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.688557] [D_R loss: 0.901415] [G loss: 0.533223]
# VALID DATA
# overall TPR : 0.654
# priv TPR : 0.645
# unpriv TPR : 0.675
# Eq. Opp : 0.030
#
# overall FPR : 0.553
# priv FPR : 0.618
# unpriv FPR : 0.510
# diff FPR : 0.107
#
# overall ACC : 0.544
# priv ACC : 0.495
# unpriv ACC : 0.569
# diff ACC : 0.074
#
#
#
# TEST DATA
# overall TPR : 0.693
# priv TPR : 0.689
# unpriv TPR : 0.702
# Eq. Opp : 0.012
#
# overall FPR : 0.480
# priv FPR : 0.563
# unpriv FPR : 0.434
# diff FPR : 0.129
#
# overall ACC : 0.598
# priv ACC : 0.547
# unpriv ACC : 0.624
# diff ACC : 0.077
#
#
#
# DIMP : 0.892
# [Lambda: 0.100000] [Epoch 10/50] [D_F loss: 0.610762] [D_R loss: 1.021801] [G loss: 16.013720]
# VALID DATA
# overall TPR : 0.247
# priv TPR : 0.226
# unpriv TPR : 0.299
# Eq. Opp : 0.073
#
# overall FPR : 0.224
# priv FPR : 0.310
# unpriv FPR : 0.170
# diff FPR : 0.140
#
# overall ACC : 0.535
# priv ACC : 0.539
# unpriv ACC : 0.532
# diff ACC : 0.007
#
#
#
# TEST DATA
# overall TPR : 0.236
# priv TPR : 0.182
# unpriv TPR : 0.383
# Eq. Opp : 0.202
#
# overall FPR : 0.237
# priv FPR : 0.377
# unpriv FPR : 0.150
# diff FPR : 0.227
#
# overall ACC : 0.528
# priv ACC : 0.537
# unpriv ACC : 0.523
# diff ACC : 0.014
#
#
#
# DIMP : 0.437
# [Lambda: 0.100000] [Epoch 20/50] [D_F loss: 0.687136] [D_R loss: 0.944339] [G loss: 0.902814]
# VALID DATA
# overall TPR : 0.605
# priv TPR : 0.646
# unpriv TPR : 0.500
# Eq. Opp : 0.146
#
# overall FPR : 0.418
# priv FPR : 0.513
# unpriv FPR : 0.359
# diff FPR : 0.155
#
# overall ACC : 0.593
# priv ACC : 0.492
# unpriv ACC : 0.644
# diff ACC : 0.152
#
#
#
# TEST DATA
# overall TPR : 0.570
# priv TPR : 0.556
# unpriv TPR : 0.611
# Eq. Opp : 0.056
#
# overall FPR : 0.450
# priv FPR : 0.532
# unpriv FPR : 0.399
# diff FPR : 0.133
#
# overall ACC : 0.559
# priv ACC : 0.520
# unpriv ACC : 0.578
# diff ACC : 0.058
#
#
#
# DIMP : 0.850
# [Lambda: 0.100000] [Epoch 30/50] [D_F loss: 0.694377] [D_R loss: 0.942147] [G loss: 0.207799]
# VALID DATA
# overall TPR : 0.670
# priv TPR : 0.662
# unpriv TPR : 0.691
# Eq. Opp : 0.029
#
# overall FPR : 0.493
# priv FPR : 0.681
# unpriv FPR : 0.377
# diff FPR : 0.304
#
# overall ACC : 0.580
# priv ACC : 0.456
# unpriv ACC : 0.642
# diff ACC : 0.186
#
#
#
# TEST DATA
# overall TPR : 0.679
# priv TPR : 0.650
# unpriv TPR : 0.759
# Eq. Opp : 0.109
#
# overall FPR : 0.511
# priv FPR : 0.704
# unpriv FPR : 0.393
# diff FPR : 0.311
#
# overall ACC : 0.575
# priv ACC : 0.466
# unpriv ACC : 0.628
# diff ACC : 0.162
#
#
#
# DIMP : 0.718
# [Lambda: 0.100000] [Epoch 40/50] [D_F loss: 0.690709] [D_R loss: 0.782309] [G loss: 0.210711]
# VALID DATA
# overall TPR : 0.560
# priv TPR : 0.568
# unpriv TPR : 0.540
# Eq. Opp : 0.028
#
# overall FPR : 0.386
# priv FPR : 0.471
# unpriv FPR : 0.333
# diff FPR : 0.137
#
# overall ACC : 0.589
# priv ACC : 0.533
# unpriv ACC : 0.617
# diff ACC : 0.084
#
#
#
# TEST DATA
# overall TPR : 0.631
# priv TPR : 0.629
# unpriv TPR : 0.636
# Eq. Opp : 0.006
#
# overall FPR : 0.418
# priv FPR : 0.476
# unpriv FPR : 0.382
# diff FPR : 0.094
#
# overall ACC : 0.604
# priv ACC : 0.564
# unpriv ACC : 0.623
# diff ACC : 0.059
#
#
#
# DIMP : 0.943
# [Lambda: 0.100000] [Epoch 50/50] [D_F loss: 0.686517] [D_R loss: 0.989907] [G loss: 0.228969]
# VALID DATA
# overall TPR : 0.667
# priv TPR : 0.687
# unpriv TPR : 0.615
# Eq. Opp : 0.072
#
# overall FPR : 0.534
# priv FPR : 0.688
# unpriv FPR : 0.438
# diff FPR : 0.250
#
# overall ACC : 0.558
# priv ACC : 0.429
# unpriv ACC : 0.624
# diff ACC : 0.195
#
#
#
# TEST DATA
# overall TPR : 0.682
# priv TPR : 0.672
# unpriv TPR : 0.708
# Eq. Opp : 0.035
#
# overall FPR : 0.547
# priv FPR : 0.674
# unpriv FPR : 0.469
# diff FPR : 0.205
#
# overall ACC : 0.555
# priv ACC : 0.463
# unpriv ACC : 0.600
# diff ACC : 0.137
#
#
#
# DIMP : 0.829

# %%
#Adult setup
results_dict = {}

for poi_ratio in np.linspace(0.1, 0.5, 5):
    results_dict[poi_ratio] = {}
    results_dict[poi_ratio]['EqOdds'] =[]
    results_dict[poi_ratio]['Acc'] = []
    results_dict[poi_ratio]['DISP'] = []
    results_dict[poi_ratio]['EqOpp']= []
    results_dict[poi_ratio]['Acc_diff'] = []

    results_dict[poi_ratio]['total_tpr'] =[]
    results_dict[poi_ratio]['total_fpr'] =[]

    results_dict[poi_ratio]['total_tpr_priv'] =[]
    results_dict[poi_ratio]['total_tpr_unpriv'] =[]
    results_dict[poi_ratio]['total_fpr_priv'] =[]
    results_dict[poi_ratio]['total_fpr_unpriv'] =[]
    
    for repeat in range(5):
        data_train, data_vt = dataset[data_name].split([0.7], shuffle=True)
        data_valid, data_test = data_vt.split([0.5], shuffle=True)

        idx = np.where(data_train.features[:, sens_idx] == 1)[0]
        poison_idx = np.random.permutation(idx)[:int(len(idx) * poi_ratio)]

        #label poisoning
        data_train.labels[poison_idx] = 1 - data_train.labels[poison_idx]

        X_train = torch.FloatTensor(data_train.features[:, ~sens_loc])
        y_train = torch.FloatTensor(data_train.labels)
        s1_train = torch.FloatTensor(data_train.features[:, sens_idx]).view(-1,1)

        X_val = torch.FloatTensor(data_valid.features[:, ~sens_loc])
        y_val = torch.FloatTensor(data_valid.labels)
        s1_val = torch.FloatTensor(data_valid.features[:, sens_idx]).view(-1,1)

        X_test = torch.FloatTensor(data_test.features[:, ~sens_loc])
        y_test = torch.FloatTensor(data_test.labels)
        s1_test = torch.FloatTensor(data_test.features[:, sens_idx]).view(-1,1)

        XS_train = torch.cat([X_train, s1_train.reshape((s1_train.shape[0], 1))], dim=1)
        XS_val = torch.cat([X_val, s1_val.reshape((s1_val.shape[0], 1))], dim=1)
        XS_test = torch.cat([X_test, s1_test.reshape((s1_test.shape[0], 1))], dim=1)

        train_result = []
        train_tensors = Namespace(XS_train = XS_train, y_train = y_train, s1_train = s1_train)
        val_tensors = Namespace(XS_val = XS_val, y_val = y_val, s1_val = s1_val) 
        test_tensors = Namespace(XS_test = XS_test, y_test = y_test, s1_test = s1_test)

        train_opt = Namespace(val=len(y_val), n_epochs=100, k=1, lr_g=5e-4, lr_f=1e-5, lr_r=1e-5)
        seed = 1

        lambda_f_set = [0.3] # Lambda value for the fairness discriminator of FR-Train.
        lambda_r = 0.1 # Lambda value for the robustness discriminator of FR-Train.

        data_train = Dataset(X_train, s1_train, y_train)
        data_valid = Dataset(X_val, s1_val, y_val)
        data_test = Dataset(X_test, s1_test, y_test)

        trainloader = torch.utils.data.DataLoader(
            data_train,
            batch_size=128,
            shuffle=True,
            )
        validloader = torch.utils.data.DataLoader(
            data_valid,
            batch_size=128,
            shuffle=True,
            drop_last = True
            )
        testloader = torch.utils.data.DataLoader(
            data_test,
            batch_size=128,
            shuffle=True,
            drop_last = True
            )


        for lambda_f in lambda_f_set:
            train_model_adult(results_dict[poi_ratio], train_tensors, val_tensors, test_tensors, train_opt, lambda_f = lambda_f, lambda_r = lambda_r, seed = seed)
# Out:
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.698578] [D_R loss: 0.908454] [G loss: 0.089615]
# VALID DATA
# overall TPR : 0.500
# priv TPR : 0.351
# unpriv TPR : 0.526
# Eq. Opp : 0.175
#
# overall FPR : 0.123
# priv FPR : 0.163
# unpriv FPR : 0.061
# diff FPR : 0.102
#
# overall ACC : 0.784
# priv ACC : 0.739
# unpriv ACC : 0.873
# diff ACC : 0.134
#
#
#
# TEST DATA
# overall TPR : 0.503
# priv TPR : 0.321
# unpriv TPR : 0.534
# Eq. Opp : 0.213
#
# overall FPR : 0.117
# priv FPR : 0.152
# unpriv FPR : 0.062
# diff FPR : 0.090
#
# overall ACC : 0.788
# priv ACC : 0.748
# unpriv ACC : 0.869
# diff ACC : 0.121
#
#
#
# DIMP : 0.334
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.673877] [D_R loss: 0.866214] [G loss: 0.017246]
# VALID DATA
# overall TPR : 0.567
# priv TPR : 0.442
# unpriv TPR : 0.589
# Eq. Opp : 0.147
#
# overall FPR : 0.144
# priv FPR : 0.203
# unpriv FPR : 0.053
# diff FPR : 0.150
#
# overall ACC : 0.785
# priv ACC : 0.732
# unpriv ACC : 0.892
# diff ACC : 0.161
#
#
#
# TEST DATA
# overall TPR : 0.596
# priv TPR : 0.431
# unpriv TPR : 0.624
# Eq. Opp : 0.193
#
# overall FPR : 0.162
# priv FPR : 0.219
# unpriv FPR : 0.071
# diff FPR : 0.149
#
# overall ACC : 0.778
# priv ACC : 0.731
# unpriv ACC : 0.874
# diff ACC : 0.143
#
#
#
# DIMP : 0.318
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.672711] [D_R loss: 1.140470] [G loss: -0.058836]
# VALID DATA
# overall TPR : 0.655
# priv TPR : 0.522
# unpriv TPR : 0.679
# Eq. Opp : 0.157
#
# overall FPR : 0.174
# priv FPR : 0.243
# unpriv FPR : 0.067
# diff FPR : 0.176
#
# overall ACC : 0.784
# priv ACC : 0.732
# unpriv ACC : 0.887
# diff ACC : 0.154
#
#
#
# TEST DATA
# overall TPR : 0.668
# priv TPR : 0.512
# unpriv TPR : 0.695
# Eq. Opp : 0.183
#
# overall FPR : 0.177
# priv FPR : 0.242
# unpriv FPR : 0.073
# diff FPR : 0.169
#
# overall ACC : 0.784
# priv ACC : 0.738
# unpriv ACC : 0.881
# diff ACC : 0.143
#
#
#
# DIMP : 0.316
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.691292] [D_R loss: 1.075517] [G loss: 0.001522]
# VALID DATA
# overall TPR : 0.694
# priv TPR : 0.593
# unpriv TPR : 0.711
# Eq. Opp : 0.118
#
# overall FPR : 0.181
# priv FPR : 0.253
# unpriv FPR : 0.069
# diff FPR : 0.184
#
# overall ACC : 0.788
# priv ACC : 0.735
# unpriv ACC : 0.894
# diff ACC : 0.158
#
#
#
# TEST DATA
# overall TPR : 0.717
# priv TPR : 0.581
# unpriv TPR : 0.740
# Eq. Opp : 0.158
#
# overall FPR : 0.172
# priv FPR : 0.236
# unpriv FPR : 0.072
# diff FPR : 0.164
#
# overall ACC : 0.800
# priv ACC : 0.756
# unpriv ACC : 0.889
# diff ACC : 0.133
#
#
#
# DIMP : 0.326
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.679793] [D_R loss: 1.015456] [G loss: -0.047971]
# VALID DATA
# overall TPR : 0.672
# priv TPR : 0.678
# unpriv TPR : 0.670
# Eq. Opp : 0.007
#
# overall FPR : 0.185
# priv FPR : 0.239
# unpriv FPR : 0.102
# diff FPR : 0.138
#
# overall ACC : 0.779
# priv ACC : 0.732
# unpriv ACC : 0.874
# diff ACC : 0.142
#
#
#
# TEST DATA
# overall TPR : 0.700
# priv TPR : 0.642
# unpriv TPR : 0.710
# Eq. Opp : 0.068
#
# overall FPR : 0.181
# priv FPR : 0.239
# unpriv FPR : 0.089
# diff FPR : 0.150
#
# overall ACC : 0.789
# priv ACC : 0.745
# unpriv ACC : 0.881
# diff ACC : 0.136
#
#
#
# DIMP : 0.389
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.670076] [D_R loss: 0.955546] [G loss: -0.005445]
# VALID DATA
# overall TPR : 0.751
# priv TPR : 0.644
# unpriv TPR : 0.770
# Eq. Opp : 0.127
#
# overall FPR : 0.192
# priv FPR : 0.273
# unpriv FPR : 0.065
# diff FPR : 0.208
#
# overall ACC : 0.794
# priv ACC : 0.740
# unpriv ACC : 0.902
# diff ACC : 0.162
#
#
#
# TEST DATA
# overall TPR : 0.758
# priv TPR : 0.622
# unpriv TPR : 0.781
# Eq. Opp : 0.159
#
# overall FPR : 0.190
# priv FPR : 0.271
# unpriv FPR : 0.063
# diff FPR : 0.208
#
# overall ACC : 0.797
# priv ACC : 0.746
# unpriv ACC : 0.902
# diff ACC : 0.156
#
#
#
# DIMP : 0.289
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.671318] [D_R loss: 0.793984] [G loss: 0.025463]
# VALID DATA
# overall TPR : 0.634
# priv TPR : 0.490
# unpriv TPR : 0.659
# Eq. Opp : 0.169
#
# overall FPR : 0.155
# priv FPR : 0.216
# unpriv FPR : 0.061
# diff FPR : 0.155
#
# overall ACC : 0.793
# priv ACC : 0.745
# unpriv ACC : 0.889
# diff ACC : 0.144
#
#
#
# TEST DATA
# overall TPR : 0.664
# priv TPR : 0.504
# unpriv TPR : 0.691
# Eq. Opp : 0.187
#
# overall FPR : 0.162
# priv FPR : 0.223
# unpriv FPR : 0.066
# diff FPR : 0.158
#
# overall ACC : 0.794
# priv ACC : 0.750
# unpriv ACC : 0.887
# diff ACC : 0.137
#
#
#
# DIMP : 0.308
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.668308] [D_R loss: 0.790829] [G loss: -0.060735]
# VALID DATA
# overall TPR : 0.786
# priv TPR : 0.687
# unpriv TPR : 0.804
# Eq. Opp : 0.117
#
# overall FPR : 0.209
# priv FPR : 0.293
# unpriv FPR : 0.079
# diff FPR : 0.214
#
# overall ACC : 0.790
# priv ACC : 0.737
# unpriv ACC : 0.895
# diff ACC : 0.158
#
#
#
# TEST DATA
# overall TPR : 0.798
# priv TPR : 0.659
# unpriv TPR : 0.822
# Eq. Opp : 0.163
#
# overall FPR : 0.224
# priv FPR : 0.316
# unpriv FPR : 0.078
# diff FPR : 0.238
#
# overall ACC : 0.781
# priv ACC : 0.728
# unpriv ACC : 0.893
# diff ACC : 0.165
#
#
#
# DIMP : 0.300
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.664588] [D_R loss: 0.759153] [G loss: -0.017175]
# VALID DATA
# overall TPR : 0.761
# priv TPR : 0.598
# unpriv TPR : 0.790
# Eq. Opp : 0.192
#
# overall FPR : 0.209
# priv FPR : 0.293
# unpriv FPR : 0.077
# diff FPR : 0.216
#
# overall ACC : 0.784
# priv ACC : 0.733
# unpriv ACC : 0.886
# diff ACC : 0.154
#
#
#
# TEST DATA
# overall TPR : 0.759
# priv TPR : 0.589
# unpriv TPR : 0.787
# Eq. Opp : 0.198
#
# overall FPR : 0.217
# priv FPR : 0.307
# unpriv FPR : 0.076
# diff FPR : 0.231
#
# overall ACC : 0.777
# priv ACC : 0.723
# unpriv ACC : 0.887
# diff ACC : 0.164
#
#
#
# DIMP : 0.289
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.680862] [D_R loss: 0.652604] [G loss: -0.020411]
# VALID DATA
# overall TPR : 0.609
# priv TPR : 0.674
# unpriv TPR : 0.597
# Eq. Opp : 0.076
#
# overall FPR : 0.132
# priv FPR : 0.165
# unpriv FPR : 0.081
# diff FPR : 0.085
#
# overall ACC : 0.804
# priv ACC : 0.761
# unpriv ACC : 0.892
# diff ACC : 0.132
#
#
#
# TEST DATA
# overall TPR : 0.609
# priv TPR : 0.630
# unpriv TPR : 0.605
# Eq. Opp : 0.025
#
# overall FPR : 0.130
# priv FPR : 0.165
# unpriv FPR : 0.075
# diff FPR : 0.090
#
# overall ACC : 0.804
# priv ACC : 0.762
# unpriv ACC : 0.892
# diff ACC : 0.130
#
#
#
# DIMP : 0.449
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.689191] [D_R loss: 1.696874] [G loss: -0.120347]
# VALID DATA
# overall TPR : 0.534
# priv TPR : 0.554
# unpriv TPR : 0.530
# Eq. Opp : 0.024
#
# overall FPR : 0.073
# priv FPR : 0.093
# unpriv FPR : 0.042
# diff FPR : 0.052
#
# overall ACC : 0.830
# priv ACC : 0.788
# unpriv ACC : 0.913
# diff ACC : 0.125
#
#
#
# TEST DATA
# overall TPR : 0.545
# priv TPR : 0.549
# unpriv TPR : 0.544
# Eq. Opp : 0.005
#
# overall FPR : 0.079
# priv FPR : 0.098
# unpriv FPR : 0.047
# diff FPR : 0.051
#
# overall ACC : 0.825
# priv ACC : 0.788
# unpriv ACC : 0.906
# diff ACC : 0.118
#
#
#
# DIMP : 0.439
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.675008] [D_R loss: 1.209018] [G loss: -0.064549]
# VALID DATA
# overall TPR : 0.644
# priv TPR : 0.572
# unpriv TPR : 0.657
# Eq. Opp : 0.085
#
# overall FPR : 0.158
# priv FPR : 0.228
# unpriv FPR : 0.047
# diff FPR : 0.181
#
# overall ACC : 0.793
# priv ACC : 0.736
# unpriv ACC : 0.910
# diff ACC : 0.174
#
#
#
# TEST DATA
# overall TPR : 0.654
# priv TPR : 0.581
# unpriv TPR : 0.666
# Eq. Opp : 0.085
#
# overall FPR : 0.166
# priv FPR : 0.230
# unpriv FPR : 0.061
# diff FPR : 0.169
#
# overall ACC : 0.788
# priv ACC : 0.737
# unpriv ACC : 0.898
# diff ACC : 0.160
#
#
#
# DIMP : 0.329
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.696925] [D_R loss: 1.235118] [G loss: -0.029989]
# VALID DATA
# overall TPR : 0.631
# priv TPR : 0.556
# unpriv TPR : 0.645
# Eq. Opp : 0.089
#
# overall FPR : 0.141
# priv FPR : 0.185
# unpriv FPR : 0.071
# diff FPR : 0.114
#
# overall ACC : 0.803
# priv ACC : 0.761
# unpriv ACC : 0.887
# diff ACC : 0.126
#
#
#
# TEST DATA
# overall TPR : 0.645
# priv TPR : 0.601
# unpriv TPR : 0.652
# Eq. Opp : 0.051
#
# overall FPR : 0.137
# priv FPR : 0.182
# unpriv FPR : 0.064
# diff FPR : 0.119
#
# overall ACC : 0.807
# priv ACC : 0.765
# unpriv ACC : 0.897
# diff ACC : 0.132
#
#
#
# DIMP : 0.381
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.666586] [D_R loss: 1.049832] [G loss: -0.106083]
# VALID DATA
# overall TPR : 0.678
# priv TPR : 0.635
# unpriv TPR : 0.686
# Eq. Opp : 0.051
#
# overall FPR : 0.160
# priv FPR : 0.219
# unpriv FPR : 0.068
# diff FPR : 0.150
#
# overall ACC : 0.800
# priv ACC : 0.751
# unpriv ACC : 0.898
# diff ACC : 0.147
#
#
#
# TEST DATA
# overall TPR : 0.687
# priv TPR : 0.656
# unpriv TPR : 0.692
# Eq. Opp : 0.036
#
# overall FPR : 0.166
# priv FPR : 0.221
# unpriv FPR : 0.075
# diff FPR : 0.146
#
# overall ACC : 0.797
# priv ACC : 0.751
# unpriv ACC : 0.894
# diff ACC : 0.142
#
#
#
# DIMP : 0.384
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.683028] [D_R loss: 0.907730] [G loss: -0.113167]
# VALID DATA
# overall TPR : 0.616
# priv TPR : 0.553
# unpriv TPR : 0.627
# Eq. Opp : 0.074
#
# overall FPR : 0.144
# priv FPR : 0.180
# unpriv FPR : 0.088
# diff FPR : 0.092
#
# overall ACC : 0.797
# priv ACC : 0.759
# unpriv ACC : 0.871
# diff ACC : 0.112
# TEST DATA
# overall TPR : 0.616
# priv TPR : 0.597
# unpriv TPR : 0.620
# Eq. Opp : 0.023
#
# overall FPR : 0.146
# priv FPR : 0.179
# unpriv FPR : 0.091
# diff FPR : 0.088
#
# overall ACC : 0.794
# priv ACC : 0.757
# unpriv ACC : 0.873
# diff ACC : 0.116
#
#
#
# DIMP : 0.469
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.677994] [D_R loss: 0.931309] [G loss: -0.106376]
# VALID DATA
# overall TPR : 0.686
# priv TPR : 0.612
# unpriv TPR : 0.700
# Eq. Opp : 0.088
#
# overall FPR : 0.178
# priv FPR : 0.232
# unpriv FPR : 0.096
# diff FPR : 0.135
#
# overall ACC : 0.788
# priv ACC : 0.747
# unpriv ACC : 0.871
# diff ACC : 0.124
#
#
#
# TEST DATA
# overall TPR : 0.686
# priv TPR : 0.656
# unpriv TPR : 0.692
# Eq. Opp : 0.035
#
# overall FPR : 0.187
# priv FPR : 0.237
# unpriv FPR : 0.105
# diff FPR : 0.132
#
# overall ACC : 0.781
# priv ACC : 0.740
# unpriv ACC : 0.867
# diff ACC : 0.127
#
#
#
# DIMP : 0.443
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.672008] [D_R loss: 0.715883] [G loss: -0.101417]
# VALID DATA
# overall TPR : 0.619
# priv TPR : 0.638
# unpriv TPR : 0.615
# Eq. Opp : 0.023
#
# overall FPR : 0.138
# priv FPR : 0.176
# unpriv FPR : 0.078
# diff FPR : 0.098
#
# overall ACC : 0.802
# priv ACC : 0.758
# unpriv ACC : 0.890
# diff ACC : 0.132
#
#
#
# TEST DATA
# overall TPR : 0.631
# priv TPR : 0.652
# unpriv TPR : 0.628
# Eq. Opp : 0.024
#
# overall FPR : 0.147
# priv FPR : 0.182
# unpriv FPR : 0.089
# diff FPR : 0.093
#
# overall ACC : 0.797
# priv ACC : 0.757
# unpriv ACC : 0.881
# diff ACC : 0.123
#
#
#
# DIMP : 0.477
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.677730] [D_R loss: 0.921605] [G loss: -0.086663]
# VALID DATA
# overall TPR : 0.684
# priv TPR : 0.647
# unpriv TPR : 0.690
# Eq. Opp : 0.044
#
# overall FPR : 0.172
# priv FPR : 0.227
# unpriv FPR : 0.085
# diff FPR : 0.143
#
# overall ACC : 0.793
# priv ACC : 0.747
# unpriv ACC : 0.885
# diff ACC : 0.138
#
#
#
# TEST DATA
# overall TPR : 0.695
# priv TPR : 0.652
# unpriv TPR : 0.702
# Eq. Opp : 0.050
#
# overall FPR : 0.175
# priv FPR : 0.226
# unpriv FPR : 0.093
# diff FPR : 0.133
#
# overall ACC : 0.792
# priv ACC : 0.751
# unpriv ACC : 0.877
# diff ACC : 0.126
#
#
#
# DIMP : 0.419
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.665056] [D_R loss: 0.689298] [G loss: -0.043304]
# VALID DATA
# overall TPR : 0.681
# priv TPR : 0.656
# unpriv TPR : 0.685
# Eq. Opp : 0.029
#
# overall FPR : 0.166
# priv FPR : 0.229
# unpriv FPR : 0.068
# diff FPR : 0.161
#
# overall ACC : 0.796
# priv ACC : 0.744
# unpriv ACC : 0.901
# diff ACC : 0.157
#
#
#
# TEST DATA
# overall TPR : 0.688
# priv TPR : 0.640
# unpriv TPR : 0.696
# Eq. Opp : 0.056
#
# overall FPR : 0.166
# priv FPR : 0.226
# unpriv FPR : 0.068
# diff FPR : 0.158
#
# overall ACC : 0.797
# priv ACC : 0.749
# unpriv ACC : 0.898
# diff ACC : 0.149
#
#
#
# DIMP : 0.358
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.661256] [D_R loss: 0.778487] [G loss: -0.060028]
# VALID DATA
# overall TPR : 0.705
# priv TPR : 0.653
# unpriv TPR : 0.714
# Eq. Opp : 0.061
#
# overall FPR : 0.173
# priv FPR : 0.230
# unpriv FPR : 0.084
# diff FPR : 0.145
#
# overall ACC : 0.797
# priv ACC : 0.753
# unpriv ACC : 0.886
# diff ACC : 0.133
#
#
#
# TEST DATA
# overall TPR : 0.698
# priv TPR : 0.636
# unpriv TPR : 0.708
# Eq. Opp : 0.072
#
# overall FPR : 0.179
# priv FPR : 0.237
# unpriv FPR : 0.083
# diff FPR : 0.154
#
# overall ACC : 0.790
# priv ACC : 0.745
# unpriv ACC : 0.884
# diff ACC : 0.139
#
#
#
# DIMP : 0.381
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.709241] [D_R loss: 0.960755] [G loss: 0.097883]
# VALID DATA
# overall TPR : 0.448
# priv TPR : 0.082
# unpriv TPR : 0.511
# Eq. Opp : 0.429
#
# overall FPR : 0.110
# priv FPR : 0.163
# unpriv FPR : 0.021
# diff FPR : 0.142
#
# overall ACC : 0.780
# priv ACC : 0.736
# unpriv ACC : 0.876
# diff ACC : 0.140
#
#
#
# TEST DATA
# overall TPR : 0.435
# priv TPR : 0.035
# unpriv TPR : 0.509
# Eq. Opp : 0.473
#
# overall FPR : 0.119
# priv FPR : 0.180
# unpriv FPR : 0.024
# diff FPR : 0.156
#
# overall ACC : 0.772
# priv ACC : 0.724
# unpriv ACC : 0.868
# diff ACC : 0.144
#
#
#
# DIMP : 0.089
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.691462] [D_R loss: 0.785963] [G loss: -0.087834]
# VALID DATA
# overall TPR : 0.521
# priv TPR : 0.263
# unpriv TPR : 0.566
# Eq. Opp : 0.303
#
# overall FPR : 0.125
# priv FPR : 0.170
# unpriv FPR : 0.048
# diff FPR : 0.122
#
# overall ACC : 0.788
# priv ACC : 0.748
# unpriv ACC : 0.872
# diff ACC : 0.123
#
#
#
# TEST DATA
# overall TPR : 0.554
# priv TPR : 0.254
# unpriv TPR : 0.609
# Eq. Opp : 0.355
#
# overall FPR : 0.131
# priv FPR : 0.189
# unpriv FPR : 0.039
# diff FPR : 0.150
#
# overall ACC : 0.792
# priv ACC : 0.749
# unpriv ACC : 0.880
# diff ACC : 0.132
#
#
#
# DIMP : 0.199
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.676564] [D_R loss: 0.854306] [G loss: -0.035632]
# VALID DATA
# overall TPR : 0.654
# priv TPR : 0.508
# unpriv TPR : 0.680
# Eq. Opp : 0.171
#
# overall FPR : 0.168
# priv FPR : 0.227
# unpriv FPR : 0.069
# diff FPR : 0.158
#
# overall ACC : 0.788
# priv ACC : 0.744
# unpriv ACC : 0.881
# diff ACC : 0.137
#
#
#
# TEST DATA
# overall TPR : 0.655
# priv TPR : 0.477
# unpriv TPR : 0.688
# Eq. Opp : 0.211
#
# overall FPR : 0.162
# priv FPR : 0.230
# unpriv FPR : 0.053
# diff FPR : 0.178
#
# overall ACC : 0.793
# priv ACC : 0.744
# unpriv ACC : 0.894
# diff ACC : 0.149
#
#
#
# DIMP : 0.272
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.676510] [D_R loss: 1.043751] [G loss: -0.084306]
# VALID DATA
# overall TPR : 0.692
# priv TPR : 0.541
# unpriv TPR : 0.719
# Eq. Opp : 0.178
#
# overall FPR : 0.191
# priv FPR : 0.260
# unpriv FPR : 0.075
# diff FPR : 0.185
#
# overall ACC : 0.780
# priv ACC : 0.734
# unpriv ACC : 0.880
# diff ACC : 0.147
#
#
#
# TEST DATA
# overall TPR : 0.723
# priv TPR : 0.609
# unpriv TPR : 0.743
# Eq. Opp : 0.134
#
# overall FPR : 0.172
# priv FPR : 0.237
# unpriv FPR : 0.068
# diff FPR : 0.170
#
# overall ACC : 0.802
# priv ACC : 0.757
# unpriv ACC : 0.895
# diff ACC : 0.139
#
#
#
# DIMP : 0.330
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.683936] [D_R loss: 0.871139] [G loss: 0.016605]
# VALID DATA
# overall TPR : 0.742
# priv TPR : 0.652
# unpriv TPR : 0.758
# Eq. Opp : 0.106
#
# overall FPR : 0.190
# priv FPR : 0.261
# unpriv FPR : 0.071
# diff FPR : 0.190
#
# overall ACC : 0.793
# priv ACC : 0.745
# unpriv ACC : 0.897
# diff ACC : 0.152
#
#
#
# TEST DATA
# overall TPR : 0.752
# priv TPR : 0.621
# unpriv TPR : 0.775
# Eq. Opp : 0.154
#
# overall FPR : 0.177
# priv FPR : 0.247
# unpriv FPR : 0.066
# diff FPR : 0.181
#
# overall ACC : 0.805
# priv ACC : 0.760
# unpriv ACC : 0.898
# diff ACC : 0.138
#
#
#
# DIMP : 0.316
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.676756] [D_R loss: 1.083130] [G loss: -0.091148]
# VALID DATA
# overall TPR : 0.671
# priv TPR : 0.678
# unpriv TPR : 0.670
# Eq. Opp : 0.008
#
# overall FPR : 0.179
# priv FPR : 0.227
# unpriv FPR : 0.098
# diff FPR : 0.128
#
# overall ACC : 0.784
# priv ACC : 0.741
# unpriv ACC : 0.876
# diff ACC : 0.135
#
#
#
# TEST DATA
# overall TPR : 0.674
# priv TPR : 0.652
# unpriv TPR : 0.678
# Eq. Opp : 0.026
#
# overall FPR : 0.164
# priv FPR : 0.212
# unpriv FPR : 0.088
# diff FPR : 0.124
#
# overall ACC : 0.796
# priv ACC : 0.754
# unpriv ACC : 0.882
# diff ACC : 0.128
#
#
#
# DIMP : 0.430
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.682388] [D_R loss: 1.004013] [G loss: -0.047840]
# VALID DATA
# overall TPR : 0.683
# priv TPR : 0.683
# unpriv TPR : 0.683
# Eq. Opp : 0.000
#
# overall FPR : 0.172
# priv FPR : 0.220
# unpriv FPR : 0.091
# diff FPR : 0.129
#
# overall ACC : 0.792
# priv ACC : 0.750
# unpriv ACC : 0.882
# diff ACC : 0.133
#
#
#
# TEST DATA
# overall TPR : 0.704
# priv TPR : 0.637
# unpriv TPR : 0.716
# Eq. Opp : 0.079
#
# overall FPR : 0.165
# priv FPR : 0.215
# unpriv FPR : 0.085
# diff FPR : 0.130
#
# overall ACC : 0.803
# priv ACC : 0.764
# unpriv ACC : 0.883
# diff ACC : 0.119
#
#
#
# DIMP : 0.402
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.689363] [D_R loss: 0.867455] [G loss: -0.074380]
# VALID DATA
# overall TPR : 0.662
# priv TPR : 0.587
# unpriv TPR : 0.675
# Eq. Opp : 0.088
#
# overall FPR : 0.164
# priv FPR : 0.213
# unpriv FPR : 0.082
# diff FPR : 0.131
#
# overall ACC : 0.793
# priv ACC : 0.752
# unpriv ACC : 0.880
# diff ACC : 0.127
#
#
#
# TEST DATA
# overall TPR : 0.666
# priv TPR : 0.590
# unpriv TPR : 0.680
# Eq. Opp : 0.091
#
# overall FPR : 0.156
# priv FPR : 0.205
# unpriv FPR : 0.079
# diff FPR : 0.125
#
# overall ACC : 0.800
# priv ACC : 0.760
# unpriv ACC : 0.883
# diff ACC : 0.123
#
#
#
# DIMP : 0.392
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.699258] [D_R loss: 0.841383] [G loss: -0.035362]
# VALID DATA
# overall TPR : 0.655
# priv TPR : 0.531
# unpriv TPR : 0.677
# Eq. Opp : 0.146
#
# overall FPR : 0.170
# priv FPR : 0.229
# unpriv FPR : 0.070
# diff FPR : 0.159
#
# overall ACC : 0.787
# priv ACC : 0.742
# unpriv ACC : 0.884
# diff ACC : 0.142
#
#
#
# TEST DATA
# overall TPR : 0.677
# priv TPR : 0.547
# unpriv TPR : 0.700
# Eq. Opp : 0.154
#
# overall FPR : 0.176
# priv FPR : 0.239
# unpriv FPR : 0.077
# diff FPR : 0.161
#
# overall ACC : 0.788
# priv ACC : 0.743
# unpriv ACC : 0.880
# diff ACC : 0.137
#
#
#
# DIMP : 0.344
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.662772] [D_R loss: 0.593504] [G loss: -0.035811]
# VALID DATA
# overall TPR : 0.645
# priv TPR : 0.558
# unpriv TPR : 0.660
# Eq. Opp : 0.102
#
# overall FPR : 0.148
# priv FPR : 0.203
# unpriv FPR : 0.055
# diff FPR : 0.148
#
# overall ACC : 0.800
# priv ACC : 0.755
# unpriv ACC : 0.899
# diff ACC : 0.145
#
#
#
# TEST DATA
# overall TPR : 0.614
# priv TPR : 0.512
# unpriv TPR : 0.633
# Eq. Opp : 0.121
#
# overall FPR : 0.134
# priv FPR : 0.186
# unpriv FPR : 0.050
# diff FPR : 0.136
#
# overall ACC : 0.805
# priv ACC : 0.758
# unpriv ACC : 0.900
# diff ACC : 0.142
#
#
#
# DIMP : 0.318
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.702828] [D_R loss: 1.753486] [G loss: -0.183426]
# VALID DATA
# overall TPR : 0.597
# priv TPR : 0.625
# unpriv TPR : 0.592
# Eq. Opp : 0.032
#
# overall FPR : 0.084
# priv FPR : 0.108
# unpriv FPR : 0.046
# diff FPR : 0.062
#
# overall ACC : 0.837
# priv ACC : 0.798
# unpriv ACC : 0.916
# diff ACC : 0.118
#
#
#
# TEST DATA
# overall TPR : 0.599
# priv TPR : 0.600
# unpriv TPR : 0.599
# Eq. Opp : 0.001
#
# overall FPR : 0.084
# priv FPR : 0.109
# unpriv FPR : 0.044
# diff FPR : 0.064
#
# overall ACC : 0.836
# priv ACC : 0.798
# unpriv ACC : 0.913
# diff ACC : 0.115
#
#
#
# DIMP : 0.418
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.676555] [D_R loss: 1.249122] [G loss: -0.095184]
# VALID DATA
# overall TPR : 0.704
# priv TPR : 0.668
# unpriv TPR : 0.710
# Eq. Opp : 0.042
#
# overall FPR : 0.149
# priv FPR : 0.207
# unpriv FPR : 0.058
# diff FPR : 0.149
#
# overall ACC : 0.814
# priv ACC : 0.767
# unpriv ACC : 0.911
# diff ACC : 0.144
#
#
#
# TEST DATA
# overall TPR : 0.717
# priv TPR : 0.623
# unpriv TPR : 0.734
# Eq. Opp : 0.112
#
# overall FPR : 0.143
# priv FPR : 0.200
# unpriv FPR : 0.053
# diff FPR : 0.147
#
# overall ACC : 0.821
# priv ACC : 0.779
# unpriv ACC : 0.908
# diff ACC : 0.129
#
#
#
# DIMP : 0.327
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.681482] [D_R loss: 1.077027] [G loss: 0.046490]
# VALID DATA
# overall TPR : 0.684
# priv TPR : 0.615
# unpriv TPR : 0.697
# Eq. Opp : 0.081
#
# overall FPR : 0.165
# priv FPR : 0.236
# unpriv FPR : 0.053
# diff FPR : 0.183
#
# overall ACC : 0.797
# priv ACC : 0.742
# unpriv ACC : 0.909
# diff ACC : 0.166
#
#
#
# TEST DATA
# overall TPR : 0.691
# priv TPR : 0.581
# unpriv TPR : 0.711
# Eq. Opp : 0.130
#
# overall FPR : 0.163
# priv FPR : 0.235
# unpriv FPR : 0.048
# diff FPR : 0.188
#
# overall ACC : 0.800
# priv ACC : 0.748
# unpriv ACC : 0.908
# diff ACC : 0.160
#
#
#
# DIMP : 0.288
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.657442] [D_R loss: 1.059878] [G loss: -0.097670]
# VALID DATA
# overall TPR : 0.721
# priv TPR : 0.630
# unpriv TPR : 0.738
# Eq. Opp : 0.108
#
# overall FPR : 0.168
# priv FPR : 0.237
# unpriv FPR : 0.060
# diff FPR : 0.177
#
# overall ACC : 0.805
# priv ACC : 0.755
# unpriv ACC : 0.904
# diff ACC : 0.149
#
#
#
# TEST DATA
# overall TPR : 0.740
# priv TPR : 0.608
# unpriv TPR : 0.765
# Eq. Opp : 0.157
#
# overall FPR : 0.173
# priv FPR : 0.245
# unpriv FPR : 0.057
# diff FPR : 0.187
#
# overall ACC : 0.805
# priv ACC : 0.758
# unpriv ACC : 0.903
# diff ACC : 0.144
#
#
#
# DIMP : 0.300
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.692996] [D_R loss: 1.121961] [G loss: -0.079255]
# VALID DATA
# overall TPR : 0.734
# priv TPR : 0.725
# unpriv TPR : 0.736
# Eq. Opp : 0.011
#
# overall FPR : 0.190
# priv FPR : 0.235
# unpriv FPR : 0.118
# diff FPR : 0.117
#
# overall ACC : 0.791
# priv ACC : 0.756
# unpriv ACC : 0.864
# diff ACC : 0.108
#
#
#
# TEST DATA
# overall TPR : 0.744
# priv TPR : 0.672
# unpriv TPR : 0.758
# Eq. Opp : 0.086
#
# overall FPR : 0.182
# priv FPR : 0.232
# unpriv FPR : 0.103
# diff FPR : 0.128
#
# overall ACC : 0.799
# priv ACC : 0.765
# unpriv ACC : 0.870
# diff ACC : 0.105
#
#
#
# DIMP : 0.429
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.679979] [D_R loss: 0.873143] [G loss: -0.037688]
# VALID DATA
# overall TPR : 0.620
# priv TPR : 0.644
# unpriv TPR : 0.616
# Eq. Opp : 0.028
#
# overall FPR : 0.143
# priv FPR : 0.185
# unpriv FPR : 0.078
# diff FPR : 0.107
#
# overall ACC : 0.798
# priv ACC : 0.752
# unpriv ACC : 0.891
# diff ACC : 0.138
#
#
#
# TEST DATA
# overall TPR : 0.629
# priv TPR : 0.634
# unpriv TPR : 0.628
# Eq. Opp : 0.006
#
# overall FPR : 0.141
# priv FPR : 0.181
# unpriv FPR : 0.075
# diff FPR : 0.106
#
# overall ACC : 0.801
# priv ACC : 0.758
# unpriv ACC : 0.890
# diff ACC : 0.132
#
#
#
# DIMP : 0.439
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.665049] [D_R loss: 0.826494] [G loss: -0.093207]
# VALID DATA
# overall TPR : 0.690
# priv TPR : 0.668
# unpriv TPR : 0.694
# Eq. Opp : 0.026
#
# overall FPR : 0.162
# priv FPR : 0.213
# unpriv FPR : 0.080
# diff FPR : 0.133
#
# overall ACC : 0.801
# priv ACC : 0.757
# unpriv ACC : 0.891
# diff ACC : 0.133
#
#
#
# TEST DATA
# overall TPR : 0.721
# priv TPR : 0.679
# unpriv TPR : 0.729
# Eq. Opp : 0.050
#
# overall FPR : 0.172
# priv FPR : 0.232
# unpriv FPR : 0.076
# diff FPR : 0.156
#
# overall ACC : 0.801
# priv ACC : 0.756
# unpriv ACC : 0.895
# diff ACC : 0.139
#
#
#
# DIMP : 0.379
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.673981] [D_R loss: 0.734622] [G loss: -0.078376]
# VALID DATA
# overall TPR : 0.692
# priv TPR : 0.614
# unpriv TPR : 0.706
# Eq. Opp : 0.092
#
# overall FPR : 0.153
# priv FPR : 0.206
# unpriv FPR : 0.070
# diff FPR : 0.136
#
# overall ACC : 0.808
# priv ACC : 0.766
# unpriv ACC : 0.894
# diff ACC : 0.128
#
#
#
# TEST DATA
# overall TPR : 0.724
# priv TPR : 0.657
# unpriv TPR : 0.736
# Eq. Opp : 0.079
#
# overall FPR : 0.164
# priv FPR : 0.221
# unpriv FPR : 0.073
# diff FPR : 0.148
#
# overall ACC : 0.808
# priv ACC : 0.765
# unpriv ACC : 0.895
# diff ACC : 0.129
#
#
#
# DIMP : 0.371
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.666125] [D_R loss: 0.719223] [G loss: -0.078949]
# VALID DATA
# overall TPR : 0.720
# priv TPR : 0.636
# unpriv TPR : 0.735
# Eq. Opp : 0.100
#
# overall FPR : 0.180
# priv FPR : 0.249
# unpriv FPR : 0.071
# diff FPR : 0.178
#
# overall ACC : 0.796
# priv ACC : 0.746
# unpriv ACC : 0.896
# diff ACC : 0.150
#
#
#
# TEST DATA
# overall TPR : 0.739
# priv TPR : 0.638
# unpriv TPR : 0.758
# Eq. Opp : 0.120
#
# overall FPR : 0.183
# priv FPR : 0.256
# unpriv FPR : 0.068
# diff FPR : 0.187
#
# overall ACC : 0.797
# priv ACC : 0.749
# unpriv ACC : 0.897
# diff ACC : 0.148
#
#
#
# DIMP : 0.328
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.695189] [D_R loss: 0.647599] [G loss: -0.069417]
# VALID DATA
# overall TPR : 0.646
# priv TPR : 0.609
# unpriv TPR : 0.653
# Eq. Opp : 0.044
#
# overall FPR : 0.174
# priv FPR : 0.220
# unpriv FPR : 0.102
# diff FPR : 0.118
#
# overall ACC : 0.781
# priv ACC : 0.740
# unpriv ACC : 0.865
# diff ACC : 0.125
#
#
#
# TEST DATA
# overall TPR : 0.665
# priv TPR : 0.619
# unpriv TPR : 0.674
# Eq. Opp : 0.055
#
# overall FPR : 0.171
# priv FPR : 0.224
# unpriv FPR : 0.086
# diff FPR : 0.138
#
# overall ACC : 0.788
# priv ACC : 0.744
# unpriv ACC : 0.879
# diff ACC : 0.136
#
#
#
# DIMP : 0.407
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.688932] [D_R loss: 1.163993] [G loss: 0.021866]
# VALID DATA
# overall TPR : 0.514
# priv TPR : 0.450
# unpriv TPR : 0.526
# Eq. Opp : 0.075
#
# overall FPR : 0.115
# priv FPR : 0.152
# unpriv FPR : 0.056
# diff FPR : 0.096
#
# overall ACC : 0.792
# priv ACC : 0.747
# unpriv ACC : 0.884
# diff ACC : 0.137
#
#
#
# TEST DATA
# overall TPR : 0.528
# priv TPR : 0.460
# unpriv TPR : 0.540
# Eq. Opp : 0.080
#
# overall FPR : 0.111
# priv FPR : 0.148
# unpriv FPR : 0.053
# diff FPR : 0.095
#
# overall ACC : 0.800
# priv ACC : 0.755
# unpriv ACC : 0.893
# diff ACC : 0.137
#
#
#
# DIMP : 0.365
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.693153] [D_R loss: 1.269058] [G loss: -0.042643]
# VALID DATA
# overall TPR : 0.595
# priv TPR : 0.487
# unpriv TPR : 0.615
# Eq. Opp : 0.129
#
# overall FPR : 0.145
# priv FPR : 0.193
# unpriv FPR : 0.069
# diff FPR : 0.124
#
# overall ACC : 0.790
# priv ACC : 0.748
# unpriv ACC : 0.877
# diff ACC : 0.130
#
#
#
# TEST DATA
# overall TPR : 0.587
# priv TPR : 0.512
# unpriv TPR : 0.600
# Eq. Opp : 0.088
#
# overall FPR : 0.121
# priv FPR : 0.166
# unpriv FPR : 0.051
# diff FPR : 0.114
#
# overall ACC : 0.807
# priv ACC : 0.762
# unpriv ACC : 0.900
# diff ACC : 0.138
#
#
#
# DIMP : 0.342
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.688451] [D_R loss: 1.169161] [G loss: 0.079361]
# VALID DATA
# overall TPR : 0.634
# priv TPR : 0.483
# unpriv TPR : 0.662
# Eq. Opp : 0.179
#
# overall FPR : 0.157
# priv FPR : 0.214
# unpriv FPR : 0.066
# diff FPR : 0.148
#
# overall ACC : 0.790
# priv ACC : 0.747
# unpriv ACC : 0.879
# diff ACC : 0.132
#
#
#
# TEST DATA
# overall TPR : 0.639
# priv TPR : 0.552
# unpriv TPR : 0.655
# Eq. Opp : 0.103
#
# overall FPR : 0.123
# priv FPR : 0.173
# unpriv FPR : 0.045
# diff FPR : 0.128
#
# overall ACC : 0.818
# priv ACC : 0.774
# unpriv ACC : 0.910
# diff ACC : 0.136
#
#
#
# DIMP : 0.316
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.690202] [D_R loss: 1.046898] [G loss: -0.032402]
# VALID DATA
# overall TPR : 0.647
# priv TPR : 0.523
# unpriv TPR : 0.670
# Eq. Opp : 0.148
#
# overall FPR : 0.164
# priv FPR : 0.218
# unpriv FPR : 0.077
# diff FPR : 0.141
#
# overall ACC : 0.789
# priv ACC : 0.747
# unpriv ACC : 0.875
# diff ACC : 0.128
# TEST DATA
# overall TPR : 0.681
# priv TPR : 0.604
# unpriv TPR : 0.694
# Eq. Opp : 0.090
#
# overall FPR : 0.162
# priv FPR : 0.221
# unpriv FPR : 0.067
# diff FPR : 0.154
#
# overall ACC : 0.800
# priv ACC : 0.752
# unpriv ACC : 0.896
# diff ACC : 0.143
#
#
#
# DIMP : 0.346
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.685944] [D_R loss: 0.860595] [G loss: -0.018658]
# VALID DATA
# overall TPR : 0.711
# priv TPR : 0.525
# unpriv TPR : 0.746
# Eq. Opp : 0.221
#
# overall FPR : 0.190
# priv FPR : 0.267
# unpriv FPR : 0.064
# diff FPR : 0.204
#
# overall ACC : 0.785
# priv ACC : 0.737
# unpriv ACC : 0.886
# diff ACC : 0.149
#
#
#
# TEST DATA
# overall TPR : 0.706
# priv TPR : 0.528
# unpriv TPR : 0.737
# Eq. Opp : 0.209
#
# overall FPR : 0.171
# priv FPR : 0.248
# unpriv FPR : 0.048
# diff FPR : 0.201
#
# overall ACC : 0.799
# priv ACC : 0.747
# unpriv ACC : 0.905
# diff ACC : 0.158
#
#
#
# DIMP : 0.254
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.687426] [D_R loss: 0.986413] [G loss: -0.018612]
# VALID DATA
# overall TPR : 0.703
# priv TPR : 0.546
# unpriv TPR : 0.732
# Eq. Opp : 0.187
#
# overall FPR : 0.171
# priv FPR : 0.224
# unpriv FPR : 0.085
# diff FPR : 0.138
#
# overall ACC : 0.798
# priv ACC : 0.763
# unpriv ACC : 0.870
# diff ACC : 0.108
#
#
#
# TEST DATA
# overall TPR : 0.701
# priv TPR : 0.584
# unpriv TPR : 0.722
# Eq. Opp : 0.138
#
# overall FPR : 0.160
# priv FPR : 0.212
# unpriv FPR : 0.076
# diff FPR : 0.136
#
# overall ACC : 0.806
# priv ACC : 0.767
# unpriv ACC : 0.885
# diff ACC : 0.118
#
#
#
# DIMP : 0.360
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.676328] [D_R loss: 0.922801] [G loss: -0.029093]
# VALID DATA
# overall TPR : 0.674
# priv TPR : 0.560
# unpriv TPR : 0.695
# Eq. Opp : 0.135
#
# overall FPR : 0.179
# priv FPR : 0.240
# unpriv FPR : 0.080
# diff FPR : 0.160
#
# overall ACC : 0.784
# priv ACC : 0.739
# unpriv ACC : 0.877
# diff ACC : 0.137
#
#
#
# TEST DATA
# overall TPR : 0.677
# priv TPR : 0.584
# unpriv TPR : 0.694
# Eq. Opp : 0.110
#
# overall FPR : 0.164
# priv FPR : 0.229
# unpriv FPR : 0.062
# diff FPR : 0.166
#
# overall ACC : 0.797
# priv ACC : 0.747
# unpriv ACC : 0.898
# diff ACC : 0.151
#
#
#
# DIMP : 0.324
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.683195] [D_R loss: 0.839350] [G loss: 0.042244]
# VALID DATA
# overall TPR : 0.692
# priv TPR : 0.608
# unpriv TPR : 0.707
# Eq. Opp : 0.100
#
# overall FPR : 0.158
# priv FPR : 0.214
# unpriv FPR : 0.069
# diff FPR : 0.145
#
# overall ACC : 0.804
# priv ACC : 0.761
# unpriv ACC : 0.892
# diff ACC : 0.130
#
#
#
# TEST DATA
# overall TPR : 0.687
# priv TPR : 0.616
# unpriv TPR : 0.700
# Eq. Opp : 0.084
#
# overall FPR : 0.156
# priv FPR : 0.209
# unpriv FPR : 0.070
# diff FPR : 0.139
#
# overall ACC : 0.806
# priv ACC : 0.762
# unpriv ACC : 0.894
# diff ACC : 0.132
#
#
#
# DIMP : 0.364
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.703095] [D_R loss: 0.776664] [G loss: 0.039018]
# VALID DATA
# overall TPR : 0.635
# priv TPR : 0.536
# unpriv TPR : 0.653
# Eq. Opp : 0.117
#
# overall FPR : 0.119
# priv FPR : 0.162
# unpriv FPR : 0.051
# diff FPR : 0.111
#
# overall ACC : 0.819
# priv ACC : 0.780
# unpriv ACC : 0.899
# diff ACC : 0.119
#
#
#
# TEST DATA
# overall TPR : 0.645
# priv TPR : 0.572
# unpriv TPR : 0.658
# Eq. Opp : 0.086
#
# overall FPR : 0.121
# priv FPR : 0.166
# unpriv FPR : 0.051
# diff FPR : 0.114
#
# overall ACC : 0.821
# priv ACC : 0.780
# unpriv ACC : 0.907
# diff ACC : 0.127
#
#
#
# DIMP : 0.344
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.678520] [D_R loss: 0.711735] [G loss: -0.059033]
# VALID DATA
# overall TPR : 0.667
# priv TPR : 0.557
# unpriv TPR : 0.688
# Eq. Opp : 0.131
#
# overall FPR : 0.160
# priv FPR : 0.215
# unpriv FPR : 0.070
# diff FPR : 0.145
#
# overall ACC : 0.797
# priv ACC : 0.755
# unpriv ACC : 0.884
# diff ACC : 0.130
#
#
#
# TEST DATA
# overall TPR : 0.658
# priv TPR : 0.556
# unpriv TPR : 0.676
# Eq. Opp : 0.120
#
# overall FPR : 0.148
# priv FPR : 0.200
# unpriv FPR : 0.064
# diff FPR : 0.136
#
# overall ACC : 0.805
# priv ACC : 0.761
# unpriv ACC : 0.893
# diff ACC : 0.132
#
#
#
# DIMP : 0.343
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.680569] [D_R loss: 1.359206] [G loss: -0.061839]
# VALID DATA
# overall TPR : 0.509
# priv TPR : 0.504
# unpriv TPR : 0.510
# Eq. Opp : 0.006
#
# overall FPR : 0.074
# priv FPR : 0.100
# unpriv FPR : 0.032
# diff FPR : 0.068
#
# overall ACC : 0.821
# priv ACC : 0.778
# unpriv ACC : 0.913
# diff ACC : 0.135
#
#
#
# TEST DATA
# overall TPR : 0.531
# priv TPR : 0.568
# unpriv TPR : 0.524
# Eq. Opp : 0.044
#
# overall FPR : 0.078
# priv FPR : 0.104
# unpriv FPR : 0.036
# diff FPR : 0.067
#
# overall ACC : 0.824
# priv ACC : 0.780
# unpriv ACC : 0.915
# diff ACC : 0.135
#
#
#
# DIMP : 0.431
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.684499] [D_R loss: 1.120069] [G loss: -0.032780]
# VALID DATA
# overall TPR : 0.682
# priv TPR : 0.552
# unpriv TPR : 0.706
# Eq. Opp : 0.154
#
# overall FPR : 0.171
# priv FPR : 0.246
# unpriv FPR : 0.048
# diff FPR : 0.199
#
# overall ACC : 0.792
# priv ACC : 0.739
# unpriv ACC : 0.904
# diff ACC : 0.165
#
#
#
# TEST DATA
# overall TPR : 0.705
# priv TPR : 0.605
# unpriv TPR : 0.724
# Eq. Opp : 0.119
#
# overall FPR : 0.191
# priv FPR : 0.281
# unpriv FPR : 0.045
# diff FPR : 0.237
#
# overall ACC : 0.783
# priv ACC : 0.720
# unpriv ACC : 0.913
# diff ACC : 0.192
#
#
#
# DIMP : 0.269
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.673106] [D_R loss: 1.334975] [G loss: -0.046648]
# VALID DATA
# overall TPR : 0.592
# priv TPR : 0.605
# unpriv TPR : 0.590
# Eq. Opp : 0.016
#
# overall FPR : 0.184
# priv FPR : 0.236
# unpriv FPR : 0.100
# diff FPR : 0.136
#
# overall ACC : 0.760
# priv ACC : 0.709
# unpriv ACC : 0.865
# diff ACC : 0.156
#
#
#
# TEST DATA
# overall TPR : 0.613
# priv TPR : 0.661
# unpriv TPR : 0.604
# Eq. Opp : 0.056
#
# overall FPR : 0.163
# priv FPR : 0.206
# unpriv FPR : 0.093
# diff FPR : 0.113
#
# overall ACC : 0.781
# priv ACC : 0.734
# unpriv ACC : 0.877
# diff ACC : 0.143
#
#
#
# DIMP : 0.490
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.677071] [D_R loss: 0.994824] [G loss: -0.030447]
# VALID DATA
# overall TPR : 0.751
# priv TPR : 0.635
# unpriv TPR : 0.772
# Eq. Opp : 0.138
#
# overall FPR : 0.239
# priv FPR : 0.343
# unpriv FPR : 0.069
# diff FPR : 0.275
#
# overall ACC : 0.759
# priv ACC : 0.693
# unpriv ACC : 0.896
# diff ACC : 0.203
#
#
#
# TEST DATA
# overall TPR : 0.757
# priv TPR : 0.657
# unpriv TPR : 0.776
# Eq. Opp : 0.119
#
# overall FPR : 0.249
# priv FPR : 0.359
# unpriv FPR : 0.073
# diff FPR : 0.286
#
# overall ACC : 0.752
# priv ACC : 0.683
# unpriv ACC : 0.894
# diff ACC : 0.211
#
#
#
# DIMP : 0.295
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.664840] [D_R loss: 1.024646] [G loss: -0.040636]
# VALID DATA
# overall TPR : 0.720
# priv TPR : 0.566
# unpriv TPR : 0.748
# Eq. Opp : 0.182
#
# overall FPR : 0.221
# priv FPR : 0.334
# unpriv FPR : 0.037
# diff FPR : 0.296
#
# overall ACC : 0.764
# priv ACC : 0.692
# unpriv ACC : 0.915
# diff ACC : 0.223
#
#
#
# TEST DATA
# overall TPR : 0.751
# priv TPR : 0.624
# unpriv TPR : 0.775
# Eq. Opp : 0.151
#
# overall FPR : 0.227
# priv FPR : 0.340
# unpriv FPR : 0.046
# diff FPR : 0.294
#
# overall ACC : 0.767
# priv ACC : 0.696
# unpriv ACC : 0.913
# diff ACC : 0.217
#
#
#
# DIMP : 0.245
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.648000] [D_R loss: 1.044073] [G loss: -0.005500]
# VALID DATA
# overall TPR : 0.630
# priv TPR : 0.615
# unpriv TPR : 0.633
# Eq. Opp : 0.017
#
# overall FPR : 0.185
# priv FPR : 0.249
# unpriv FPR : 0.080
# diff FPR : 0.169
#
# overall ACC : 0.769
# priv ACC : 0.714
# unpriv ACC : 0.883
# diff ACC : 0.169
#
#
#
# TEST DATA
# overall TPR : 0.661
# priv TPR : 0.690
# unpriv TPR : 0.655
# Eq. Opp : 0.035
#
# overall FPR : 0.190
# priv FPR : 0.254
# unpriv FPR : 0.087
# diff FPR : 0.167
#
# overall ACC : 0.773
# priv ACC : 0.718
# unpriv ACC : 0.886
# diff ACC : 0.168
#
#
#
# DIMP : 0.423
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.663249] [D_R loss: 0.816168] [G loss: 0.013736]
# VALID DATA
# overall TPR : 0.592
# priv TPR : 0.529
# unpriv TPR : 0.603
# Eq. Opp : 0.074
#
# overall FPR : 0.187
# priv FPR : 0.265
# unpriv FPR : 0.060
# diff FPR : 0.205
#
# overall ACC : 0.757
# priv ACC : 0.693
# unpriv ACC : 0.891
# diff ACC : 0.198
#
#
#
# TEST DATA
# overall TPR : 0.614
# priv TPR : 0.565
# unpriv TPR : 0.623
# Eq. Opp : 0.059
#
# overall FPR : 0.198
# priv FPR : 0.282
# unpriv FPR : 0.062
# diff FPR : 0.221
#
# overall ACC : 0.755
# priv ACC : 0.688
# unpriv ACC : 0.893
# diff ACC : 0.205
#
#
#
# DIMP : 0.316
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.676674] [D_R loss: 0.903371] [G loss: -0.003314]
# VALID DATA
# overall TPR : 0.725
# priv TPR : 0.640
# unpriv TPR : 0.740
# Eq. Opp : 0.101
#
# overall FPR : 0.228
# priv FPR : 0.306
# unpriv FPR : 0.101
# diff FPR : 0.205
#
# overall ACC : 0.760
# priv ACC : 0.708
# unpriv ACC : 0.868
# diff ACC : 0.160
#
#
#
# TEST DATA
# overall TPR : 0.748
# priv TPR : 0.679
# unpriv TPR : 0.762
# Eq. Opp : 0.083
#
# overall FPR : 0.244
# priv FPR : 0.329
# unpriv FPR : 0.108
# diff FPR : 0.221
#
# overall ACC : 0.754
# priv ACC : 0.699
# unpriv ACC : 0.866
# diff ACC : 0.167
#
#
#
# DIMP : 0.382
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.647508] [D_R loss: 0.794022] [G loss: -0.039837]
# VALID DATA
# overall TPR : 0.704
# priv TPR : 0.574
# unpriv TPR : 0.728
# Eq. Opp : 0.154
#
# overall FPR : 0.217
# priv FPR : 0.316
# unpriv FPR : 0.054
# diff FPR : 0.263
#
# overall ACC : 0.764
# priv ACC : 0.698
# unpriv ACC : 0.902
# diff ACC : 0.204
#
#
#
# TEST DATA
# overall TPR : 0.727
# priv TPR : 0.627
# unpriv TPR : 0.745
# Eq. Opp : 0.118
#
# overall FPR : 0.219
# priv FPR : 0.322
# unpriv FPR : 0.054
# diff FPR : 0.267
#
# overall ACC : 0.767
# priv ACC : 0.699
# unpriv ACC : 0.907
# diff ACC : 0.207
#
#
#
# DIMP : 0.274
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.654826] [D_R loss: 0.788025] [G loss: -0.115382]
# VALID DATA
# overall TPR : 0.635
# priv TPR : 0.595
# unpriv TPR : 0.642
# Eq. Opp : 0.047
#
# overall FPR : 0.212
# priv FPR : 0.302
# unpriv FPR : 0.065
# diff FPR : 0.237
#
# overall ACC : 0.750
# priv ACC : 0.680
# unpriv ACC : 0.895
# diff ACC : 0.214
#
#
#
# TEST DATA
# overall TPR : 0.667
# priv TPR : 0.601
# unpriv TPR : 0.679
# Eq. Opp : 0.078
#
# overall FPR : 0.210
# priv FPR : 0.298
# unpriv FPR : 0.069
# diff FPR : 0.229
#
# overall ACC : 0.759
# priv ACC : 0.695
# unpriv ACC : 0.890
# diff ACC : 0.196
#
#
#
# DIMP : 0.322
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.691138] [D_R loss: 1.348912] [G loss: 0.013880]
# VALID DATA
# overall TPR : 0.568
# priv TPR : 0.443
# unpriv TPR : 0.590
# Eq. Opp : 0.146
#
# overall FPR : 0.094
# priv FPR : 0.139
# unpriv FPR : 0.022
# diff FPR : 0.118
#
# overall ACC : 0.821
# priv ACC : 0.776
# unpriv ACC : 0.917
# diff ACC : 0.142
#
#
#
# TEST DATA
# overall TPR : 0.572
# priv TPR : 0.428
# unpriv TPR : 0.596
# Eq. Opp : 0.168
#
# overall FPR : 0.096
# priv FPR : 0.143
# unpriv FPR : 0.026
# diff FPR : 0.117
#
# overall ACC : 0.820
# priv ACC : 0.772
# unpriv ACC : 0.916
# diff ACC : 0.144
#
#
#
# DIMP : 0.237
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.679199] [D_R loss: 1.353856] [G loss: -0.013957]
# VALID DATA
# overall TPR : 0.670
# priv TPR : 0.640
# unpriv TPR : 0.675
# Eq. Opp : 0.035
#
# overall FPR : 0.157
# priv FPR : 0.216
# unpriv FPR : 0.060
# diff FPR : 0.156
#
# overall ACC : 0.800
# priv ACC : 0.750
# unpriv ACC : 0.906
# diff ACC : 0.156
#
#
#
# TEST DATA
# overall TPR : 0.670
# priv TPR : 0.642
# unpriv TPR : 0.675
# Eq. Opp : 0.033
#
# overall FPR : 0.165
# priv FPR : 0.224
# unpriv FPR : 0.076
# diff FPR : 0.147
#
# overall ACC : 0.793
# priv ACC : 0.743
# unpriv ACC : 0.894
# diff ACC : 0.150
#
#
#
# DIMP : 0.369
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.709915] [D_R loss: 0.982601] [G loss: -0.079778]
# VALID DATA
# overall TPR : 0.649
# priv TPR : 0.569
# unpriv TPR : 0.663
# Eq. Opp : 0.094
#
# overall FPR : 0.166
# priv FPR : 0.238
# unpriv FPR : 0.050
# diff FPR : 0.188
#
# overall ACC : 0.788
# priv ACC : 0.731
# unpriv ACC : 0.907
# diff ACC : 0.176
#
#
#
# TEST DATA
# overall TPR : 0.652
# priv TPR : 0.584
# unpriv TPR : 0.663
# Eq. Opp : 0.078
#
# overall FPR : 0.170
# priv FPR : 0.246
# unpriv FPR : 0.054
# diff FPR : 0.192
#
# overall ACC : 0.785
# priv ACC : 0.724
# unpriv ACC : 0.907
# diff ACC : 0.183
#
#
#
# DIMP : 0.290
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.673660] [D_R loss: 1.156143] [G loss: -0.030033]
# VALID DATA
# overall TPR : 0.723
# priv TPR : 0.577
# unpriv TPR : 0.748
# Eq. Opp : 0.171
#
# overall FPR : 0.211
# priv FPR : 0.304
# unpriv FPR : 0.059
# diff FPR : 0.244
#
# overall ACC : 0.773
# priv ACC : 0.712
# unpriv ACC : 0.900
# diff ACC : 0.187
#
#
#
# TEST DATA
# overall TPR : 0.731
# priv TPR : 0.601
# unpriv TPR : 0.752
# Eq. Opp : 0.152
#
# overall FPR : 0.227
# priv FPR : 0.328
# unpriv FPR : 0.074
# diff FPR : 0.255
#
# overall ACC : 0.763
# priv ACC : 0.698
# unpriv ACC : 0.891
# diff ACC : 0.193
#
#
#
# DIMP : 0.279
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.668852] [D_R loss: 0.918968] [G loss: -0.028549]
# VALID DATA
# overall TPR : 0.631
# priv TPR : 0.632
# unpriv TPR : 0.630
# Eq. Opp : 0.002
#
# overall FPR : 0.195
# priv FPR : 0.254
# unpriv FPR : 0.100
# diff FPR : 0.154
#
# overall ACC : 0.761
# priv ACC : 0.709
# unpriv ACC : 0.870
# diff ACC : 0.160
#
#
#
# TEST DATA
# overall TPR : 0.646
# priv TPR : 0.663
# unpriv TPR : 0.643
# Eq. Opp : 0.019
#
# overall FPR : 0.208
# priv FPR : 0.274
# unpriv FPR : 0.107
# diff FPR : 0.167
#
# overall ACC : 0.755
# priv ACC : 0.699
# unpriv ACC : 0.868
# diff ACC : 0.169
#
#
#
# DIMP : 0.423
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.681894] [D_R loss: 0.885744] [G loss: 0.039207]
# VALID DATA
# overall TPR : 0.678
# priv TPR : 0.634
# unpriv TPR : 0.686
# Eq. Opp : 0.052
#
# overall FPR : 0.195
# priv FPR : 0.270
# unpriv FPR : 0.073
# diff FPR : 0.197
#
# overall ACC : 0.773
# priv ACC : 0.716
# unpriv ACC : 0.893
# diff ACC : 0.177
#
#
#
# TEST DATA
# overall TPR : 0.680
# priv TPR : 0.642
# unpriv TPR : 0.686
# Eq. Opp : 0.044
#
# overall FPR : 0.203
# priv FPR : 0.282
# unpriv FPR : 0.084
# diff FPR : 0.198
#
# overall ACC : 0.767
# priv ACC : 0.707
# unpriv ACC : 0.886
# diff ACC : 0.179
#
#
#
# DIMP : 0.348
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.679116] [D_R loss: 0.862637] [G loss: -0.030863]
# VALID DATA
# overall TPR : 0.718
# priv TPR : 0.602
# unpriv TPR : 0.738
# Eq. Opp : 0.136
#
# overall FPR : 0.209
# priv FPR : 0.288
# unpriv FPR : 0.080
# diff FPR : 0.208
#
# overall ACC : 0.773
# priv ACC : 0.720
# unpriv ACC : 0.884
# diff ACC : 0.164
#
#
#
# TEST DATA
# overall TPR : 0.726
# priv TPR : 0.580
# unpriv TPR : 0.750
# Eq. Opp : 0.169
#
# overall FPR : 0.225
# priv FPR : 0.317
# unpriv FPR : 0.086
# diff FPR : 0.231
#
# overall ACC : 0.763
# priv ACC : 0.705
# unpriv ACC : 0.878
# diff ACC : 0.173
#
#
#
# DIMP : 0.304
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.686512] [D_R loss: 0.919835] [G loss: -0.080629]
# VALID DATA
# overall TPR : 0.699
# priv TPR : 0.634
# unpriv TPR : 0.710
# Eq. Opp : 0.077
#
# overall FPR : 0.196
# priv FPR : 0.263
# unpriv FPR : 0.086
# diff FPR : 0.177
#
# overall ACC : 0.778
# priv ACC : 0.729
# unpriv ACC : 0.882
# diff ACC : 0.153
#
#
#
# TEST DATA
# overall TPR : 0.715
# priv TPR : 0.663
# unpriv TPR : 0.723
# Eq. Opp : 0.061
#
# overall FPR : 0.209
# priv FPR : 0.284
# unpriv FPR : 0.096
# diff FPR : 0.187
#
# overall ACC : 0.772
# priv ACC : 0.719
# unpriv ACC : 0.878
# diff ACC : 0.159
#
#
#
# DIMP : 0.368
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.694343] [D_R loss: 0.844299] [G loss: 0.005716]
# VALID DATA
# overall TPR : 0.674
# priv TPR : 0.617
# unpriv TPR : 0.684
# Eq. Opp : 0.067
#
# overall FPR : 0.234
# priv FPR : 0.317
# unpriv FPR : 0.098
# diff FPR : 0.219
#
# overall ACC : 0.743
# priv ACC : 0.683
# unpriv ACC : 0.870
# diff ACC : 0.186
#
#
#
# TEST DATA
# overall TPR : 0.685
# priv TPR : 0.667
# unpriv TPR : 0.689
# Eq. Opp : 0.022
#
# overall FPR : 0.237
# priv FPR : 0.325
# unpriv FPR : 0.103
# diff FPR : 0.222
#
# overall ACC : 0.744
# priv ACC : 0.679
# unpriv ACC : 0.872
# diff ACC : 0.193
#
#
#
# DIMP : 0.368
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.673081] [D_R loss: 0.736102] [G loss: -0.031148]
# VALID DATA
# overall TPR : 0.697
# priv TPR : 0.598
# unpriv TPR : 0.713
# Eq. Opp : 0.115
#
# overall FPR : 0.213
# priv FPR : 0.298
# unpriv FPR : 0.074
# diff FPR : 0.225
#
# overall ACC : 0.765
# priv ACC : 0.705
# unpriv ACC : 0.889
# diff ACC : 0.184
#
#
#
# TEST DATA
# overall TPR : 0.708
# priv TPR : 0.593
# unpriv TPR : 0.727
# Eq. Opp : 0.135
#
# overall FPR : 0.219
# priv FPR : 0.315
# unpriv FPR : 0.075
# diff FPR : 0.240
#
# overall ACC : 0.762
# priv ACC : 0.699
# unpriv ACC : 0.890
# diff ACC : 0.191
#
#
#
# DIMP : 0.290
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.677503] [D_R loss: 1.370700] [G loss: 0.112837]
# VALID DATA
# overall TPR : 0.478
# priv TPR : 0.374
# unpriv TPR : 0.497
# Eq. Opp : 0.123
#
# overall FPR : 0.173
# priv FPR : 0.238
# unpriv FPR : 0.064
# diff FPR : 0.173
#
# overall ACC : 0.736
# priv ACC : 0.677
# unpriv ACC : 0.865
# diff ACC : 0.189
#
#
#
# TEST DATA
# overall TPR : 0.497
# priv TPR : 0.361
# unpriv TPR : 0.520
# Eq. Opp : 0.159
#
# overall FPR : 0.173
# priv FPR : 0.237
# unpriv FPR : 0.069
# diff FPR : 0.168
#
# overall ACC : 0.746
# priv ACC : 0.687
# unpriv ACC : 0.870
# diff ACC : 0.183
#
#
#
# DIMP : 0.307
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.680352] [D_R loss: 1.158634] [G loss: 0.016089]
# VALID DATA
# overall TPR : 0.552
# priv TPR : 0.450
# unpriv TPR : 0.570
# Eq. Opp : 0.120
#
# overall FPR : 0.176
# priv FPR : 0.244
# unpriv FPR : 0.061
# diff FPR : 0.183
#
# overall ACC : 0.753
# priv ACC : 0.696
# unpriv ACC : 0.878
# diff ACC : 0.181
#
#
#
# TEST DATA
# overall TPR : 0.527
# priv TPR : 0.369
# unpriv TPR : 0.553
# Eq. Opp : 0.184
#
# overall FPR : 0.164
# priv FPR : 0.237
# unpriv FPR : 0.048
# diff FPR : 0.189
#
# overall ACC : 0.760
# priv ACC : 0.698
# unpriv ACC : 0.890
# diff ACC : 0.192
#
#
#
# DIMP : 0.245
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.676826] [D_R loss: 1.117488] [G loss: -0.017095]
# VALID DATA
# overall TPR : 0.645
# priv TPR : 0.519
# unpriv TPR : 0.668
# Eq. Opp : 0.149
#
# overall FPR : 0.202
# priv FPR : 0.284
# unpriv FPR : 0.063
# diff FPR : 0.221
#
# overall ACC : 0.758
# priv ACC : 0.701
# unpriv ACC : 0.885
# diff ACC : 0.184
# TEST DATA
# overall TPR : 0.646
# priv TPR : 0.498
# unpriv TPR : 0.670
# Eq. Opp : 0.172
#
# overall FPR : 0.183
# priv FPR : 0.268
# unpriv FPR : 0.045
# diff FPR : 0.223
#
# overall ACC : 0.775
# priv ACC : 0.713
# unpriv ACC : 0.906
# diff ACC : 0.194
#
#
#
# DIMP : 0.237
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.670807] [D_R loss: 1.142240] [G loss: -0.015756]
# VALID DATA
# overall TPR : 0.704
# priv TPR : 0.569
# unpriv TPR : 0.729
# Eq. Opp : 0.160
#
# overall FPR : 0.200
# priv FPR : 0.281
# unpriv FPR : 0.061
# diff FPR : 0.220
#
# overall ACC : 0.776
# priv ACC : 0.722
# unpriv ACC : 0.892
# diff ACC : 0.170
#
#
#
# TEST DATA
# overall TPR : 0.704
# priv TPR : 0.579
# unpriv TPR : 0.724
# Eq. Opp : 0.145
#
# overall FPR : 0.192
# priv FPR : 0.279
# unpriv FPR : 0.051
# diff FPR : 0.228
#
# overall ACC : 0.783
# priv ACC : 0.722
# unpriv ACC : 0.910
# diff ACC : 0.187
#
#
#
# DIMP : 0.257
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.675710] [D_R loss: 0.956856] [G loss: 0.097758]
# VALID DATA
# overall TPR : 0.655
# priv TPR : 0.500
# unpriv TPR : 0.682
# Eq. Opp : 0.182
#
# overall FPR : 0.212
# priv FPR : 0.305
# unpriv FPR : 0.054
# diff FPR : 0.250
#
# overall ACC : 0.754
# priv ACC : 0.691
# unpriv ACC : 0.891
# diff ACC : 0.200
#
#
#
# TEST DATA
# overall TPR : 0.656
# priv TPR : 0.511
# unpriv TPR : 0.680
# Eq. Opp : 0.169
#
# overall FPR : 0.194
# priv FPR : 0.293
# unpriv FPR : 0.035
# diff FPR : 0.258
#
# overall ACC : 0.769
# priv ACC : 0.698
# unpriv ACC : 0.917
# diff ACC : 0.218
#
#
#
# DIMP : 0.207
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.668882] [D_R loss: 1.032035] [G loss: -0.013686]
# VALID DATA
# overall TPR : 0.696
# priv TPR : 0.615
# unpriv TPR : 0.711
# Eq. Opp : 0.095
#
# overall FPR : 0.226
# priv FPR : 0.308
# unpriv FPR : 0.086
# diff FPR : 0.222
#
# overall ACC : 0.754
# priv ACC : 0.698
# unpriv ACC : 0.876
# diff ACC : 0.178
#
#
#
# TEST DATA
# overall TPR : 0.720
# priv TPR : 0.704
# unpriv TPR : 0.723
# Eq. Opp : 0.019
#
# overall FPR : 0.230
# priv FPR : 0.318
# unpriv FPR : 0.088
# diff FPR : 0.229
#
# overall ACC : 0.758
# priv ACC : 0.695
# unpriv ACC : 0.890
# diff ACC : 0.194
#
#
#
# DIMP : 0.346
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.670997] [D_R loss: 0.836073] [G loss: -0.018888]
# VALID DATA
# overall TPR : 0.759
# priv TPR : 0.618
# unpriv TPR : 0.784
# Eq. Opp : 0.167
#
# overall FPR : 0.236
# priv FPR : 0.336
# unpriv FPR : 0.067
# diff FPR : 0.268
#
# overall ACC : 0.763
# priv ACC : 0.703
# unpriv ACC : 0.893
# diff ACC : 0.190
#
#
#
# TEST DATA
# overall TPR : 0.765
# priv TPR : 0.652
# unpriv TPR : 0.784
# Eq. Opp : 0.132
#
# overall FPR : 0.231
# priv FPR : 0.341
# unpriv FPR : 0.054
# diff FPR : 0.287
#
# overall ACC : 0.768
# priv ACC : 0.698
# unpriv ACC : 0.915
# diff ACC : 0.217
#
#
#
# DIMP : 0.245
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.666119] [D_R loss: 0.807122] [G loss: -0.063826]
# VALID DATA
# overall TPR : 0.647
# priv TPR : 0.536
# unpriv TPR : 0.666
# Eq. Opp : 0.130
#
# overall FPR : 0.189
# priv FPR : 0.265
# unpriv FPR : 0.061
# diff FPR : 0.203
#
# overall ACC : 0.768
# priv ACC : 0.713
# unpriv ACC : 0.888
# diff ACC : 0.175
#
#
#
# TEST DATA
# overall TPR : 0.637
# priv TPR : 0.562
# unpriv TPR : 0.650
# Eq. Opp : 0.087
#
# overall FPR : 0.185
# priv FPR : 0.268
# unpriv FPR : 0.051
# diff FPR : 0.217
#
# overall ACC : 0.771
# priv ACC : 0.706
# unpriv ACC : 0.908
# diff ACC : 0.202
#
#
#
# DIMP : 0.272
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.671460] [D_R loss: 0.644269] [G loss: 0.016123]
# VALID DATA
# overall TPR : 0.698
# priv TPR : 0.646
# unpriv TPR : 0.707
# Eq. Opp : 0.061
#
# overall FPR : 0.197
# priv FPR : 0.264
# unpriv FPR : 0.082
# diff FPR : 0.182
#
# overall ACC : 0.776
# priv ACC : 0.727
# unpriv ACC : 0.884
# diff ACC : 0.158
#
#
#
# TEST DATA
# overall TPR : 0.670
# priv TPR : 0.691
# unpriv TPR : 0.666
# Eq. Opp : 0.025
#
# overall FPR : 0.195
# priv FPR : 0.279
# unpriv FPR : 0.058
# diff FPR : 0.221
#
# overall ACC : 0.772
# priv ACC : 0.704
# unpriv ACC : 0.915
# diff ACC : 0.211
#
#
#
# DIMP : 0.314
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.678203] [D_R loss: 0.765910] [G loss: -0.022356]
# VALID DATA
# overall TPR : 0.675
# priv TPR : 0.623
# unpriv TPR : 0.684
# Eq. Opp : 0.061
#
# overall FPR : 0.191
# priv FPR : 0.250
# unpriv FPR : 0.092
# diff FPR : 0.158
#
# overall ACC : 0.774
# priv ACC : 0.729
# unpriv ACC : 0.873
# diff ACC : 0.144
#
#
#
# TEST DATA
# overall TPR : 0.651
# priv TPR : 0.682
# unpriv TPR : 0.645
# Eq. Opp : 0.037
#
# overall FPR : 0.187
# priv FPR : 0.258
# unpriv FPR : 0.074
# diff FPR : 0.184
#
# overall ACC : 0.773
# priv ACC : 0.712
# unpriv ACC : 0.900
# diff ACC : 0.188
#
#
#
# DIMP : 0.366
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.695892] [D_R loss: 1.746500] [G loss: -0.180013]
# VALID DATA
# overall TPR : 0.511
# priv TPR : 0.480
# unpriv TPR : 0.516
# Eq. Opp : 0.036
#
# overall FPR : 0.074
# priv FPR : 0.106
# unpriv FPR : 0.023
# diff FPR : 0.083
#
# overall ACC : 0.820
# priv ACC : 0.771
# unpriv ACC : 0.924
# diff ACC : 0.153
#
#
#
# TEST DATA
# overall TPR : 0.510
# priv TPR : 0.498
# unpriv TPR : 0.513
# Eq. Opp : 0.015
#
# overall FPR : 0.075
# priv FPR : 0.102
# unpriv FPR : 0.034
# diff FPR : 0.068
#
# overall ACC : 0.825
# priv ACC : 0.780
# unpriv ACC : 0.913
# diff ACC : 0.133
#
#
#
# DIMP : 0.380
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.681610] [D_R loss: 1.247590] [G loss: -0.080768]
# VALID DATA
# overall TPR : 0.616
# priv TPR : 0.531
# unpriv TPR : 0.629
# Eq. Opp : 0.098
#
# overall FPR : 0.118
# priv FPR : 0.168
# unpriv FPR : 0.038
# diff FPR : 0.130
#
# overall ACC : 0.813
# priv ACC : 0.766
# unpriv ACC : 0.916
# diff ACC : 0.150
#
#
#
# TEST DATA
# overall TPR : 0.590
# priv TPR : 0.556
# unpriv TPR : 0.596
# Eq. Opp : 0.041
#
# overall FPR : 0.114
# priv FPR : 0.160
# unpriv FPR : 0.044
# diff FPR : 0.116
#
# overall ACC : 0.815
# priv ACC : 0.765
# unpriv ACC : 0.911
# diff ACC : 0.146
#
#
#
# DIMP : 0.346
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.675438] [D_R loss: 1.041345] [G loss: -0.006778]
# VALID DATA
# overall TPR : 0.766
# priv TPR : 0.586
# unpriv TPR : 0.793
# Eq. Opp : 0.208
#
# overall FPR : 0.237
# priv FPR : 0.346
# unpriv FPR : 0.061
# diff FPR : 0.285
#
# overall ACC : 0.764
# priv ACC : 0.700
# unpriv ACC : 0.902
# diff ACC : 0.203
#
#
#
# TEST DATA
# overall TPR : 0.756
# priv TPR : 0.659
# unpriv TPR : 0.774
# Eq. Opp : 0.115
#
# overall FPR : 0.246
# priv FPR : 0.359
# unpriv FPR : 0.073
# diff FPR : 0.286
#
# overall ACC : 0.755
# priv ACC : 0.682
# unpriv ACC : 0.896
# diff ACC : 0.215
#
#
#
# DIMP : 0.287
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.666472] [D_R loss: 1.030205] [G loss: -0.042361]
# VALID DATA
# overall TPR : 0.671
# priv TPR : 0.579
# unpriv TPR : 0.685
# Eq. Opp : 0.106
#
# overall FPR : 0.206
# ...
# priv TPR : 0.663
# unpriv TPR : 0.575
# Eq. Opp : 0.089
#
# overall FPR : 0.308
# priv FPR : 0.439
# unpriv FPR : 0.100
# diff FPR : 0.340
#
# overall ACC : 0.665
# priv ACC : 0.565
# unpriv ACC : 0.877
# diff ACC : 0.312
#
#
#
# TEST DATA
# overall TPR : 0.609
# priv TPR : 0.698
# unpriv TPR : 0.593
# Eq. Opp : 0.105
#
# overall FPR : 0.314
# priv FPR : 0.443
# unpriv FPR : 0.112
# diff FPR : 0.331
#
# overall ACC : 0.667
# priv ACC : 0.568
# unpriv ACC : 0.866
# diff ACC : 0.298
#
#
#
# DIMP : 0.365
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.666516] [D_R loss: 1.203959] [G loss: -0.031094]
# VALID DATA
# overall TPR : 0.743
# priv TPR : 0.537
# unpriv TPR : 0.773
# Eq. Opp : 0.236
#
# overall FPR : 0.415
# priv FPR : 0.645
# unpriv FPR : 0.043
# diff FPR : 0.602
#
# overall ACC : 0.625
# priv ACC : 0.488
# unpriv ACC : 0.916
# diff ACC : 0.428
#
#
#
# TEST DATA
# overall TPR : 0.742
# priv TPR : 0.588
# unpriv TPR : 0.771
# Eq. Opp : 0.182
#
# overall FPR : 0.408
# priv FPR : 0.638
# unpriv FPR : 0.047
# diff FPR : 0.591
#
# overall ACC : 0.628
# priv ACC : 0.488
# unpriv ACC : 0.912
# diff ACC : 0.424
#
#
#
# DIMP : 0.159
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.660342] [D_R loss: 0.884229] [G loss: 0.039809]
# VALID DATA
# overall TPR : 0.622
# priv TPR : 0.604
# unpriv TPR : 0.625
# Eq. Opp : 0.021
#
# overall FPR : 0.361
# priv FPR : 0.533
# unpriv FPR : 0.087
# diff FPR : 0.446
#
# overall ACC : 0.634
# priv ACC : 0.518
# unpriv ACC : 0.883
# diff ACC : 0.365
#
#
#
# TEST DATA
# overall TPR : 0.633
# priv TPR : 0.682
# unpriv TPR : 0.624
# Eq. Opp : 0.058
#
# overall FPR : 0.350
# priv FPR : 0.518
# unpriv FPR : 0.085
# diff FPR : 0.433
#
# overall ACC : 0.646
# priv ACC : 0.526
# unpriv ACC : 0.889
# diff ACC : 0.363
#
#
#
# DIMP : 0.277
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.672994] [D_R loss: 1.201296] [G loss: -0.011409]
# VALID DATA
# overall TPR : 0.595
# priv TPR : 0.546
# unpriv TPR : 0.602
# Eq. Opp : 0.055
#
# overall FPR : 0.351
# priv FPR : 0.530
# unpriv FPR : 0.064
# diff FPR : 0.466
#
# overall ACC : 0.636
# priv ACC : 0.512
# unpriv ACC : 0.898
# diff ACC : 0.386
#
#
#
# TEST DATA
# overall TPR : 0.615
# priv TPR : 0.643
# unpriv TPR : 0.610
# Eq. Opp : 0.033
#
# overall FPR : 0.336
# priv FPR : 0.507
# unpriv FPR : 0.066
# diff FPR : 0.441
#
# overall ACC : 0.652
# priv ACC : 0.529
# unpriv ACC : 0.901
# diff ACC : 0.372
#
#
#
# DIMP : 0.245
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.681185] [D_R loss: 0.828880] [G loss: 0.001496]
# VALID DATA
# overall TPR : 0.641
# priv TPR : 0.532
# unpriv TPR : 0.656
# Eq. Opp : 0.124
#
# overall FPR : 0.382
# priv FPR : 0.588
# unpriv FPR : 0.052
# diff FPR : 0.537
#
# overall ACC : 0.623
# priv ACC : 0.490
# unpriv ACC : 0.909
# diff ACC : 0.419
#
#
#
# TEST DATA
# overall TPR : 0.668
# priv TPR : 0.620
# unpriv TPR : 0.677
# Eq. Opp : 0.058
#
# overall FPR : 0.394
# priv FPR : 0.608
# unpriv FPR : 0.057
# diff FPR : 0.551
#
# overall ACC : 0.621
# priv ACC : 0.480
# unpriv ACC : 0.907
# diff ACC : 0.427
#
#
#
# DIMP : 0.192
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.651027] [D_R loss: 0.889316] [G loss: 0.058213]
# VALID DATA
# overall TPR : 0.673
# priv TPR : 0.549
# unpriv TPR : 0.691
# Eq. Opp : 0.142
#
# overall FPR : 0.354
# priv FPR : 0.544
# unpriv FPR : 0.051
# diff FPR : 0.492
#
# overall ACC : 0.652
# priv ACC : 0.531
# unpriv ACC : 0.910
# diff ACC : 0.379
#
#
#
# TEST DATA
# overall TPR : 0.690
# priv TPR : 0.631
# unpriv TPR : 0.700
# Eq. Opp : 0.069
#
# overall FPR : 0.351
# priv FPR : 0.542
# unpriv FPR : 0.048
# diff FPR : 0.495
#
# overall ACC : 0.659
# priv ACC : 0.532
# unpriv ACC : 0.916
# diff ACC : 0.384
#
#
#
# DIMP : 0.193
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.675058] [D_R loss: 0.711962] [G loss: 0.044030]
# VALID DATA
# overall TPR : 0.525
# priv TPR : 0.598
# unpriv TPR : 0.514
# Eq. Opp : 0.084
#
# overall FPR : 0.324
# priv FPR : 0.473
# unpriv FPR : 0.084
# diff FPR : 0.389
#
# overall ACC : 0.638
# priv ACC : 0.523
# unpriv ACC : 0.885
# diff ACC : 0.362
#
#
#
# TEST DATA
# overall TPR : 0.538
# priv TPR : 0.675
# unpriv TPR : 0.513
# Eq. Opp : 0.161
#
# overall FPR : 0.312
# priv FPR : 0.466
# unpriv FPR : 0.070
# diff FPR : 0.396
#
# overall ACC : 0.651
# priv ACC : 0.528
# unpriv ACC : 0.901
# diff ACC : 0.373
#
#
#
# DIMP : 0.288
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.678564] [D_R loss: 0.911260] [G loss: 0.012519]
# VALID DATA
# overall TPR : 0.590
# priv TPR : 0.632
# unpriv TPR : 0.584
# Eq. Opp : 0.048
#
# overall FPR : 0.319
# priv FPR : 0.468
# unpriv FPR : 0.081
# diff FPR : 0.388
#
# overall ACC : 0.659
# priv ACC : 0.549
# unpriv ACC : 0.892
# diff ACC : 0.343
#
#
#
# TEST DATA
# overall TPR : 0.588
# priv TPR : 0.667
# unpriv TPR : 0.574
# Eq. Opp : 0.092
#
# overall FPR : 0.307
# priv FPR : 0.454
# unpriv FPR : 0.074
# diff FPR : 0.381
#
# overall ACC : 0.668
# priv ACC : 0.554
# unpriv ACC : 0.897
# diff ACC : 0.342
#
#
#
# DIMP : 0.287
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.711336] [D_R loss: 1.385367] [G loss: 0.202955]
# VALID DATA
# overall TPR : 0.295
# priv TPR : 0.140
# unpriv TPR : 0.321
# Eq. Opp : 0.181
#
# overall FPR : 0.151
# priv FPR : 0.231
# unpriv FPR : 0.022
# diff FPR : 0.209
#
# overall ACC : 0.712
# priv ACC : 0.630
# unpriv ACC : 0.886
# diff ACC : 0.256
#
#
#
# TEST DATA
# overall TPR : 0.346
# priv TPR : 0.128
# unpriv TPR : 0.381
# Eq. Opp : 0.254
#
# overall FPR : 0.166
# priv FPR : 0.250
# unpriv FPR : 0.025
# diff FPR : 0.225
#
# overall ACC : 0.716
# priv ACC : 0.638
# unpriv ACC : 0.885
# diff ACC : 0.247
#
#
#
# DIMP : 0.124
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.677577] [D_R loss: 0.888164] [G loss: 0.088022]
# VALID DATA
# overall TPR : 0.418
# priv TPR : 0.288
# unpriv TPR : 0.439
# Eq. Opp : 0.151
#
# overall FPR : 0.244
# priv FPR : 0.377
# unpriv FPR : 0.028
# diff FPR : 0.350
#
# overall ACC : 0.673
# priv ACC : 0.566
# unpriv ACC : 0.897
# diff ACC : 0.331
#
#
#
# TEST DATA
# overall TPR : 0.470
# priv TPR : 0.269
# unpriv TPR : 0.502
# Eq. Opp : 0.234
#
# overall FPR : 0.260
# priv FPR : 0.393
# unpriv FPR : 0.035
# diff FPR : 0.358
#
# overall ACC : 0.675
# priv ACC : 0.575
# unpriv ACC : 0.891
# diff ACC : 0.316
#
#
#
# DIMP : 0.141
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.677369] [D_R loss: 1.327799] [G loss: 0.163861]
# VALID DATA
# overall TPR : 0.567
# priv TPR : 0.468
# unpriv TPR : 0.584
# Eq. Opp : 0.116
#
# overall FPR : 0.338
# priv FPR : 0.512
# unpriv FPR : 0.055
# diff FPR : 0.457
#
# overall ACC : 0.638
# priv ACC : 0.518
# unpriv ACC : 0.893
# diff ACC : 0.375
#
#
#
# TEST DATA
# overall TPR : 0.629
# priv TPR : 0.476
# unpriv TPR : 0.654
# Eq. Opp : 0.179
#
# overall FPR : 0.358
# priv FPR : 0.532
# unpriv FPR : 0.065
# diff FPR : 0.466
#
# overall ACC : 0.639
# priv ACC : 0.525
# unpriv ACC : 0.886
# diff ACC : 0.362
#
#
#
# DIMP : 0.191
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.667059] [D_R loss: 1.199313] [G loss: 0.040598]
# VALID DATA
# overall TPR : 0.650
# priv TPR : 0.560
# unpriv TPR : 0.665
# Eq. Opp : 0.106
#
# overall FPR : 0.378
# priv FPR : 0.574
# unpriv FPR : 0.058
# diff FPR : 0.516
#
# overall ACC : 0.629
# priv ACC : 0.500
# unpriv ACC : 0.900
# diff ACC : 0.400
#
#
#
# TEST DATA
# overall TPR : 0.700
# priv TPR : 0.546
# unpriv TPR : 0.725
# Eq. Opp : 0.179
#
# overall FPR : 0.426
# priv FPR : 0.637
# unpriv FPR : 0.070
# diff FPR : 0.566
#
# overall ACC : 0.605
# priv ACC : 0.473
# unpriv ACC : 0.889
# diff ACC : 0.416
#
#
#
# DIMP : 0.182
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.674829] [D_R loss: 1.084478] [G loss: 0.002574]
# VALID DATA
# overall TPR : 0.641
# priv TPR : 0.647
# unpriv TPR : 0.640
# Eq. Opp : 0.007
#
# overall FPR : 0.353
# priv FPR : 0.521
# unpriv FPR : 0.080
# diff FPR : 0.442
#
# overall ACC : 0.645
# priv ACC : 0.528
# unpriv ACC : 0.890
# diff ACC : 0.362
#
#
#
# TEST DATA
# overall TPR : 0.685
# priv TPR : 0.652
# unpriv TPR : 0.690
# Eq. Opp : 0.038
#
# overall FPR : 0.378
# priv FPR : 0.549
# unpriv FPR : 0.090
# diff FPR : 0.458
#
# overall ACC : 0.637
# priv ACC : 0.524
# unpriv ACC : 0.883
# diff ACC : 0.359
#
#
#
# DIMP : 0.253
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.668025] [D_R loss: 0.800342] [G loss: 0.060885]
# VALID DATA
# overall TPR : 0.707
# priv TPR : 0.585
# unpriv TPR : 0.727
# Eq. Opp : 0.141
#
# overall FPR : 0.373
# priv FPR : 0.572
# unpriv FPR : 0.050
# diff FPR : 0.522
#
# overall ACC : 0.646
# priv ACC : 0.521
# unpriv ACC : 0.910
# diff ACC : 0.389
#
#
#
# TEST DATA
# overall TPR : 0.728
# priv TPR : 0.586
# unpriv TPR : 0.751
# Eq. Opp : 0.165
#
# overall FPR : 0.398
# priv FPR : 0.598
# unpriv FPR : 0.062
# diff FPR : 0.536
#
# overall ACC : 0.632
# priv ACC : 0.507
# unpriv ACC : 0.901
# diff ACC : 0.393
#
#
#
# DIMP : 0.182
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.659846] [D_R loss: 1.114286] [G loss: 0.061223]
# VALID DATA
# overall TPR : 0.476
# priv TPR : 0.611
# unpriv TPR : 0.454
# Eq. Opp : 0.157
#
# overall FPR : 0.286
# priv FPR : 0.413
# unpriv FPR : 0.078
# diff FPR : 0.335
#
# overall ACC : 0.655
# priv ACC : 0.545
# unpriv ACC : 0.888
# diff ACC : 0.343
#
#
#
# TEST DATA
# overall TPR : 0.448
# priv TPR : 0.573
# unpriv TPR : 0.428
# Eq. Opp : 0.145
#
# overall FPR : 0.285
# priv FPR : 0.395
# unpriv FPR : 0.098
# diff FPR : 0.298
#
# overall ACC : 0.651
# priv ACC : 0.551
# unpriv ACC : 0.867
# diff ACC : 0.316
#
#
#
# DIMP : 0.366
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.662674] [D_R loss: 0.996432] [G loss: -0.004154]
# VALID DATA
# overall TPR : 0.671
# priv TPR : 0.596
# unpriv TPR : 0.684
# Eq. Opp : 0.088
#
# overall FPR : 0.396
# priv FPR : 0.599
# unpriv FPR : 0.063
# diff FPR : 0.536
#
# overall ACC : 0.621
# priv ACC : 0.489
# unpriv ACC : 0.899
# diff ACC : 0.411
#
#
#
# TEST DATA
# overall TPR : 0.669
# priv TPR : 0.630
# unpriv TPR : 0.676
# Eq. Opp : 0.046
#
# overall FPR : 0.406
# priv FPR : 0.599
# unpriv FPR : 0.082
# diff FPR : 0.517
#
# overall ACC : 0.612
# priv ACC : 0.484
# unpriv ACC : 0.887
# diff ACC : 0.403
#
#
#
# DIMP : 0.225
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.642141] [D_R loss: 0.941004] [G loss: -0.024505]
# VALID DATA
# overall TPR : 0.523
# priv TPR : 0.627
# unpriv TPR : 0.505
# Eq. Opp : 0.121
#
# overall FPR : 0.300
# priv FPR : 0.437
# unpriv FPR : 0.077
# diff FPR : 0.360
#
# overall ACC : 0.657
# priv ACC : 0.545
# unpriv ACC : 0.891
# diff ACC : 0.345
#
#
#
# TEST DATA
# overall TPR : 0.496
# priv TPR : 0.639
# unpriv TPR : 0.473
# Eq. Opp : 0.165
#
# overall FPR : 0.303
# priv FPR : 0.426
# unpriv FPR : 0.095
# diff FPR : 0.332
#
# overall ACC : 0.649
# priv ACC : 0.543
# unpriv ACC : 0.877
# diff ACC : 0.334
#
#
#
# DIMP : 0.346
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.652632] [D_R loss: 0.864733] [G loss: 0.001759]
# VALID DATA
# overall TPR : 0.680
# priv TPR : 0.691
# unpriv TPR : 0.678
# Eq. Opp : 0.013
#
# overall FPR : 0.376
# priv FPR : 0.540
# unpriv FPR : 0.108
# diff FPR : 0.433
#
# overall ACC : 0.638
# priv ACC : 0.527
# unpriv ACC : 0.870
# diff ACC : 0.343
#
#
#
# TEST DATA
# overall TPR : 0.683
# priv TPR : 0.718
# unpriv TPR : 0.677
# Eq. Opp : 0.041
#
# overall FPR : 0.381
# priv FPR : 0.534
# unpriv FPR : 0.124
# diff FPR : 0.410
#
# overall ACC : 0.634
# priv ACC : 0.530
# unpriv ACC : 0.859
# diff ACC : 0.329
#
#
#
# DIMP : 0.324
# [Lambda: 0.300000] [Epoch 10/100] [D_F loss: 0.675655] [D_R loss: 1.573039] [G loss: -0.073953]
# VALID DATA
# overall TPR : 0.470
# priv TPR : 0.500
# unpriv TPR : 0.465
# Eq. Opp : 0.035
#
# overall FPR : 0.236
# priv FPR : 0.367
# unpriv FPR : 0.032
# diff FPR : 0.335
#
# overall ACC : 0.690
# priv ACC : 0.579
# unpriv ACC : 0.918
# diff ACC : 0.339
#
#
#
# TEST DATA
# overall TPR : 0.458
# priv TPR : 0.488
# unpriv TPR : 0.452
# Eq. Opp : 0.036
#
# overall FPR : 0.233
# priv FPR : 0.358
# unpriv FPR : 0.023
# diff FPR : 0.335
#
# overall ACC : 0.689
# priv ACC : 0.582
# unpriv ACC : 0.919
# diff ACC : 0.337
#
#
#
# DIMP : 0.203
# [Lambda: 0.300000] [Epoch 20/100] [D_F loss: 0.679012] [D_R loss: 1.150083] [G loss: 0.103465]
# VALID DATA
# overall TPR : 0.478
# priv TPR : 0.608
# unpriv TPR : 0.456
# Eq. Opp : 0.151
#
# overall FPR : 0.251
# priv FPR : 0.378
# unpriv FPR : 0.052
# diff FPR : 0.326
#
# overall ACC : 0.681
# priv ACC : 0.569
# unpriv ACC : 0.911
# diff ACC : 0.342
#
#
#
# TEST DATA
# overall TPR : 0.468
# priv TPR : 0.570
# unpriv TPR : 0.450
# Eq. Opp : 0.120
#
# overall FPR : 0.256
# priv FPR : 0.382
# unpriv FPR : 0.046
# diff FPR : 0.336
#
# overall ACC : 0.674
# priv ACC : 0.565
# unpriv ACC : 0.908
# diff ACC : 0.343
#
#
#
# DIMP : 0.269
# [Lambda: 0.300000] [Epoch 30/100] [D_F loss: 0.670880] [D_R loss: 1.231256] [G loss: -0.017436]
# VALID DATA
# overall TPR : 0.727
# priv TPR : 0.619
# unpriv TPR : 0.745
# Eq. Opp : 0.127
#
# overall FPR : 0.322
# priv FPR : 0.494
# unpriv FPR : 0.056
# diff FPR : 0.438
#
# overall ACC : 0.690
# priv ACC : 0.583
# unpriv ACC : 0.909
# diff ACC : 0.326
#
#
#
# TEST DATA
# overall TPR : 0.738
# priv TPR : 0.633
# unpriv TPR : 0.756
# Eq. Opp : 0.124
#
# overall FPR : 0.332
# priv FPR : 0.500
# unpriv FPR : 0.049
# diff FPR : 0.451
#
# overall ACC : 0.686
# priv ACC : 0.581
# unpriv ACC : 0.913
# diff ACC : 0.332
#
#
#
# DIMP : 0.204
# [Lambda: 0.300000] [Epoch 40/100] [D_F loss: 0.657914] [D_R loss: 1.260778] [G loss: -0.013021]
# VALID DATA
# overall TPR : 0.669
# priv TPR : 0.692
# unpriv TPR : 0.665
# Eq. Opp : 0.026
#
# overall FPR : 0.408
# priv FPR : 0.622
# unpriv FPR : 0.076
# diff FPR : 0.546
#
# overall ACC : 0.611
# priv ACC : 0.471
# unpriv ACC : 0.899
# diff ACC : 0.428
#
#
#
# TEST DATA
# overall TPR : 0.665
# priv TPR : 0.629
# unpriv TPR : 0.672
# Eq. Opp : 0.043
#
# overall FPR : 0.422
# priv FPR : 0.635
# unpriv FPR : 0.067
# diff FPR : 0.568
#
# overall ACC : 0.600
# priv ACC : 0.462
# unpriv ACC : 0.897
# diff ACC : 0.435
#
#
#
# DIMP : 0.207
# [Lambda: 0.300000] [Epoch 50/100] [D_F loss: 0.668543] [D_R loss: 1.093999] [G loss: 0.010818]
# VALID DATA
# overall TPR : 0.668
# priv TPR : 0.633
# unpriv TPR : 0.673
# Eq. Opp : 0.041
#
# overall FPR : 0.417
# priv FPR : 0.653
# unpriv FPR : 0.051
# diff FPR : 0.602
#
# overall ACC : 0.604
# priv ACC : 0.452
# unpriv ACC : 0.915
# diff ACC : 0.463
#
#
#
# TEST DATA
# overall TPR : 0.664
# priv TPR : 0.598
# unpriv TPR : 0.676
# Eq. Opp : 0.078
#
# overall FPR : 0.414
# priv FPR : 0.634
# unpriv FPR : 0.045
# diff FPR : 0.589
#
# overall ACC : 0.606
# priv ACC : 0.464
# unpriv ACC : 0.912
# diff ACC : 0.448
#
#
#
# DIMP : 0.172
# [Lambda: 0.300000] [Epoch 60/100] [D_F loss: 0.649733] [D_R loss: 1.061397] [G loss: 0.060717]
# VALID DATA
# overall TPR : 0.547
# priv TPR : 0.640
# unpriv TPR : 0.532
# Eq. Opp : 0.108
#
# overall FPR : 0.298
# priv FPR : 0.449
# unpriv FPR : 0.062
# diff FPR : 0.387
#
# overall ACC : 0.664
# priv ACC : 0.545
# unpriv ACC : 0.906
# diff ACC : 0.361
#
#
#
# TEST DATA
# overall TPR : 0.536
# priv TPR : 0.570
# unpriv TPR : 0.529
# Eq. Opp : 0.041
#
# overall FPR : 0.302
# priv FPR : 0.451
# unpriv FPR : 0.054
# diff FPR : 0.397
#
# overall ACC : 0.657
# priv ACC : 0.543
# unpriv ACC : 0.901
# diff ACC : 0.358
#
#
#
# DIMP : 0.243
# [Lambda: 0.300000] [Epoch 70/100] [D_F loss: 0.634791] [D_R loss: 1.017296] [G loss: -0.029315]
# VALID DATA
# overall TPR : 0.568
# priv TPR : 0.627
# unpriv TPR : 0.559
# Eq. Opp : 0.068
#
# overall FPR : 0.369
# priv FPR : 0.572
# unpriv FPR : 0.054
# diff FPR : 0.517
#
# overall ACC : 0.615
# priv ACC : 0.470
# unpriv ACC : 0.911
# diff ACC : 0.441
# TEST DATA
# overall TPR : 0.573
# priv TPR : 0.570
# unpriv TPR : 0.574
# Eq. Opp : 0.004
#
# overall FPR : 0.377
# priv FPR : 0.572
# unpriv FPR : 0.049
# diff FPR : 0.523
#
# overall ACC : 0.611
# priv ACC : 0.474
# unpriv ACC : 0.906
# diff ACC : 0.432
#
#
#
# DIMP : 0.194
# [Lambda: 0.300000] [Epoch 80/100] [D_F loss: 0.647027] [D_R loss: 1.054087] [G loss: -0.006262]
# VALID DATA
# overall TPR : 0.629
# priv TPR : 0.686
# unpriv TPR : 0.620
# Eq. Opp : 0.067
#
# overall FPR : 0.353
# priv FPR : 0.547
# unpriv FPR : 0.050
# diff FPR : 0.497
#
# overall ACC : 0.642
# priv ACC : 0.506
# unpriv ACC : 0.921
# diff ACC : 0.415
#
#
#
# TEST DATA
# overall TPR : 0.626
# priv TPR : 0.609
# unpriv TPR : 0.629
# Eq. Opp : 0.019
#
# overall FPR : 0.363
# priv FPR : 0.555
# unpriv FPR : 0.041
# diff FPR : 0.514
#
# overall ACC : 0.634
# priv ACC : 0.503
# unpriv ACC : 0.917
# diff ACC : 0.415
#
#
#
# DIMP : 0.188
# [Lambda: 0.300000] [Epoch 90/100] [D_F loss: 0.664828] [D_R loss: 0.985620] [G loss: 0.019174]
# VALID DATA
# overall TPR : 0.643
# priv TPR : 0.642
# unpriv TPR : 0.644
# Eq. Opp : 0.001
#
# overall FPR : 0.331
# priv FPR : 0.511
# unpriv FPR : 0.053
# diff FPR : 0.458
#
# overall ACC : 0.663
# priv ACC : 0.539
# unpriv ACC : 0.915
# diff ACC : 0.376
#
#
#
# TEST DATA
# overall TPR : 0.646
# priv TPR : 0.629
# unpriv TPR : 0.648
# Eq. Opp : 0.020
#
# overall FPR : 0.348
# priv FPR : 0.527
# unpriv FPR : 0.048
# diff FPR : 0.480
#
# overall ACC : 0.651
# priv ACC : 0.528
# unpriv ACC : 0.914
# diff ACC : 0.386
#
#
#
# DIMP : 0.206
# [Lambda: 0.300000] [Epoch 100/100] [D_F loss: 0.646202] [D_R loss: 0.825224] [G loss: 0.024384]
# VALID DATA
# overall TPR : 0.602
# priv TPR : 0.657
# unpriv TPR : 0.592
# Eq. Opp : 0.064
#
# overall FPR : 0.346
# priv FPR : 0.527
# unpriv FPR : 0.063
# diff FPR : 0.464
#
# overall ACC : 0.641
# priv ACC : 0.511
# unpriv ACC : 0.906
# diff ACC : 0.395
#
#
#
# TEST DATA
# overall TPR : 0.598
# priv TPR : 0.617
# unpriv TPR : 0.594
# Eq. Opp : 0.023
#
# overall FPR : 0.352
# priv FPR : 0.526
# unpriv FPR : 0.061
# diff FPR : 0.465
#
# overall ACC : 0.635
# priv ACC : 0.512
# unpriv ACC : 0.900
# diff ACC : 0.389
#
#
#
# DIMP : 0.233

# %%
lambda_r
# Out:
# 0.1

# %%
lambda_f_set
# Out:
# [0.3]

# %%
train_opt
# Out:
# Namespace(k=1, lr_f=1e-05, lr_g=0.005, lr_r=1e-05, n_epochs=100, val=6783)

# %%
results_dict
# Out:
# {0.1: {'EqOdds': [tensor(0.1152, device='cuda:0'),
#    tensor(0.2263, device='cuda:0'),
#    tensor(0.2571, device='cuda:0'),
#    tensor(0.1932, device='cuda:0'),
#    tensor(0.2559, device='cuda:0')],
#   'Acc': [tensor(0.8044, device='cuda:0'),
#    tensor(0.7897, device='cuda:0'),
#    tensor(0.8047, device='cuda:0'),
#    tensor(0.7879, device='cuda:0'),
#    tensor(0.8045, device='cuda:0')],
#   'DISP': [],
#   'EqOpp': [tensor(0.0251, device='cuda:0'),
#    tensor(0.0721, device='cuda:0'),
#    tensor(0.1209, device='cuda:0'),
#    tensor(0.0549, device='cuda:0'),
#    tensor(0.1198, device='cuda:0')],
#   'Acc_diff': [tensor(0.1301, device='cuda:0'),
#    tensor(0.1388, device='cuda:0'),
#    tensor(0.1418, device='cuda:0'),
#    tensor(0.1355, device='cuda:0'),
#    tensor(0.1319, device='cuda:0')],
#   'total_tpr': [tensor(0.6086, device='cuda:0'),
#    tensor(0.6979, device='cuda:0'),
#    tensor(0.6140, device='cuda:0'),
#    tensor(0.6653, device='cuda:0'),
#    tensor(0.6579, device='cuda:0')],
#   'total_fpr': [tensor(0.1305, device='cuda:0'),
#    tensor(0.1790, device='cuda:0'),
#    tensor(0.1336, device='cuda:0'),
#    tensor(0.1705, device='cuda:0'),
#    tensor(0.1477, device='cuda:0')],
#   'total_tpr_priv': [tensor(0.6301, device='cuda:0'),
#    tensor(0.6364, device='cuda:0'),
#    tensor(0.5117, device='cuda:0'),
#    tensor(0.6189, device='cuda:0'),
#    tensor(0.5560, device='cuda:0')],
#   'total_tpr_unpriv': [tensor(0.6050, device='cuda:0'),
#    tensor(0.7085, device='cuda:0'),
#    tensor(0.6327, device='cuda:0'),
#    tensor(0.6738, device='cuda:0'),
#    tensor(0.6758, device='cuda:0')],
#   'total_fpr_priv': [tensor(0.1653, device='cuda:0'),
#    tensor(0.2374, device='cuda:0'),
#    tensor(0.1862, device='cuda:0'),
#    tensor(0.2238, device='cuda:0'),
#    tensor(0.2003, device='cuda:0')],
#   'total_fpr_unpriv': [tensor(0.0752, device='cuda:0'),
#    tensor(0.0831, device='cuda:0'),
#    tensor(0.0500, device='cuda:0'),
#    tensor(0.0856, device='cuda:0'),
#    tensor(0.0642, device='cuda:0')]},
#  0.2: {'EqOdds': [tensor(0.3062, device='cuda:0'),
#    tensor(0.3751, device='cuda:0'),
#    tensor(0.2207, device='cuda:0'),
#    tensor(0.2078, device='cuda:0'),
#    tensor(0.3195, device='cuda:0')],
#   'Acc': [tensor(0.7588, device='cuda:0'),
#    tensor(0.7624, device='cuda:0'),
#    tensor(0.7728, device='cuda:0'),
#    tensor(0.7661, device='cuda:0'),
#    tensor(0.7472, device='cuda:0')],
#   'DISP': [],
#   'EqOpp': [tensor(0.0775, device='cuda:0'),
#    tensor(0.1347, device='cuda:0'),
#    tensor(0.0369, device='cuda:0'),
#    tensor(0.0273, device='cuda:0'),
#    tensor(0.0617, device='cuda:0')],
#   'Acc_diff': [tensor(0.1956, device='cuda:0'),
#    tensor(0.1909, device='cuda:0'),
#    tensor(0.1880, device='cuda:0'),
#    tensor(0.1627, device='cuda:0'),
#    tensor(0.2206, device='cuda:0')],
#   'total_tpr': [tensor(0.6667, device='cuda:0'),
#    tensor(0.7082, device='cuda:0'),
#    tensor(0.6506, device='cuda:0'),
#    tensor(0.6858, device='cuda:0'),
#    tensor(0.6805, device='cuda:0')],
#   'total_fpr': [tensor(0.2103, device='cuda:0'),
#    tensor(0.2193, device='cuda:0'),
#    tensor(0.1875, device='cuda:0'),
#    tensor(0.2084, device='cuda:0'),
#    tensor(0.2308, device='cuda:0')],
#   'total_tpr_priv': [tensor(0.6015, device='cuda:0'),
#    tensor(0.5926, device='cuda:0'),
#    tensor(0.6824, device='cuda:0'),
#    tensor(0.6628, device='cuda:0'),
#    tensor(0.6272, device='cuda:0')],
#   'total_tpr_unpriv': [tensor(0.6790, device='cuda:0'),
#    tensor(0.7273, device='cuda:0'),
#    tensor(0.6455, device='cuda:0'),
#    tensor(0.6902, device='cuda:0'),
#    tensor(0.6889, device='cuda:0')],
#   'total_fpr_priv': [tensor(0.2979, device='cuda:0'),
#    tensor(0.3152, device='cuda:0'),
#    tensor(0.2577, device='cuda:0'),
#    tensor(0.2801, device='cuda:0'),
#    tensor(0.3298, device='cuda:0')],
#   'total_fpr_unpriv': [tensor(0.0693, device='cuda:0'),
#    tensor(0.0747, device='cuda:0'),
#    tensor(0.0740, device='cuda:0'),
#    tensor(0.0997, device='cuda:0'),
#    tensor(0.0720, device='cuda:0')]},
#  0.30000000000000004: {'EqOdds': [tensor(0.3322, device='cuda:0'),
#    tensor(0.3144, device='cuda:0'),
#    tensor(0.4338, device='cuda:0'),
#    tensor(0.3543, device='cuda:0'),
#    tensor(0.4397, device='cuda:0')],
#   'Acc': [tensor(0.6924, device='cuda:0'),
#    tensor(0.7308, device='cuda:0'),
#    tensor(0.7180, device='cuda:0'),
#    tensor(0.7475, device='cuda:0'),
#    tensor(0.7319, device='cuda:0')],
#   'DISP': [],
#   'EqOpp': [tensor(0.0232, device='cuda:0'),
#    tensor(0.1286, device='cuda:0'),
#    tensor(0.1073, device='cuda:0'),
#    tensor(0.0939, device='cuda:0'),
#    tensor(0.0954, device='cuda:0')],
#   'Acc_diff': [tensor(0.2652, device='cuda:0'),
#    tensor(0.2399, device='cuda:0'),
#    tensor(0.2732, device='cuda:0'),
#    tensor(0.2122, device='cuda:0'),
#    tensor(0.2708, device='cuda:0')],
#   'total_tpr': [tensor(0.6273, device='cuda:0'),
#    tensor(0.4693, device='cuda:0'),
#    tensor(0.6238, device='cuda:0'),
#    tensor(0.6887, device='cuda:0'),
#    tensor(0.7139, device='cuda:0')],
#   'total_fpr': [tensor(0.2861, device='cuda:0'),
#    tensor(0.1811, device='cuda:0'),
#    tensor(0.2514, device='cuda:0'),
#    tensor(0.2327, device='cuda:0'),
#    tensor(0.2622, device='cuda:0')],
#   'total_tpr_priv': [tensor(0.6074, device='cuda:0'),
#    tensor(0.5787, device='cuda:0'),
#    tensor(0.5331, device='cuda:0'),
#    tensor(0.6087, device='cuda:0'),
#    tensor(0.6322, device='cuda:0')],
#   'total_tpr_unpriv': [tensor(0.6306, device='cuda:0'),
#    tensor(0.4502, device='cuda:0'),
#    tensor(0.6404, device='cuda:0'),
#    tensor(0.7026, device='cuda:0'),
#    tensor(0.7277, device='cuda:0')],
#   'total_fpr_priv': [tensor(0.4058, device='cuda:0'),
#    tensor(0.2531, device='cuda:0'),
#    tensor(0.3783, device='cuda:0'),
#    tensor(0.3297, device='cuda:0'),
#    tensor(0.3958, device='cuda:0')],
#   'total_fpr_unpriv': [tensor(0.0968, device='cuda:0'),
#    tensor(0.0672, device='cuda:0'),
#    tensor(0.0518, device='cuda:0'),
#    tensor(0.0693, device='cuda:0'),
#    tensor(0.0515, device='cuda:0')]},
#  0.4: {'EqOdds': [tensor(0.4814, device='cuda:0'),
#    tensor(0.4237, device='cuda:0'),
#    tensor(0.4036, device='cuda:0'),
#    tensor(0.3898, device='cuda:0'),
#    tensor(0.6780, device='cuda:0')],
#   'Acc': [tensor(0.6813, device='cuda:0'),
#    tensor(0.6882, device='cuda:0'),
#    tensor(0.6909, device='cuda:0'),
#    tensor(0.6788, device='cuda:0'),
#    tensor(0.6906, device='cuda:0')],
#   'DISP': [],
#   'EqOpp': [tensor(0.1135, device='cuda:0'),
#    tensor(0.1060, device='cuda:0'),
#    tensor(0.0950, device='cuda:0'),
#    tensor(0.0411, device='cuda:0'),
#    tensor(0.2431, device='cuda:0')],
#   'Acc_diff': [tensor(0.2644, device='cuda:0'),
#    tensor(0.3034, device='cuda:0'),
#    tensor(0.3078, device='cuda:0'),
#    tensor(0.2966, device='cuda:0'),
#    tensor(0.3057, device='cuda:0')],
#   'total_tpr': [tensor(0.7398, device='cuda:0'),
#    tensor(0.5714, device='cuda:0'),
#    tensor(0.5203, device='cuda:0'),
#    tensor(0.6446, device='cuda:0'),
#    tensor(0.7170, device='cuda:0')],
#   'total_fpr': [tensor(0.3380, device='cuda:0'),
#    tensor(0.2740, device='cuda:0'),
#    tensor(0.2555, device='cuda:0'),
#    tensor(0.3100, device='cuda:0'),
#    tensor(0.3183, device='cuda:0')],
#   'total_tpr_priv': [tensor(0.6444, device='cuda:0'),
#    tensor(0.6614, device='cuda:0'),
#    tensor(0.6008, device='cuda:0'),
#    tensor(0.6792, device='cuda:0'),
#    tensor(0.5128, device='cuda:0')],
#   'total_tpr_unpriv': [tensor(0.7579, device='cuda:0'),
#    tensor(0.5554, device='cuda:0'),
#    tensor(0.5058, device='cuda:0'),
#    tensor(0.6382, device='cuda:0'),
#    tensor(0.7559, device='cuda:0')],
#   'total_fpr_priv': [tensor(0.4799, device='cuda:0'),
#    tensor(0.3972, device='cuda:0'),
#    tensor(0.3741, device='cuda:0'),
#    tensor(0.4422, device='cuda:0'),
#    tensor(0.4820, device='cuda:0')],
#   'total_fpr_unpriv': [tensor(0.1120, device='cuda:0'),
#    tensor(0.0795, device='cuda:0'),
#    tensor(0.0655, device='cuda:0'),
#    tensor(0.0935, device='cuda:0'),
#    tensor(0.0471, device='cuda:0')]},
#  0.5: {'EqOdds': [tensor(0.6779, device='cuda:0'),
#    tensor(0.5942, device='cuda:0'),
#    tensor(0.4730, device='cuda:0'),
#    tensor(0.4505, device='cuda:0'),
#    tensor(0.4877, device='cuda:0')],
#   'Acc': [tensor(0.6169, device='cuda:0'),
#    tensor(0.6406, device='cuda:0'),
#    tensor(0.6677, device='cuda:0'),
#    tensor(0.6340, device='cuda:0'),
#    tensor(0.6350, device='cuda:0')],
#   'DISP': [],
#   'EqOpp': [tensor(0.0967, device='cuda:0'),
#    tensor(0.0892, device='cuda:0'),
#    tensor(0.0925, device='cuda:0'),
#    tensor(0.0409, device='cuda:0'),
#    tensor(0.0228, device='cuda:0')],
#   'Acc_diff': [tensor(0.4349, device='cuda:0'),
#    tensor(0.3876, device='cuda:0'),
#    tensor(0.3423, device='cuda:0'),
#    tensor(0.3290, device='cuda:0'),
#    tensor(0.3886, device='cuda:0')],
#   'total_tpr': [tensor(0.6983, device='cuda:0'),
#    tensor(0.6790, device='cuda:0'),
#    tensor(0.5885, device='cuda:0'),
#    tensor(0.6828, device='cuda:0'),
#    tensor(0.5978, device='cuda:0')],
#   'total_fpr': [tensor(0.4100, device='cuda:0'),
#    tensor(0.3720, device='cuda:0'),
#    tensor(0.3068, device='cuda:0'),
#    tensor(0.3815, device='cuda:0'),
#    tensor(0.3523, device='cuda:0')],
#   'total_tpr_priv': [tensor(0.6160, device='cuda:0'),
#    tensor(0.6032, device='cuda:0'),
#    tensor(0.6667, device='cuda:0'),
#    tensor(0.7181, device='cuda:0'),
#    tensor(0.6172, device='cuda:0')],
#   'total_tpr_unpriv': [tensor(0.7127, device='cuda:0'),
#    tensor(0.6924, device='cuda:0'),
#    tensor(0.5742, device='cuda:0'),
#    tensor(0.6771, device='cuda:0'),
#    tensor(0.5944, device='cuda:0')],
#   'total_fpr_priv': [tensor(0.6345, device='cuda:0'),
#    tensor(0.5582, device='cuda:0'),
#    tensor(0.4543, device='cuda:0'),
#    tensor(0.5340, device='cuda:0'),
#    tensor(0.5262, device='cuda:0')],
#   'total_fpr_unpriv': [tensor(0.0533, device='cuda:0'),
#    tensor(0.0531, device='cuda:0'),
#    tensor(0.0738, device='cuda:0'),
#    tensor(0.1245, device='cuda:0'),
#    tensor(0.0612, device='cuda:0')]}}

# %%
#German setup
results_dict = {}

for poi_ratio in np.linspace(0.1, 0.5, 5):
    data_train, data_vt = dataset[data_name].split([0.7], shuffle=True)
    data_valid, data_test = data_vt.split([0.5], shuffle=True)

    idx = np.where(data_train.features[:, sens_idx] == 1)[0]
    poison_idx = np.random.permutation(idx)[:int(len(idx) * poi_ratio)]

    #label poisoning
    data_train.labels[poison_idx] = 1 - data_train.labels[poison_idx]

    X_train = torch.FloatTensor(data_train.features[:, ~sens_loc])
    y_train = torch.FloatTensor(data_train.labels)
    s1_train = torch.FloatTensor(data_train.features[:, sens_idx]).view(-1,1)

    X_val = torch.FloatTensor(data_valid.features[:, ~sens_loc])
    y_val = torch.FloatTensor(data_valid.labels)
    s1_val = torch.FloatTensor(data_valid.features[:, sens_idx]).view(-1,1)

    X_test = torch.FloatTensor(data_test.features[:, ~sens_loc])
    y_test = torch.FloatTensor(data_test.labels)
    s1_test = torch.FloatTensor(data_test.features[:, sens_idx]).view(-1,1)

    XS_train = torch.cat([X_train, s1_train.reshape((s1_train.shape[0], 1))], dim=1)
    XS_val = torch.cat([X_val, s1_val.reshape((s1_val.shape[0], 1))], dim=1)
    XS_test = torch.cat([X_test, s1_test.reshape((s1_test.shape[0], 1))], dim=1)

    train_result = []
    train_tensors = Namespace(XS_train = XS_train, y_train = y_train, s1_train = s1_train)
    val_tensors = Namespace(XS_val = XS_val, y_val = y_val, s1_val = s1_val) 
    test_tensors = Namespace(XS_test = XS_test, y_test = y_test, s1_test = s1_test)

    train_opt = Namespace(val=len(y_val), n_epochs=100, k=1, lr_g=5e-4, lr_f=1e-5, lr_r=1e-5)
    seed = 1

    lambda_f_set = [0.1] # Lambda value for the fairness discriminator of FR-Train.
    lambda_r = 0.2 # Lambda value for the robustness discriminator of FR-Train.

    results_dict[poi_ratio] = {}
    
    data_train = Dataset(X_train, s1_train, y_train)
    data_valid = Dataset(X_val, s1_val, y_val)
    data_test = Dataset(X_test, s1_test, y_test)

    trainloader = torch.utils.data.DataLoader(
        data_train,
        batch_size=128,
        shuffle=True,
        )
    validloader = torch.utils.data.DataLoader(
        data_valid,
        batch_size=128,
        shuffle=True,
        drop_last = True
        )
    testloader = torch.utils.data.DataLoader(
        data_test,
        batch_size=128,
        shuffle=True,
        drop_last = True
        )


    for lambda_f in lambda_f_set:
        train_model_adult(results_dict[poi_ratio], train_tensors, val_tensors, test_tensors, train_opt, lambda_f = lambda_f, lambda_r = lambda_r, seed = seed)
# Out:
# [Lambda: 0.100000] [Epoch 10/100] [D_F loss: 35.000000] [D_R loss: 56.391727] [G loss: 13.647821]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.648
# priv ACC : 0.718
# unpriv ACC : 0.512
# diff ACC : 0.206
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.719
# priv ACC : 0.765
# unpriv ACC : 0.628
# diff ACC : 0.137
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/100] [D_F loss: 21.882446] [D_R loss: 55.871990] [G loss: 12.997374]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.641
# priv ACC : 0.701
# unpriv ACC : 0.512
# diff ACC : 0.189
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.703
# priv ACC : 0.767
# unpriv ACC : 0.571
# diff ACC : 0.196
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 30/100] [D_F loss: 19.462774] [D_R loss: 51.388802] [G loss: 1.666140]
# VALID DATA
# overall TPR : 0.023
# priv TPR : 0.053
# unpriv TPR : 0.000
# Eq. Opp : 0.053
#
# overall FPR : 0.012
# priv FPR : 0.000
# unpriv FPR : 0.042
# diff FPR : 0.042
#
# overall ACC : 0.664
# priv ACC : 0.718
# unpriv ACC : 0.558
# diff ACC : 0.160
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.719
# priv ACC : 0.793
# unpriv ACC : 0.561
# diff ACC : 0.232
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 40/100] [D_F loss: 22.810970] [D_R loss: 44.893913] [G loss: 1.725353]
# VALID DATA
# overall TPR : 0.104
# priv TPR : 0.143
# unpriv TPR : 0.074
# Eq. Opp : 0.069
#
# overall FPR : 0.075
# priv FPR : 0.071
# unpriv FPR : 0.083
# diff FPR : 0.012
#
# overall ACC : 0.617
# priv ACC : 0.651
# unpriv ACC : 0.556
# diff ACC : 0.095
#
#
#
# TEST DATA
# overall TPR : 0.118
# priv TPR : 0.062
# unpriv TPR : 0.167
# Eq. Opp : 0.104
#
# overall FPR : 0.021
# priv FPR : 0.030
# unpriv FPR : 0.000
# diff FPR : 0.030
#
# overall ACC : 0.750
# priv ACC : 0.798
# unpriv ACC : 0.659
# diff ACC : 0.139
#
#
#
# DIMP : 0.382
# [Lambda: 0.100000] [Epoch 50/100] [D_F loss: 10.785436] [D_R loss: 43.863758] [G loss: 0.530435]
# VALID DATA
# overall TPR : 0.170
# priv TPR : 0.150
# unpriv TPR : 0.185
# Eq. Opp : 0.035
#
# overall FPR : 0.111
# priv FPR : 0.129
# unpriv FPR : 0.053
# diff FPR : 0.076
#
# overall ACC : 0.625
# priv ACC : 0.663
# unpriv ACC : 0.538
# diff ACC : 0.124
#
#
#
# TEST DATA
# overall TPR : 0.171
# priv TPR : 0.167
# unpriv TPR : 0.176
# Eq. Opp : 0.010
#
# overall FPR : 0.032
# priv FPR : 0.046
# unpriv FPR : 0.000
# diff FPR : 0.046
#
# overall ACC : 0.750
# priv ACC : 0.793
# unpriv ACC : 0.674
# diff ACC : 0.119
#
#
#
# DIMP : 0.891
# [Lambda: 0.100000] [Epoch 60/100] [D_F loss: 24.318518] [D_R loss: 41.731552] [G loss: -5.173076]
# VALID DATA
# overall TPR : 0.262
# priv TPR : 0.333
# unpriv TPR : 0.208
# Eq. Opp : 0.125
#
# overall FPR : 0.151
# priv FPR : 0.180
# unpriv FPR : 0.080
# diff FPR : 0.100
#
# overall ACC : 0.656
# priv ACC : 0.647
# unpriv ACC : 0.674
# diff ACC : 0.027
#
#
#
# TEST DATA
# overall TPR : 0.243
# priv TPR : 0.211
# unpriv TPR : 0.278
# Eq. Opp : 0.067
#
# overall FPR : 0.088
# priv FPR : 0.094
# unpriv FPR : 0.074
# diff FPR : 0.020
#
# overall ACC : 0.719
# priv ACC : 0.768
# unpriv ACC : 0.630
# diff ACC : 0.138
#
#
#
# DIMP : 0.972
# [Lambda: 0.100000] [Epoch 70/100] [D_F loss: 17.613766] [D_R loss: 34.840782] [G loss: -2.480215]
# VALID DATA
# overall TPR : 0.224
# priv TPR : 0.273
# unpriv TPR : 0.185
# Eq. Opp : 0.088
#
# overall FPR : 0.152
# priv FPR : 0.172
# unpriv FPR : 0.095
# diff FPR : 0.077
#
# overall ACC : 0.609
# priv ACC : 0.624
# unpriv ACC : 0.581
# diff ACC : 0.042
#
#
#
# TEST DATA
# overall TPR : 0.355
# priv TPR : 0.308
# unpriv TPR : 0.389
# Eq. Opp : 0.081
#
# overall FPR : 0.082
# priv FPR : 0.086
# unpriv FPR : 0.074
# diff FPR : 0.012
#
# overall ACC : 0.781
# priv ACC : 0.807
# unpriv ACC : 0.725
# diff ACC : 0.082
#
#
#
# DIMP : 0.985
# [Lambda: 0.100000] [Epoch 80/100] [D_F loss: 19.582809] [D_R loss: 41.087158] [G loss: -3.078602]
# VALID DATA
# overall TPR : 0.265
# priv TPR : 0.304
# unpriv TPR : 0.231
# Eq. Opp : 0.074
#
# overall FPR : 0.177
# priv FPR : 0.193
# unpriv FPR : 0.136
# diff FPR : 0.057
#
# overall ACC : 0.609
# priv ACC : 0.627
# unpriv ACC : 0.578
# diff ACC : 0.049
#
#
#
# TEST DATA
# overall TPR : 0.351
# priv TPR : 0.294
# unpriv TPR : 0.400
# Eq. Opp : 0.106
#
# overall FPR : 0.099
# priv FPR : 0.111
# unpriv FPR : 0.071
# diff FPR : 0.040
#
# overall ACC : 0.742
# priv ACC : 0.771
# unpriv ACC : 0.689
# diff ACC : 0.082
#
#
#
# DIMP : 0.861
# [Lambda: 0.100000] [Epoch 90/100] [D_F loss: 14.975465] [D_R loss: 24.583164] [G loss: -1.019920]
# VALID DATA
# overall TPR : 0.356
# priv TPR : 0.500
# unpriv TPR : 0.276
# Eq. Opp : 0.224
#
# overall FPR : 0.193
# priv FPR : 0.210
# unpriv FPR : 0.143
# diff FPR : 0.067
#
# overall ACC : 0.648
# priv ACC : 0.626
# unpriv ACC : 0.703
# diff ACC : 0.076
#
#
#
# TEST DATA
# overall TPR : 0.421
# priv TPR : 0.389
# unpriv TPR : 0.450
# Eq. Opp : 0.061
#
# overall FPR : 0.122
# priv FPR : 0.138
# unpriv FPR : 0.080
# diff FPR : 0.058
#
# overall ACC : 0.742
# priv ACC : 0.765
# unpriv ACC : 0.698
# diff ACC : 0.067
#
#
#
# DIMP : 0.988
# [Lambda: 0.100000] [Epoch 100/100] [D_F loss: 13.259489] [D_R loss: 2.760080] [G loss: 10.343213]
# VALID DATA
# overall TPR : 0.370
# priv TPR : 0.435
# unpriv TPR : 0.304
# Eq. Opp : 0.130
#
# overall FPR : 0.195
# priv FPR : 0.193
# unpriv FPR : 0.200
# diff FPR : 0.007
#
# overall ACC : 0.648
# priv ACC : 0.663
# unpriv ACC : 0.625
# diff ACC : 0.038
#
#
#
# TEST DATA
# overall TPR : 0.375
# priv TPR : 0.353
# unpriv TPR : 0.400
# Eq. Opp : 0.047
#
# overall FPR : 0.115
# priv FPR : 0.136
# unpriv FPR : 0.067
# diff FPR : 0.070
#
# overall ACC : 0.758
# priv ACC : 0.778
# unpriv ACC : 0.723
# diff ACC : 0.054
#
#
#
# DIMP : 0.919
# [Lambda: 0.100000] [Epoch 10/100] [D_F loss: 31.920822] [D_R loss: 56.215591] [G loss: -4.334981]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.703
# priv ACC : 0.756
# unpriv ACC : 0.579
# diff ACC : 0.177
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.727
# priv ACC : 0.730
# unpriv ACC : 0.718
# diff ACC : 0.012
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/100] [D_F loss: 4.801363] [D_R loss: 35.255810] [G loss: -2.775987]
# VALID DATA
# overall TPR : 0.222
# priv TPR : 0.214
# unpriv TPR : 0.227
# Eq. Opp : 0.013
#
# overall FPR : 0.163
# priv FPR : 0.176
# unpriv FPR : 0.125
# diff FPR : 0.051
#
# overall ACC : 0.664
# priv ACC : 0.678
# unpriv ACC : 0.632
# diff ACC : 0.046
#
#
#
# TEST DATA
# overall TPR : 0.306
# priv TPR : 0.455
# unpriv TPR : 0.240
# Eq. Opp : 0.215
#
# overall FPR : 0.196
# priv FPR : 0.143
# unpriv FPR : 0.310
# diff FPR : 0.167
#
# overall ACC : 0.664
# priv ACC : 0.682
# unpriv ACC : 0.625
# diff ACC : 0.057
#
#
#
# DIMP : 0.487
# [Lambda: 0.100000] [Epoch 30/100] [D_F loss: 7.232382] [D_R loss: 18.212109] [G loss: -0.638370]
# VALID DATA
# overall TPR : 0.333
# priv TPR : 0.385
# unpriv TPR : 0.300
# Eq. Opp : 0.085
#
# overall FPR : 0.221
# priv FPR : 0.236
# unpriv FPR : 0.174
# diff FPR : 0.062
#
# overall ACC : 0.664
# priv ACC : 0.663
# unpriv ACC : 0.667
# diff ACC : 0.004
#
#
#
# TEST DATA
# overall TPR : 0.432
# priv TPR : 0.500
# unpriv TPR : 0.400
# Eq. Opp : 0.100
#
# overall FPR : 0.176
# priv FPR : 0.123
# unpriv FPR : 0.308
# diff FPR : 0.185
#
# overall ACC : 0.711
# priv ACC : 0.744
# unpriv ACC : 0.632
# diff ACC : 0.113
#
#
#
# DIMP : 0.543
# [Lambda: 0.100000] [Epoch 40/100] [D_F loss: 2.936118] [D_R loss: 5.017245] [G loss: 3.722552]
# VALID DATA
# overall TPR : 0.429
# priv TPR : 0.462
# unpriv TPR : 0.409
# Eq. Opp : 0.052
#
# overall FPR : 0.280
# priv FPR : 0.324
# unpriv FPR : 0.160
# diff FPR : 0.164
#
# overall ACC : 0.641
# priv ACC : 0.611
# unpriv ACC : 0.711
# diff ACC : 0.099
#
#
#
# TEST DATA
# overall TPR : 0.432
# priv TPR : 0.538
# unpriv TPR : 0.375
# Eq. Opp : 0.163
#
# overall FPR : 0.242
# priv FPR : 0.188
# unpriv FPR : 0.370
# diff FPR : 0.183
#
# overall ACC : 0.664
# priv ACC : 0.693
# unpriv ACC : 0.600
# diff ACC : 0.093
#
#
#
# DIMP : 0.561
# [Lambda: 0.100000] [Epoch 50/100] [D_F loss: 5.738483] [D_R loss: 4.523365] [G loss: 3.026066]
# VALID DATA
# overall TPR : 0.545
# priv TPR : 0.533
# unpriv TPR : 0.556
# Eq. Opp : 0.022
#
# overall FPR : 0.221
# priv FPR : 0.257
# unpriv FPR : 0.120
# diff FPR : 0.137
#
# overall ACC : 0.719
# priv ACC : 0.705
# unpriv ACC : 0.750
# diff ACC : 0.045
#
#
#
# TEST DATA
# overall TPR : 0.405
# priv TPR : 0.417
# unpriv TPR : 0.400
# Eq. Opp : 0.017
#
# overall FPR : 0.209
# priv FPR : 0.172
# unpriv FPR : 0.296
# diff FPR : 0.124
#
# overall ACC : 0.680
# priv ACC : 0.708
# unpriv ACC : 0.615
# diff ACC : 0.092
#
#
#
# DIMP : 0.708
# [Lambda: 0.100000] [Epoch 60/100] [D_F loss: 4.862841] [D_R loss: 4.169364] [G loss: 1.947477]
# VALID DATA
# overall TPR : 0.475
# priv TPR : 0.562
# unpriv TPR : 0.417
# Eq. Opp : 0.146
#
# overall FPR : 0.261
# priv FPR : 0.277
# unpriv FPR : 0.217
# diff FPR : 0.060
#
# overall ACC : 0.656
# priv ACC : 0.640
# unpriv ACC : 0.692
# diff ACC : 0.052
#
#
#
# TEST DATA
# overall TPR : 0.450
# priv TPR : 0.429
# unpriv TPR : 0.462
# Eq. Opp : 0.033
#
# overall FPR : 0.205
# priv FPR : 0.212
# unpriv FPR : 0.182
# diff FPR : 0.030
#
# overall ACC : 0.688
# priv ACC : 0.696
# unpriv ACC : 0.667
# diff ACC : 0.029
#
#
#
# DIMP : 0.983
# [Lambda: 0.100000] [Epoch 70/100] [D_F loss: 3.324680] [D_R loss: 3.711500] [G loss: 0.429208]
# VALID DATA
# overall TPR : 0.513
# priv TPR : 0.562
# unpriv TPR : 0.478
# Eq. Opp : 0.084
#
# overall FPR : 0.191
# priv FPR : 0.206
# unpriv FPR : 0.143
# diff FPR : 0.063
#
# overall ACC : 0.719
# priv ACC : 0.714
# unpriv ACC : 0.730
# diff ACC : 0.015
#
#
#
# TEST DATA
# overall TPR : 0.429
# priv TPR : 0.462
# unpriv TPR : 0.409
# Eq. Opp : 0.052
#
# overall FPR : 0.258
# priv FPR : 0.242
# unpriv FPR : 0.296
# diff FPR : 0.054
#
# overall ACC : 0.656
# priv ACC : 0.670
# unpriv ACC : 0.625
# diff ACC : 0.045
#
#
#
# DIMP : 0.812
# [Lambda: 0.100000] [Epoch 80/100] [D_F loss: 1.299964] [D_R loss: 3.294631] [G loss: 1.010704]
# VALID DATA
# overall TPR : 0.514
# priv TPR : 0.462
# unpriv TPR : 0.545
# Eq. Opp : 0.084
#
# overall FPR : 0.226
# priv FPR : 0.250
# unpriv FPR : 0.143
# diff FPR : 0.107
#
# overall ACC : 0.703
# priv ACC : 0.702
# unpriv ACC : 0.706
# diff ACC : 0.004
#
#
#
# TEST DATA
# overall TPR : 0.459
# priv TPR : 0.429
# unpriv TPR : 0.478
# Eq. Opp : 0.050
#
# overall FPR : 0.242
# priv FPR : 0.234
# unpriv FPR : 0.259
# diff FPR : 0.025
#
# overall ACC : 0.672
# priv ACC : 0.690
# unpriv ACC : 0.634
# diff ACC : 0.056
#
#
#
# DIMP : 0.943
# [Lambda: 0.100000] [Epoch 90/100] [D_F loss: 1.457705] [D_R loss: 2.963304] [G loss: 1.011031]
# VALID DATA
# overall TPR : 0.529
# priv TPR : 0.538
# unpriv TPR : 0.524
# Eq. Opp : 0.015
#
# overall FPR : 0.191
# priv FPR : 0.203
# unpriv FPR : 0.160
# diff FPR : 0.043
#
# overall ACC : 0.734
# priv ACC : 0.733
# unpriv ACC : 0.737
# diff ACC : 0.004
#
#
#
# TEST DATA
# overall TPR : 0.444
# priv TPR : 0.417
# unpriv TPR : 0.458
# Eq. Opp : 0.042
#
# overall FPR : 0.250
# priv FPR : 0.281
# unpriv FPR : 0.179
# diff FPR : 0.103
#
# overall ACC : 0.664
# priv ACC : 0.648
# unpriv ACC : 0.700
# diff ACC : 0.052
#
#
#
# DIMP : 0.759
# [Lambda: 0.100000] [Epoch 100/100] [D_F loss: 1.262596] [D_R loss: 2.787005] [G loss: 0.246886]
# VALID DATA
# overall TPR : 0.590
# priv TPR : 0.533
# unpriv TPR : 0.625
# Eq. Opp : 0.092
#
# overall FPR : 0.225
# priv FPR : 0.239
# unpriv FPR : 0.182
# diff FPR : 0.057
#
# overall ACC : 0.719
# priv ACC : 0.725
# unpriv ACC : 0.703
# diff ACC : 0.023
#
#
#
# TEST DATA
# overall TPR : 0.514
# priv TPR : 0.500
# unpriv TPR : 0.522
# Eq. Opp : 0.022
#
# overall FPR : 0.275
# priv FPR : 0.295
# unpriv FPR : 0.233
# diff FPR : 0.062
#
# overall ACC : 0.664
# priv ACC : 0.655
# unpriv ACC : 0.682
# diff ACC : 0.027
#
#
#
# DIMP : 0.891
# [Lambda: 0.100000] [Epoch 10/100] [D_F loss: 33.580730] [D_R loss: 56.619122] [G loss: -0.281998]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.727
# priv ACC : 0.756
# unpriv ACC : 0.667
# diff ACC : 0.089
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.703
# priv ACC : 0.708
# unpriv ACC : 0.688
# diff ACC : 0.021
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/100] [D_F loss: 3.707762] [D_R loss: 33.368511] [G loss: -0.483791]
# VALID DATA
# overall TPR : 0.514
# priv TPR : 0.600
# unpriv TPR : 0.412
# Eq. Opp : 0.188
#
# overall FPR : 0.198
# priv FPR : 0.141
# unpriv FPR : 0.333
# diff FPR : 0.193
#
# overall ACC : 0.719
# priv ACC : 0.765
# unpriv ACC : 0.638
# diff ACC : 0.127
#
#
#
# TEST DATA
# overall TPR : 0.378
# priv TPR : 0.333
# unpriv TPR : 0.393
# Eq. Opp : 0.060
#
# overall FPR : 0.220
# priv FPR : 0.200
# unpriv FPR : 0.286
# diff FPR : 0.086
#
# overall ACC : 0.664
# priv ACC : 0.684
# unpriv ACC : 0.600
# diff ACC : 0.084
#
#
#
# DIMP : 0.850
# [Lambda: 0.100000] [Epoch 30/100] [D_F loss: 3.778627] [D_R loss: 18.432302] [G loss: 3.077850]
# VALID DATA
# overall TPR : 0.424
# priv TPR : 0.600
# unpriv TPR : 0.278
# Eq. Opp : 0.322
#
# overall FPR : 0.242
# priv FPR : 0.206
# unpriv FPR : 0.333
# diff FPR : 0.127
#
# overall ACC : 0.672
# priv ACC : 0.686
# unpriv ACC : 0.643
# diff ACC : 0.043
#
#
#
# TEST DATA
# overall TPR : 0.459
# priv TPR : 0.250
# unpriv TPR : 0.560
# Eq. Opp : 0.310
#
# overall FPR : 0.264
# priv FPR : 0.246
# unpriv FPR : 0.318
# diff FPR : 0.072
#
# overall ACC : 0.656
# priv ACC : 0.702
# unpriv ACC : 0.529
# diff ACC : 0.173
#
#
#
# DIMP : 0.892
# [Lambda: 0.100000] [Epoch 40/100] [D_F loss: 3.385725] [D_R loss: 5.591931] [G loss: 4.077101]
# VALID DATA
# overall TPR : 0.457
# priv TPR : 0.500
# unpriv TPR : 0.421
# Eq. Opp : 0.079
#
# overall FPR : 0.269
# priv FPR : 0.262
# unpriv FPR : 0.286
# diff FPR : 0.024
#
# overall ACC : 0.656
# priv ACC : 0.667
# unpriv ACC : 0.636
# diff ACC : 0.030
#
#
#
# TEST DATA
# overall TPR : 0.500
# priv TPR : 0.455
# unpriv TPR : 0.519
# Eq. Opp : 0.064
#
# overall FPR : 0.300
# priv FPR : 0.275
# unpriv FPR : 0.381
# diff FPR : 0.106
#
# overall ACC : 0.641
# priv ACC : 0.667
# unpriv ACC : 0.562
# diff ACC : 0.104
#
#
#
# DIMP : 0.846
# [Lambda: 0.100000] [Epoch 50/100] [D_F loss: 4.000112] [D_R loss: 4.951245] [G loss: 4.548826]
# VALID DATA
# overall TPR : 0.486
# priv TPR : 0.529
# unpriv TPR : 0.444
# Eq. Opp : 0.085
#
# overall FPR : 0.290
# priv FPR : 0.281
# unpriv FPR : 0.310
# diff FPR : 0.029
#
# overall ACC : 0.648
# priv ACC : 0.659
# unpriv ACC : 0.630
# diff ACC : 0.028
#
#
#
# TEST DATA
# overall TPR : 0.579
# priv TPR : 0.538
# unpriv TPR : 0.600
# Eq. Opp : 0.062
#
# overall FPR : 0.378
# priv FPR : 0.364
# unpriv FPR : 0.417
# diff FPR : 0.053
#
# overall ACC : 0.609
# priv ACC : 0.626
# unpriv ACC : 0.568
# diff ACC : 0.059
#
#
#
# DIMP : 0.933
# [Lambda: 0.100000] [Epoch 60/100] [D_F loss: 3.723019] [D_R loss: 4.610278] [G loss: 2.134272]
# VALID DATA
# overall TPR : 0.457
# priv TPR : 0.471
# unpriv TPR : 0.444
# Eq. Opp : 0.026
#
# overall FPR : 0.333
# priv FPR : 0.338
# unpriv FPR : 0.320
# diff FPR : 0.018
#
# overall ACC : 0.609
# priv ACC : 0.616
# unpriv ACC : 0.595
# diff ACC : 0.021
#
#
#
# TEST DATA
# overall TPR : 0.622
# priv TPR : 0.500
# unpriv TPR : 0.680
# Eq. Opp : 0.180
#
# overall FPR : 0.363
# priv FPR : 0.358
# unpriv FPR : 0.375
# diff FPR : 0.017
#
# overall ACC : 0.633
# priv ACC : 0.652
# unpriv ACC : 0.583
# diff ACC : 0.069
#
#
#
# DIMP : 0.935
# [Lambda: 0.100000] [Epoch 70/100] [D_F loss: 1.649049] [D_R loss: 4.165547] [G loss: 0.977539]
# VALID DATA
# overall TPR : 0.395
# priv TPR : 0.389
# unpriv TPR : 0.400
# Eq. Opp : 0.011
#
# overall FPR : 0.356
# priv FPR : 0.369
# unpriv FPR : 0.320
# diff FPR : 0.049
#
# overall ACC : 0.570
# priv ACC : 0.576
# unpriv ACC : 0.558
# diff ACC : 0.018
#
#
#
# TEST DATA
# overall TPR : 0.647
# priv TPR : 0.375
# unpriv TPR : 0.731
# Eq. Opp : 0.356
#
# overall FPR : 0.362
# priv FPR : 0.361
# unpriv FPR : 0.364
# diff FPR : 0.003
#
# overall ACC : 0.641
# priv ACC : 0.663
# unpriv ACC : 0.567
# diff ACC : 0.097
#
#
#
# DIMP : 0.799
# [Lambda: 0.100000] [Epoch 80/100] [D_F loss: 3.118702] [D_R loss: 3.820593] [G loss: 1.925155]
# VALID DATA
# overall TPR : 0.417
# priv TPR : 0.500
# unpriv TPR : 0.350
# Eq. Opp : 0.150
#
# overall FPR : 0.348
# priv FPR : 0.354
# unpriv FPR : 0.333
# diff FPR : 0.021
#
# overall ACC : 0.586
# priv ACC : 0.576
# unpriv ACC : 0.605
# diff ACC : 0.028
#
#
#
# TEST DATA
# overall TPR : 0.658
# priv TPR : 0.417
# unpriv TPR : 0.769
# Eq. Opp : 0.353
#
# overall FPR : 0.422
# priv FPR : 0.433
# unpriv FPR : 0.391
# diff FPR : 0.042
#
# overall ACC : 0.602
# priv ACC : 0.624
# unpriv ACC : 0.543
# diff ACC : 0.081
#
#
#
# DIMP : 0.759
# [Lambda: 0.100000] [Epoch 90/100] [D_F loss: 1.535395] [D_R loss: 3.401670] [G loss: 0.618866]
# VALID DATA
# overall TPR : 0.500
# priv TPR : 0.474
# unpriv TPR : 0.529
# Eq. Opp : 0.056
#
# overall FPR : 0.391
# priv FPR : 0.394
# unpriv FPR : 0.385
# diff FPR : 0.009
#
# overall ACC : 0.578
# priv ACC : 0.590
# unpriv ACC : 0.556
# diff ACC : 0.035
#
#
#
# TEST DATA
# overall TPR : 0.629
# priv TPR : 0.455
# unpriv TPR : 0.708
# Eq. Opp : 0.254
#
# overall FPR : 0.376
# priv FPR : 0.338
# unpriv FPR : 0.500
# diff FPR : 0.162
#
# overall ACC : 0.625
# priv ACC : 0.674
# unpriv ACC : 0.485
# diff ACC : 0.189
#
#
#
# DIMP : 0.890
# [Lambda: 0.100000] [Epoch 100/100] [D_F loss: 1.440438] [D_R loss: 3.237169] [G loss: 0.288327]
# VALID DATA
# overall TPR : 0.486
# priv TPR : 0.529
# unpriv TPR : 0.444
# Eq. Opp : 0.085
#
# overall FPR : 0.344
# priv FPR : 0.313
# unpriv FPR : 0.423
# diff FPR : 0.110
#
# overall ACC : 0.609
# priv ACC : 0.635
# unpriv ACC : 0.558
# diff ACC : 0.077
#
#
#
# TEST DATA
# overall TPR : 0.615
# priv TPR : 0.417
# unpriv TPR : 0.704
# Eq. Opp : 0.287
#
# overall FPR : 0.371
# priv FPR : 0.357
# unpriv FPR : 0.421
# diff FPR : 0.064
#
# overall ACC : 0.625
# priv ACC : 0.660
# unpriv ACC : 0.516
# diff ACC : 0.144
#
#
#
# DIMP : 0.924
# [Lambda: 0.100000] [Epoch 10/100] [D_F loss: 30.000002] [D_R loss: 56.355026] [G loss: 22.871462]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.695
# priv ACC : 0.717
# unpriv ACC : 0.639
# diff ACC : 0.079
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.664
# priv ACC : 0.681
# unpriv ACC : 0.618
# diff ACC : 0.063
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/100] [D_F loss: 28.959572] [D_R loss: 55.172455] [G loss: 7.361261]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.664
# priv ACC : 0.703
# unpriv ACC : 0.568
# diff ACC : 0.136
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.695
# priv ACC : 0.695
# unpriv ACC : 0.697
# diff ACC : 0.002
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 30/100] [D_F loss: 15.253900] [D_R loss: 42.044258] [G loss: 9.401897]
# VALID DATA
# overall TPR : 0.171
# priv TPR : 0.214
# unpriv TPR : 0.148
# Eq. Opp : 0.066
#
# overall FPR : 0.023
# priv FPR : 0.016
# unpriv FPR : 0.042
# diff FPR : 0.026
#
# overall ACC : 0.719
# priv ACC : 0.733
# unpriv ACC : 0.684
# diff ACC : 0.049
#
#
#
# TEST DATA
# overall TPR : 0.195
# priv TPR : 0.000
# unpriv TPR : 0.286
# Eq. Opp : 0.286
#
# overall FPR : 0.138
# priv FPR : 0.066
# unpriv FPR : 0.308
# diff FPR : 0.242
#
# overall ACC : 0.648
# priv ACC : 0.730
# unpriv ACC : 0.462
# diff ACC : 0.269
#
#
#
# DIMP : 0.657
# [Lambda: 0.100000] [Epoch 40/100] [D_F loss: 18.617287] [D_R loss: 36.831104] [G loss: 2.887595]
# VALID DATA
# overall TPR : 0.400
# priv TPR : 0.583
# unpriv TPR : 0.321
# Eq. Opp : 0.262
#
# overall FPR : 0.136
# priv FPR : 0.132
# unpriv FPR : 0.150
# diff FPR : 0.018
#
# overall ACC : 0.719
# priv ACC : 0.708
# unpriv ACC : 0.750
# diff ACC : 0.042
#
#
#
# TEST DATA
# overall TPR : 0.186
# priv TPR : 0.000
# unpriv TPR : 0.267
# Eq. Opp : 0.267
#
# overall FPR : 0.271
# priv FPR : 0.213
# unpriv FPR : 0.417
# diff FPR : 0.204
#
# overall ACC : 0.547
# priv ACC : 0.615
# unpriv ACC : 0.378
# diff ACC : 0.237
#
#
#
# DIMP : 0.854
# [Lambda: 0.100000] [Epoch 50/100] [D_F loss: 8.998174] [D_R loss: 27.813745] [G loss: 2.269420]
# VALID DATA
# overall TPR : 0.436
# priv TPR : 0.429
# unpriv TPR : 0.440
# Eq. Opp : 0.011
#
# overall FPR : 0.146
# priv FPR : 0.152
# unpriv FPR : 0.130
# diff FPR : 0.021
#
# overall ACC : 0.727
# priv ACC : 0.736
# unpriv ACC : 0.703
# diff ACC : 0.034
#
#
#
# TEST DATA
# overall TPR : 0.263
# priv TPR : 0.000
# unpriv TPR : 0.400
# Eq. Opp : 0.400
#
# overall FPR : 0.244
# priv FPR : 0.169
# unpriv FPR : 0.440
# diff FPR : 0.271
#
# overall ACC : 0.609
# priv ACC : 0.711
# unpriv ACC : 0.368
# diff ACC : 0.343
#
#
#
# DIMP : 0.806
# [Lambda: 0.100000] [Epoch 60/100] [D_F loss: 11.965278] [D_R loss: 4.291820] [G loss: 4.664049]
# VALID DATA
# overall TPR : 0.425
# priv TPR : 0.400
# unpriv TPR : 0.440
# Eq. Opp : 0.040
#
# overall FPR : 0.193
# priv FPR : 0.197
# unpriv FPR : 0.182
# diff FPR : 0.015
#
# overall ACC : 0.688
# priv ACC : 0.703
# unpriv ACC : 0.649
# diff ACC : 0.055
#
#
#
# TEST DATA
# overall TPR : 0.263
# priv TPR : 0.000
# unpriv TPR : 0.385
# Eq. Opp : 0.385
#
# overall FPR : 0.233
# priv FPR : 0.169
# unpriv FPR : 0.400
# diff FPR : 0.231
#
# overall ACC : 0.617
# priv ACC : 0.703
# unpriv ACC : 0.405
# diff ACC : 0.298
#
#
#
# DIMP : 0.854
# [Lambda: 0.100000] [Epoch 70/100] [D_F loss: 3.224913] [D_R loss: 3.769493] [G loss: 6.356251]
# VALID DATA
# overall TPR : 0.375
# priv TPR : 0.385
# unpriv TPR : 0.370
# Eq. Opp : 0.014
#
# overall FPR : 0.205
# priv FPR : 0.197
# unpriv FPR : 0.227
# diff FPR : 0.030
#
# overall ACC : 0.664
# priv ACC : 0.677
# unpriv ACC : 0.629
# diff ACC : 0.049
#
#
#
# TEST DATA
# overall TPR : 0.282
# priv TPR : 0.000
# unpriv TPR : 0.440
# Eq. Opp : 0.440
#
# overall FPR : 0.213
# priv FPR : 0.138
# unpriv FPR : 0.417
# diff FPR : 0.278
#
# overall ACC : 0.633
# priv ACC : 0.744
# unpriv ACC : 0.368
# diff ACC : 0.376
#
#
#
# DIMP : 0.844
# [Lambda: 0.100000] [Epoch 80/100] [D_F loss: 4.596591] [D_R loss: 3.494492] [G loss: 7.092780]
# VALID DATA
# overall TPR : 0.390
# priv TPR : 0.286
# unpriv TPR : 0.444
# Eq. Opp : 0.159
#
# overall FPR : 0.230
# priv FPR : 0.258
# unpriv FPR : 0.143
# diff FPR : 0.115
#
# overall ACC : 0.648
# priv ACC : 0.656
# unpriv ACC : 0.629
# diff ACC : 0.027
#
#
#
# TEST DATA
# overall TPR : 0.359
# priv TPR : 0.000
# unpriv TPR : 0.519
# Eq. Opp : 0.519
#
# overall FPR : 0.258
# priv FPR : 0.200
# unpriv FPR : 0.474
# diff FPR : 0.274
#
# overall ACC : 0.625
# priv ACC : 0.722
# unpriv ACC : 0.323
# diff ACC : 0.399
#
#
#
# DIMP : 0.994
# [Lambda: 0.100000] [Epoch 90/100] [D_F loss: 10.368677] [D_R loss: 3.124804] [G loss: 5.565732]
# VALID DATA
# overall TPR : 0.390
# priv TPR : 0.400
# unpriv TPR : 0.385
# Eq. Opp : 0.015
#
# overall FPR : 0.253
# priv FPR : 0.250
# unpriv FPR : 0.261
# diff FPR : 0.011
#
# overall ACC : 0.633
# priv ACC : 0.644
# unpriv ACC : 0.605
# diff ACC : 0.039
#
#
#
# TEST DATA
# overall TPR : 0.410
# priv TPR : 0.077
# unpriv TPR : 0.577
# Eq. Opp : 0.500
#
# overall FPR : 0.281
# priv FPR : 0.239
# unpriv FPR : 0.409
# diff FPR : 0.170
#
# overall ACC : 0.625
# priv ACC : 0.710
# unpriv ACC : 0.400
# diff ACC : 0.310
#
#
#
# DIMP : 0.857
# [Lambda: 0.100000] [Epoch 100/100] [D_F loss: 9.847833] [D_R loss: 2.667303] [G loss: 2.407530]
# VALID DATA
# overall TPR : 0.409
# priv TPR : 0.333
# unpriv TPR : 0.448
# Eq. Opp : 0.115
#
# overall FPR : 0.250
# priv FPR : 0.266
# unpriv FPR : 0.200
# diff FPR : 0.066
#
# overall ACC : 0.633
# priv ACC : 0.645
# unpriv ACC : 0.600
# diff ACC : 0.045
#
#
#
# TEST DATA
# overall TPR : 0.474
# priv TPR : 0.200
# unpriv TPR : 0.571
# Eq. Opp : 0.371
#
# overall FPR : 0.289
# priv FPR : 0.239
# unpriv FPR : 0.435
# diff FPR : 0.196
#
# overall ACC : 0.641
# priv ACC : 0.705
# unpriv ACC : 0.455
# diff ACC : 0.251
#
#
#
# DIMP : 0.926
# [Lambda: 0.100000] [Epoch 10/100] [D_F loss: 28.599041] [D_R loss: 56.277344] [G loss: 14.649019]
# VALID DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.703
# priv ACC : 0.760
# unpriv ACC : 0.531
# diff ACC : 0.229
#
#
#
# TEST DATA
# overall TPR : 0.000
# priv TPR : 0.000
# unpriv TPR : 0.000
# Eq. Opp : 0.000
#
# overall FPR : 0.000
# priv FPR : 0.000
# unpriv FPR : 0.000
# diff FPR : 0.000
#
# overall ACC : 0.688
# priv ACC : 0.721
# unpriv ACC : 0.619
# diff ACC : 0.102
#
#
#
# DIMP : nan
# [Lambda: 0.100000] [Epoch 20/100] [D_F loss: 4.759403] [D_R loss: 23.607298] [G loss: 1.587321]
# VALID DATA
# overall TPR : 0.237
# priv TPR : 0.462
# unpriv TPR : 0.120
# Eq. Opp : 0.342
#
# overall FPR : 0.233
# priv FPR : 0.203
# unpriv FPR : 0.333
# diff FPR : 0.130
#
# overall ACC : 0.609
# priv ACC : 0.617
# unpriv ACC : 0.588
# diff ACC : 0.029
#
#
#
# TEST DATA
# overall TPR : 0.190
# priv TPR : 0.222
# unpriv TPR : 0.167
# Eq. Opp : 0.056
#
# overall FPR : 0.174
# priv FPR : 0.200
# unpriv FPR : 0.115
# diff FPR : 0.085
#
# overall ACC : 0.617
# priv ACC : 0.619
# unpriv ACC : 0.614
# diff ACC : 0.005
#
#
#
# DIMP : 0.835
# [Lambda: 0.100000] [Epoch 30/100] [D_F loss: 4.436927] [D_R loss: 14.896943] [G loss: 5.178470]
# VALID DATA
# overall TPR : 0.216
# priv TPR : 0.308
# unpriv TPR : 0.167
# Eq. Opp : 0.141
#
# overall FPR : 0.253
# priv FPR : 0.254
# unpriv FPR : 0.250
# diff FPR : 0.004
#
# overall ACC : 0.594
# priv ACC : 0.600
# unpriv ACC : 0.576
# diff ACC : 0.024
#
#
#
# TEST DATA
# overall TPR : 0.256
# priv TPR : 0.278
# unpriv TPR : 0.240
# Eq. Opp : 0.038
#
# overall FPR : 0.212
# priv FPR : 0.268
# unpriv FPR : 0.103
# diff FPR : 0.164
#
# overall ACC : 0.609
# priv ACC : 0.580
# unpriv ACC : 0.660
# diff ACC : 0.079
#
#
#
# DIMP : 0.657
# [Lambda: 0.100000] [Epoch 40/100] [D_F loss: 1.294336] [D_R loss: 5.009733] [G loss: 5.891504]
# VALID DATA
# overall TPR : 0.317
# priv TPR : 0.400
# unpriv TPR : 0.269
# Eq. Opp : 0.131
#
# overall FPR : 0.299
# priv FPR : 0.299
# unpriv FPR : 0.300
# diff FPR : 0.001
#
# overall ACC : 0.578
# priv ACC : 0.581
# unpriv ACC : 0.571
# diff ACC : 0.009
#
#
#
# TEST DATA
# overall TPR : 0.273
# priv TPR : 0.316
# unpriv TPR : 0.240
# Eq. Opp : 0.076
#
# overall FPR : 0.190
# priv FPR : 0.200
# unpriv FPR : 0.172
# diff FPR : 0.028
#
# overall ACC : 0.625
# priv ACC : 0.625
# unpriv ACC : 0.625
# diff ACC : 0.000
#
#
#
# DIMP : 0.927
# [Lambda: 0.100000] [Epoch 50/100] [D_F loss: 1.881267] [D_R loss: 4.632492] [G loss: 4.285539]
# VALID DATA
# overall TPR : 0.282
# priv TPR : 0.400
# unpriv TPR : 0.208
# Eq. Opp : 0.192
#
# overall FPR : 0.393
# priv FPR : 0.371
# unpriv FPR : 0.474
# diff FPR : 0.102
#
# overall ACC : 0.508
# priv ACC : 0.521
# unpriv ACC : 0.471
# diff ACC : 0.051
#
#
#
# TEST DATA
# overall TPR : 0.286
# priv TPR : 0.333
# unpriv TPR : 0.250
# Eq. Opp : 0.083
#
# overall FPR : 0.256
# priv FPR : 0.288
# unpriv FPR : 0.185
# diff FPR : 0.103
#
# overall ACC : 0.594
# priv ACC : 0.578
# unpriv ACC : 0.622
# diff ACC : 0.044
#
#
#
# DIMP : 0.882
# [Lambda: 0.100000] [Epoch 60/100] [D_F loss: 1.207181] [D_R loss: 4.210495] [G loss: 2.987177]
# VALID DATA
# overall TPR : 0.333
# priv TPR : 0.417
# unpriv TPR : 0.296
# Eq. Opp : 0.120
#
# overall FPR : 0.404
# priv FPR : 0.437
# unpriv FPR : 0.278
# diff FPR : 0.159
#
# overall ACC : 0.516
# priv ACC : 0.490
# unpriv ACC : 0.600
# diff ACC : 0.110
#
#
#
# TEST DATA
# overall TPR : 0.256
# priv TPR : 0.312
# unpriv TPR : 0.222
# Eq. Opp : 0.090
#
# overall FPR : 0.306
# priv FPR : 0.393
# unpriv FPR : 0.138
# diff FPR : 0.255
#
# overall ACC : 0.547
# priv ACC : 0.482
# unpriv ACC : 0.667
# diff ACC : 0.185
#
#
#
# DIMP : 0.593
# [Lambda: 0.100000] [Epoch 70/100] [D_F loss: 1.535565] [D_R loss: 3.740830] [G loss: 4.173036]
# VALID DATA
# overall TPR : 0.366
# priv TPR : 0.467
# unpriv TPR : 0.308
# Eq. Opp : 0.159
#
# overall FPR : 0.379
# priv FPR : 0.455
# unpriv FPR : 0.143
# diff FPR : 0.312
#
# overall ACC : 0.539
# priv ACC : 0.478
# unpriv ACC : 0.694
# diff ACC : 0.216
#
#
#
# TEST DATA
# overall TPR : 0.275
# priv TPR : 0.294
# unpriv TPR : 0.261
# Eq. Opp : 0.033
#
# overall FPR : 0.330
# priv FPR : 0.390
# unpriv FPR : 0.207
# diff FPR : 0.183
#
# overall ACC : 0.547
# priv ACC : 0.512
# unpriv ACC : 0.609
# diff ACC : 0.097
#
#
#
# DIMP : 0.676
# [Lambda: 0.100000] [Epoch 80/100] [D_F loss: 1.438013] [D_R loss: 3.470154] [G loss: 2.407016]
# VALID DATA
# overall TPR : 0.351
# priv TPR : 0.357
# unpriv TPR : 0.348
# Eq. Opp : 0.009
#
# overall FPR : 0.451
# priv FPR : 0.543
# unpriv FPR : 0.143
# diff FPR : 0.400
#
# overall ACC : 0.492
# priv ACC : 0.430
# unpriv ACC : 0.657
# diff ACC : 0.227
#
#
#
# TEST DATA
# overall TPR : 0.286
# priv TPR : 0.200
# unpriv TPR : 0.333
# Eq. Opp : 0.133
#
# overall FPR : 0.395
# priv FPR : 0.525
# unpriv FPR : 0.111
# diff FPR : 0.414
#
# overall ACC : 0.500
# priv ACC : 0.430
# unpriv ACC : 0.643
# diff ACC : 0.213
#
#
#
# DIMP : 0.307
# [Lambda: 0.100000] [Epoch 90/100] [D_F loss: 1.491895] [D_R loss: 2.937979] [G loss: 0.459151]
# VALID DATA
# overall TPR : 0.368
# priv TPR : 0.429
# unpriv TPR : 0.333
# Eq. Opp : 0.095
#
# overall FPR : 0.489
# priv FPR : 0.603
# unpriv FPR : 0.136
# diff FPR : 0.467
#
# overall ACC : 0.469
# priv ACC : 0.380
# unpriv ACC : 0.694
# diff ACC : 0.314
#
#
#
# TEST DATA
# overall TPR : 0.372
# priv TPR : 0.333
# unpriv TPR : 0.400
# Eq. Opp : 0.067
#
# overall FPR : 0.447
# priv FPR : 0.554
# unpriv FPR : 0.241
# diff FPR : 0.312
#
# overall ACC : 0.492
# priv ACC : 0.432
# unpriv ACC : 0.596
# diff ACC : 0.164
#
#
#
# DIMP : 0.546
# [Lambda: 0.100000] [Epoch 100/100] [D_F loss: 1.294747] [D_R loss: 2.647167] [G loss: 0.983592]
# VALID DATA
# overall TPR : 0.450
# priv TPR : 0.462
# unpriv TPR : 0.444
# Eq. Opp : 0.017
#
# overall FPR : 0.443
# priv FPR : 0.545
# unpriv FPR : 0.136
# diff FPR : 0.409
#
# overall ACC : 0.523
# priv ACC : 0.452
# unpriv ACC : 0.714
# diff ACC : 0.263
#
#
#
# TEST DATA
# overall TPR : 0.432
# priv TPR : 0.412
# unpriv TPR : 0.444
# Eq. Opp : 0.033
#
# overall FPR : 0.452
# priv FPR : 0.542
# unpriv FPR : 0.240
# diff FPR : 0.302
#
# overall ACC : 0.508
# priv ACC : 0.453
# unpriv ACC : 0.619
# diff ACC : 0.166
#
#
#
# DIMP : 0.605

# %%
results_dict
# Out:
# {0.1: {'EqOdds': tensor(0.1168, device='cuda:0'),
#   'Acc': tensor(0.7578, device='cuda:0'),
#   'DISP': tensor(0.9191, device='cuda:0', grad_fn=<DivBackward0>),
#   'EqOpp': tensor(0.0471, device='cuda:0'),
#   'Acc_diff': tensor(0.0544, device='cuda:0'),
#   'total_tpr': tensor(0.3750, device='cuda:0'),
#   'total_fpr': tensor(0.1146, device='cuda:0'),
#   'total_tpr_priv': tensor(0.3529, device='cuda:0'),
#   'total_tpr_unpriv': tensor(0.4000, device='cuda:0'),
#   'total_fpr_priv': tensor(0.1364, device='cuda:0'),
#   'total_fpr_unpriv': tensor(0.0667, device='cuda:0')},
#  0.2: {'EqOdds': tensor(0.0835, device='cuda:0'),
#   'Acc': tensor(0.6641, device='cuda:0'),
#   'DISP': tensor(0.8909, device='cuda:0', grad_fn=<DivBackward0>),
#   'EqOpp': tensor(0.0217, device='cuda:0'),
#   'Acc_diff': tensor(0.0271, device='cuda:0'),
#   'total_tpr': tensor(0.5135, device='cuda:0'),
#   'total_fpr': tensor(0.2747, device='cuda:0'),
#   'total_tpr_priv': tensor(0.5000, device='cuda:0'),
#   'total_tpr_unpriv': tensor(0.5217, device='cuda:0'),
#   'total_fpr_priv': tensor(0.2951, device='cuda:0'),
#   'total_fpr_unpriv': tensor(0.2333, device='cuda:0')},
#  0.30000000000000004: {'EqOdds': tensor(0.3509, device='cuda:0'),
#   'Acc': tensor(0.6250, device='cuda:0'),
#   'DISP': tensor(0.9245, device='cuda:0', grad_fn=<DivBackward0>),
#   'EqOpp': tensor(0.2870, device='cuda:0'),
#   'Acc_diff': tensor(0.1437, device='cuda:0'),
#   'total_tpr': tensor(0.6154, device='cuda:0'),
#   'total_fpr': tensor(0.3708, device='cuda:0'),
#   'total_tpr_priv': tensor(0.4167, device='cuda:0'),
#   'total_tpr_unpriv': tensor(0.7037, device='cuda:0'),
#   'total_fpr_priv': tensor(0.3571, device='cuda:0'),
#   'total_fpr_unpriv': tensor(0.4211, device='cuda:0')},
#  0.4: {'EqOdds': tensor(0.5674, device='cuda:0'),
#   'Acc': tensor(0.6406, device='cuda:0'),
#   'DISP': tensor(0.9263, device='cuda:0', grad_fn=<DivBackward0>),
#   'EqOpp': tensor(0.3714, device='cuda:0'),
#   'Acc_diff': tensor(0.2507, device='cuda:0'),
#   'total_tpr': tensor(0.4737, device='cuda:0'),
#   'total_fpr': tensor(0.2889, device='cuda:0'),
#   'total_tpr_priv': tensor(0.2000, device='cuda:0'),
#   'total_tpr_unpriv': tensor(0.5714, device='cuda:0'),
#   'total_fpr_priv': tensor(0.2388, device='cuda:0'),
#   'total_fpr_unpriv': tensor(0.4348, device='cuda:0')},
#  0.5: {'EqOdds': tensor(0.3351, device='cuda:0'),
#   'Acc': tensor(0.5078, device='cuda:0'),
#   'DISP': tensor(0.6050, device='cuda:0', grad_fn=<DivBackward0>),
#   'EqOpp': tensor(0.0327, device='cuda:0'),
#   'Acc_diff': tensor(0.1656, device='cuda:0'),
#   'total_tpr': tensor(0.4318, device='cuda:0'),
#   'total_fpr': tensor(0.4524, device='cuda:0'),
#   'total_tpr_priv': tensor(0.4118, device='cuda:0'),
#   'total_tpr_unpriv': tensor(0.4444, device='cuda:0'),
#   'total_fpr_priv': tensor(0.5424, device='cuda:0'),
#   'total_fpr_unpriv': tensor(0.2400, device='cuda:0')}}

# %%
data_name
# Out:
# 'adult'

# %%
with open(f'results/{data_name}/robust_fr_dict-3.pkl', 'wb') as f:
    pickle.dump(results_dict, f)

# %%
def train_model_adult(results_dict, train_tensors, val_tensors, test_tensors, train_opt, lambda_f, lambda_r, seed):
    """
      Trains FR-Train by using the classes in FRTrain_arch.py.
      
      Args:
        train_tensors: Training data.
        val_tensors: Clean validation data.
        test_tensors: Test data.
        train_opt: Options for the training. It currently contains size of validation set, 
                number of epochs, generator/discriminator update ratio, and learning rates.
        lambda_f: The tuning knob for L_2 (ref: FR-Train paper, Section 3.3).
        lambda_r: The tuning knob for L_3 (ref: FR-Train paper, Section 3.3).
        seed: An integer value for specifying torch random seed.
        
      Returns:
        Information about the tuning knobs (lambda_f, lambda_r),
        the test accuracy of the trained model, and disparate impact of the trained model.
    """
    # Initializes generator and discriminator
    Tensor = torch.FloatTensor

    XS_train = train_tensors.XS_train
    y_train = train_tensors.y_train
    s1_train = train_tensors.s1_train

    XS_val = val_tensors.XS_val
    y_val = val_tensors.y_val
    s1_val = val_tensors.s1_val

    XS_test = test_tensors.XS_test
    y_test = test_tensors.y_test
    s1_test = test_tensors.s1_test

    # Saves return values here
    test_result = [] 

    val = train_opt.val # Number of data points in validation set
    k = train_opt.k     # Update ratio of generator and discriminator (1:k training).
    n_epochs = train_opt.n_epochs  # Number of training epoch

    # The loss values of each component will be saved in the following lists. 
    # We can draw epoch-loss graph by the following lists, if necessary.
    g_losses =[]
    d_f_losses = []
    d_r_losses = []
    clean_test_result = []

    bce_loss = torch.nn.BCELoss()

    # Initializes generator and discriminator
    generator = Generator(input_size, latent_size).cuda()
    discriminator_F = DiscriminatorF().cuda()
    discriminator_R = DiscriminatorR(input_size, latent_size).cuda()

    # Initializes weights
    torch.manual_seed(seed)
    generator.apply(weights_init_normal)
    discriminator_F.apply(weights_init_normal)
    discriminator_R.apply(weights_init_normal)

    optimizer_G = torch.optim.Adam(generator.parameters(), lr=train_opt.lr_g)
    optimizer_D_F = torch.optim.SGD(discriminator_F.parameters(), lr=train_opt.lr_f)
    optimizer_D_R = torch.optim.SGD(discriminator_R.parameters(), lr=train_opt.lr_r)

    for epoch in range(1, n_epochs + 1):
        cnt = 0
    #     for x, s, y, x_val, s_val, y_val in trainloader:
        generator.train()
        for x, s, y in trainloader:
            cnt += 1
            x, s, y = x.cuda(), s.cuda(), y.cuda()
            x_val, s_val, y_val = iter(validloader).next()
            x_val, s_val, y_val = x_val.cuda(), s_val.cuda(), y_val.cuda()
            # -------------------
            #  Forwards Generator
            # -------------------
            if cnt % k == 0 or epoch < 10:
                optimizer_G.zero_grad()

            gen_y = generator(x)
            gen_data = torch.cat([x, gen_y.reshape((gen_y.shape[0], 1))], dim=1)


            # -------------------------------
            #  Trains Fairness Discriminator
            # -------------------------------

            optimizer_D_F.zero_grad()

            # Discriminator_F tries to distinguish the sensitive groups by using the output of the generator.
            d_f_loss = bce_loss(discriminator_F(gen_y.detach()), s)
            d_f_loss.backward()
            d_f_losses.append(d_f_loss)
            optimizer_D_F.step()

            # ---------------------------------
            #  Trains Robustness Discriminator
            # ---------------------------------
            optimizer_D_R.zero_grad()

            XSY_val_data = torch.cat([x_val, y_val.view(-1,1)], dim = 1).cuda()
            fake = Variable(Tensor(len(x), 1).fill_(0.0), requires_grad=False).cuda()
            clean = Variable(Tensor(len(x_val), 1).fill_(1.0), requires_grad=False).cuda()

            # Discriminator_R tries to distinguish whether the input is from the validation data or the generated data from generator.
            clean_loss =  bce_loss(discriminator_R(XSY_val_data), clean)
            poison_loss = bce_loss(discriminator_R(gen_data.detach()), fake)
            d_r_loss = 0.5 * (clean_loss + poison_loss)

            d_r_loss.backward()
            d_r_losses.append(d_r_loss)
            optimizer_D_R.step()

            # ---------------------
            #  Updates Generator
            # ---------------------
            if epoch < 10 :
                g_loss = bce_loss((F.tanh(gen_y)+1)/2, y)
                g_loss.backward()
                g_losses.append(g_loss)
                optimizer_G.step()
            elif cnt % k == 0:
                r_decision = discriminator_R(gen_data)
                generated = Variable(Tensor(len(gen_data), 1).fill_(0.0), requires_grad=False).cuda()
                
                r_gen = bce_loss(r_decision, generated)

                # ---------------------------------
                #  Re-weights using output of D_R
                # ---------------------------------
#                 if epoch % 10 == 0:
                
                if epoch < 10:
                    r_weight = torch.ones_like(y, requires_grad=False).float().cuda()
                else:
                    r_ones = torch.ones_like(y, requires_grad=False).float().cuda()
                    loss_ratio = (g_losses[-1]/d_r_losses[-1]).detach()
                    a = 1/(1+torch.exp(-(loss_ratio-3)))
                    b = 1-a
                    r_weight_tmp = r_decision.detach().squeeze()
                    r_weight = a * r_weight_tmp + b * r_ones

                f_cost = F.binary_cross_entropy(discriminator_F(gen_y), s, reduction="none").squeeze()
                g_cost = F.binary_cross_entropy_with_logits(gen_y, y, reduction="none").squeeze()

                f_gen = torch.mean(f_cost*r_weight)
                g_loss = (1-lambda_f-lambda_r) * torch.mean(g_cost*r_weight) - lambda_f * f_gen -  lambda_r * r_gen 

                g_loss.backward()
                optimizer_G.step()

            g_losses.append(g_loss)

        if epoch % 10 == 0:
            print(
                    "[Lambda: %1f] [Epoch %d/%d] [D_F loss: %f] [D_R loss: %f] [G loss: %f]"
                    % (lambda_f, epoch, n_epochs, d_f_losses[-1], d_r_losses[-1], g_losses[-1])
                )

            tp_priv, tn_priv, fp_priv, fn_priv, \
            tp_unpriv, tn_unpriv, fp_unpriv, fn_unpriv = 0, 0, 0, 0, 0, 0, 0, 0

            for x_val, a_val, y_val in validloader:
                x_val, a_val, y_val = x_val.cuda(), a_val.cuda(), y_val.cuda()

                priv_idx = (a_val==1).squeeze()
                positive_idx = y_val==1

                pred_test = generator(x_val).view(-1)

                pred_test[pred_test>0] = 1
                pred_test[pred_test<=0] = 0

                test_lb_priv = y_val[priv_idx].view(-1)
                test_lb_unpriv = y_val[~priv_idx].view(-1)

                pred_priv = pred_test[priv_idx]
                pred_unpriv = pred_test[~priv_idx]

                y_val = y_val.cpu().detach().numpy()
                test_lb_priv = test_lb_priv.cpu().detach().numpy()
                test_lb_unpriv = test_lb_unpriv.cpu().detach().numpy()

                try:
                    pred_priv = pred_priv.argmax(1)
                except:
                    pass
                try:
                    pred_unpriv = pred_unpriv.argmax(1)
                except:
                    pass


                tp_priv += sum(pred_priv[test_lb_priv == 1] == 1)
                fp_priv += sum(pred_priv[test_lb_priv == 0] == 1)
                tn_priv += sum(pred_priv[test_lb_priv == 0] == 0)
                fn_priv += sum(pred_priv[test_lb_priv == 1] == 0)

                tp_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 1)
                fp_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 1)
                tn_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 0)
                fn_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 0)

            tpr_overall = (tp_priv + tp_unpriv)/(tp_priv + tp_unpriv + fn_priv + fn_unpriv).float().item()
            tpr_priv = (tp_unpriv)/(tp_unpriv + fn_unpriv).float().item()
            tpr_unpriv = (tp_priv)/(tp_priv + fn_priv).float().item()

            fpr_overall = (fp_priv + fp_unpriv)/(tn_priv + tn_unpriv + fp_priv + fp_unpriv).float().item()
            fpr_unpriv = (fp_unpriv)/(tn_unpriv + fp_unpriv).float().item()
            fpr_priv = (fp_priv)/(tn_priv + fp_priv).float().item()

            acc_overall = (tp_priv + tn_priv + tp_unpriv + tn_unpriv)/(tp_priv + tn_priv + tp_unpriv + tn_unpriv + \
                                                                      fp_priv + fn_priv + fp_unpriv + fn_unpriv).float().item()
            acc_priv = (tp_priv + tn_priv)/(tp_priv + tn_priv + fp_priv + fn_priv).float().item()
            acc_unpriv = (tp_unpriv + tn_unpriv)/(tp_unpriv + tn_unpriv + fp_unpriv + fn_unpriv).float().item()


            print("VALID DATA")
            print('overall TPR : {0:.3f}'.format( tpr_overall))
            print('priv TPR : {0:.3f}'.format( tpr_priv))
            print('unpriv TPR : {0:.3f}'.format( tpr_unpriv))
            print('Eq. Opp : {0:.3f}'.format( abs(tpr_unpriv - tpr_priv)))
            print()
            print('overall FPR : {0:.3f}'.format( fpr_overall))
            print('priv FPR : {0:.3f}'.format( fpr_priv))
            print('unpriv FPR : {0:.3f}'.format( fpr_unpriv))
            print('diff FPR : {0:.3f}'.format( abs(fpr_unpriv-fpr_priv)))
            print()
            print('overall ACC : {0:.3f}'.format( acc_overall))
            print('priv ACC : {0:.3f}'.format( acc_priv))
            print('unpriv ACC : {0:.3f}'.format( acc_unpriv)) 
            print('diff ACC : {0:.3f}\n\n\n'.format( abs(acc_unpriv-acc_priv)))
            
            tp_priv, tn_priv, fp_priv, fn_priv, \
            tp_unpriv, tn_unpriv, fp_unpriv, fn_unpriv = 0, 0, 0, 0, 0, 0, 0, 0
            
            y_hat1_priv, y_hat1_unpriv, priv, unpriv = [], [],[], []

            
            generator.eval()
            for x_val, a_val, y_val in testloader:
                x_val, a_val, y_val = x_val.cuda(), a_val.cuda(), y_val.cuda()

                priv_idx = (a_val==1).squeeze()
                positive_idx = y_val==1

                pred_test = generator(x_val).view(-1)

                pred_test[pred_test>0] = 1
                pred_test[pred_test<=0] = 0

                test_lb_priv = y_val[priv_idx].view(-1)
                test_lb_unpriv = y_val[~priv_idx].view(-1)

                pred_priv = pred_test[priv_idx]
                pred_unpriv = pred_test[~priv_idx]

                y_val = y_val.cpu().detach().numpy()
                test_lb_priv = test_lb_priv.cpu().detach().numpy()
                test_lb_unpriv = test_lb_unpriv.cpu().detach().numpy()

                try:
                    pred_priv = pred_priv.argmax(1)
                except:
                    pass
                try:
                    pred_unpriv = pred_unpriv.argmax(1)
                except:
                    pass


                tp_priv += sum(pred_priv[test_lb_priv == 1] == 1)
                fp_priv += sum(pred_priv[test_lb_priv == 0] == 1)
                tn_priv += sum(pred_priv[test_lb_priv == 0] == 0)
                fn_priv += sum(pred_priv[test_lb_priv == 1] == 0)

                tp_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 1)
                fp_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 1)
                tn_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 0)
                fn_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 0)
                
                y_hat1_priv.append(pred_priv)
                y_hat1_unpriv.append(pred_unpriv)
                priv.append(priv_idx)
                unpriv.append(~priv_idx)

            tpr_overall = (tp_priv + tp_unpriv)/(tp_priv + tp_unpriv + fn_priv + fn_unpriv).float().item()
            tpr_priv = (tp_unpriv)/(tp_unpriv + fn_unpriv).float().item()
            tpr_unpriv = (tp_priv)/(tp_priv + fn_priv).float().item()

            fpr_overall = (fp_priv + fp_unpriv)/(tn_priv + tn_unpriv + fp_priv + fp_unpriv).float().item()
            fpr_unpriv = (fp_unpriv)/(tn_unpriv + fp_unpriv).float().item()
            fpr_priv = (fp_priv)/(tn_priv + fp_priv).float().item()

            acc_overall = (tp_priv + tn_priv + tp_unpriv + tn_unpriv)/(tp_priv + tn_priv + tp_unpriv + tn_unpriv + \
                                                                      fp_priv + fn_priv + fp_unpriv + fn_unpriv).float().item()
            acc_priv = (tp_priv + tn_priv)/(tp_priv + tn_priv + fp_priv + fn_priv).float().item()
            acc_unpriv = (tp_unpriv + tn_unpriv)/(tp_unpriv + tn_unpriv + fp_unpriv + fn_unpriv).float().item()
            
            y_hat1_priv = sum(torch.cat(y_hat1_priv)).float()/sum(torch.cat(priv))
            y_hat1_unpriv = sum(torch.cat(y_hat1_unpriv)).float()/sum(torch.cat(unpriv))
            
            dimp = min(y_hat1_priv/y_hat1_unpriv, y_hat1_unpriv/y_hat1_priv)

            print("TEST DATA")
            print('overall TPR : {0:.3f}'.format( tpr_overall))
            print('priv TPR : {0:.3f}'.format( tpr_priv))
            print('unpriv TPR : {0:.3f}'.format( tpr_unpriv))
            print('Eq. Opp : {0:.3f}'.format( abs(tpr_unpriv - tpr_priv)))
            print()
            print('overall FPR : {0:.3f}'.format( fpr_overall))
            print('priv FPR : {0:.3f}'.format( fpr_priv))
            print('unpriv FPR : {0:.3f}'.format( fpr_unpriv))
            print('diff FPR : {0:.3f}'.format( abs(fpr_unpriv-fpr_priv)))
            print()
            print('overall ACC : {0:.3f}'.format( acc_overall))
            print('priv ACC : {0:.3f}'.format( acc_priv))
            print('unpriv ACC : {0:.3f}'.format( acc_unpriv)) 
            print('diff ACC : {0:.3f}\n\n\n'.format( abs(acc_unpriv-acc_priv)))
            
            print('DIMP : {0:.3f}'.format( dimp)) 
            
        

    results_dict['EqOdds'].append(abs(fpr_unpriv-fpr_priv) + abs(tpr_unpriv - tpr_priv))
    results_dict['Acc'].append( acc_overall)
    results_dict['EqOpp'].append( abs(tpr_unpriv - tpr_priv))
    results_dict['Acc_diff'].append( abs(acc_unpriv-acc_priv))

    results_dict['total_tpr'].append(tpr_overall)
    results_dict['total_fpr'].append(fpr_overall)

    results_dict['total_tpr_priv'].append(tpr_priv)
    results_dict['total_tpr_unpriv'].append(tpr_unpriv)
    results_dict['total_fpr_priv'].append(fpr_priv)
    results_dict['total_fpr_unpriv'].append(fpr_unpriv)


        #     torch.save(generator.state_dict(), './FR-Train_on_poi_synthetic.pth')

#     tmp = test_model(generator, XS_test, y_test, s1_test)
#     test_result.append([lambda_f, lambda_r, tmp[0].item(), tmp[1]])
    
#     return test_result

# %%
Tensor = torch.FloatTensor

XS_train = train_tensors.XS_train
y_train = train_tensors.y_train
s1_train = train_tensors.s1_train

XS_val = val_tensors.XS_val
y_val = val_tensors.y_val
s1_val = val_tensors.s1_val

XS_test = test_tensors.XS_test
y_test = test_tensors.y_test
s1_test = test_tensors.s1_test

# Saves return values here
test_result = [] 

val = train_opt.val # Number of data points in validation set
k = train_opt.k     # Update ratio of generator and discriminator (1:k training).
n_epochs = train_opt.n_epochs  # Number of training epoch

# Changes the input validation data to an appropriate shape for the training
XSY_val = torch.cat([XS_val, y_val.reshape((y_val.shape[0], 1))], dim=1)  

# The loss values of each component will be saved in the following lists. 
# We can draw epoch-loss graph by the following lists, if necessary.
g_losses =[]
d_f_losses = []
d_r_losses = []
clean_test_result = []

bce_loss = torch.nn.BCELoss()

# Initializes generator and discriminator
generator = Generator(input_size, latent_size).cuda()
discriminator_F = DiscriminatorF().cuda()
discriminator_R = DiscriminatorR(input_size, latent_size).cuda()

# Initializes weights
torch.manual_seed(seed)
generator.apply(weights_init_normal)
discriminator_F.apply(weights_init_normal)
discriminator_R.apply(weights_init_normal)

optimizer_G = torch.optim.Adam(generator.parameters(), lr=train_opt.lr_g)
optimizer_D_F = torch.optim.SGD(discriminator_F.parameters(), lr=train_opt.lr_f)
optimizer_D_R = torch.optim.SGD(discriminator_R.parameters(), lr=train_opt.lr_r)

# %%
# valid = Variable(Tensor(train_len, 1).fill_(1.0), requires_grad=False)
# generated = Variable(Tensor(train_len, 1).fill_(0.0), requires_grad=False)
# fake = Variable(Tensor(train_len, 1).fill_(0.0), requires_grad=False)
# clean = Variable(Tensor(val_len, 1).fill_(1.0), requires_grad=False)


# r_weight = torch.ones_like(y_train, requires_grad=False).float()
# r_ones = torch.ones_like(y_train, requires_grad=False).float()

for epoch in range(1, n_epochs):
#     for x, s, y, x_val, s_val, y_val in trainloader:
    for x, s, y in trainloader:
        x, s, y = x.cuda(), s.cuda(), y.cuda()
        x_val, s_val, y_val = iter(validloader).next()
        x_val, s_val, y_val = x_val.cuda(), s_val.cuda(), y_val.cuda()
        # -------------------
        #  Forwards Generator
        # -------------------
        if epoch % k == 0 or epoch < 10:
            optimizer_G.zero_grad()

        gen_y = generator(x)
        gen_data = torch.cat([x, gen_y.reshape((gen_y.shape[0], 1))], dim=1)


        # -------------------------------
        #  Trains Fairness Discriminator
        # -------------------------------

        optimizer_D_F.zero_grad()

        # Discriminator_F tries to distinguish the sensitive groups by using the output of the generator.
        d_f_loss = bce_loss(discriminator_F(gen_y.detach()), s)
        d_f_loss.backward()
        d_f_losses.append(d_f_loss)
        optimizer_D_F.step()

        # ---------------------------------
        #  Trains Robustness Discriminator
        # ---------------------------------
        optimizer_D_R.zero_grad()

        XSY_val_data = torch.cat([x_val, y_val.view(-1,1)], dim = 1).cuda()
        fake = Variable(Tensor(len(x), 1).fill_(0.0), requires_grad=False).cuda()
        clean = Variable(Tensor(len(x_val), 1).fill_(1.0), requires_grad=False).cuda()
        
        # Discriminator_R tries to distinguish whether the input is from the validation data or the generated data from generator.
        clean_loss =  bce_loss(discriminator_R(XSY_val_data), clean)
        poison_loss = bce_loss(discriminator_R(gen_data.detach()), fake)
        d_r_loss = 0.5 * (clean_loss + poison_loss)

        d_r_loss.backward()
        d_r_losses.append(d_r_loss)
        optimizer_D_R.step()

        # ---------------------
        #  Updates Generator
        # ---------------------
        if epoch < 10 :
            g_loss = 0.1 * bce_loss((F.tanh(gen_y)+1)/2, y)
            g_loss.backward()
            g_losses.append(g_loss)
            optimizer_G.step()
        elif epoch % k == 0:
            generated = Variable(Tensor(len(x), 1).fill_(0.0), requires_grad=False).cuda()
            
            r_decision = discriminator_R(gen_data)
            r_gen = bce_loss(r_decision, generated)

            # ---------------------------------
            #  Re-weights using output of D_R
            # ---------------------------------
#             if epoch % 10 == 0:
            r_ones = torch.ones_like(y, requires_grad=False).float().cuda()

            loss_ratio = (g_losses[-1]/d_r_losses[-1]).detach()
            a = 1/(1+torch.exp(-(loss_ratio-3)))
            b = 1-a
            r_weight_tmp = r_decision.detach().squeeze()
            r_weight = a * r_weight_tmp + b * r_ones

            f_cost = F.binary_cross_entropy(discriminator_F(gen_y), s, reduction="none").squeeze()
            g_cost = F.binary_cross_entropy_with_logits(gen_y.squeeze(), (y.squeeze()+1)/2, reduction="none").squeeze()

            f_gen = torch.mean(f_cost*r_weight)
            g_loss = (1-lambda_f-lambda_r) * torch.mean(g_cost*r_weight) - lambda_f * f_gen -  lambda_r * r_gen 

            g_loss.backward()
            optimizer_G.step()


        g_losses.append(g_loss)

    if epoch % 5 == 0:
        print(
                "[Lambda: %1f] [Epoch %d/%d] [D_F loss: %f] [D_R loss: %f] [G loss: %f]"
                % (lambda_f, epoch, n_epochs, d_f_losses[-1], d_r_losses[-1], g_losses[-1])
            )

        tp_priv, tn_priv, fp_priv, fn_priv, \
        tp_unpriv, tn_unpriv, fp_unpriv, fn_unpriv = 0, 0, 0, 0, 0, 0, 0, 0

        for x_val, a_val, y_val in validloader:
            x_val, a_val, y_val = x_val.cuda(), a_val.cuda(), y_val.cuda()

            priv_idx = (a_val==1).squeeze()
            positive_idx = y_val==1

            pred_test = generator(x_val).view(-1)
            
            pred_test[pred_test>0] = 1
            pred_test[pred_test<=0] = 0

            test_lb_priv = y_val[priv_idx].view(-1)
            test_lb_unpriv = y_val[~priv_idx].view(-1)

            pred_priv = pred_test[priv_idx]
            pred_unpriv = pred_test[~priv_idx]

            y_val = y_val.cpu().detach().numpy()
            test_lb_priv = test_lb_priv.cpu().detach().numpy()
            test_lb_unpriv = test_lb_unpriv.cpu().detach().numpy()

            try:
                pred_priv = pred_priv.argmax(1)
            except:
                pass
            try:
                pred_unpriv = pred_unpriv.argmax(1)
            except:
                pass


            tp_priv += sum(pred_priv[test_lb_priv == 1] == 1)
            fp_priv += sum(pred_priv[test_lb_priv == 0] == 1)
            tn_priv += sum(pred_priv[test_lb_priv == 0] == 0)
            fn_priv += sum(pred_priv[test_lb_priv == 1] == 0)

            tp_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 1)
            fp_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 1)
            tn_unpriv += sum(pred_unpriv[test_lb_unpriv == 0] == 0)
            fn_unpriv += sum(pred_unpriv[test_lb_unpriv == 1] == 0)

        tpr_overall = (tp_priv + tp_unpriv)/(tp_priv + tp_unpriv + fn_priv + fn_unpriv).float().item()
        tpr_priv = (tp_unpriv)/(tp_unpriv + fn_unpriv).float().item()
        tpr_unpriv = (tp_priv)/(tp_priv + fn_priv).float().item()

        fpr_overall = (fp_priv + fp_unpriv)/(tn_priv + tn_unpriv + fp_priv + fp_unpriv).float().item()
        fpr_unpriv = (fp_unpriv)/(tn_unpriv + fp_unpriv).float().item()
        fpr_priv = (fp_priv)/(tn_priv + fp_priv).float().item()

        acc_overall = (tp_priv + tn_priv + tp_unpriv + tn_unpriv)/(tp_priv + tn_priv + tp_unpriv + tn_unpriv + \
                                                                  fp_priv + fn_priv + fp_unpriv + fn_unpriv).float().item()
        acc_priv = (tp_priv + tn_priv)/(tp_priv + tn_priv + fp_priv + fn_priv).float().item()
        acc_unpriv = (tp_unpriv + tn_unpriv)/(tp_unpriv + tn_unpriv + fp_unpriv + fn_unpriv).float().item()


        print()
        print('overall TPR : {0:.3f}'.format( tpr_overall))
        print('priv TPR : {0:.3f}'.format( tpr_priv))
        print('unpriv TPR : {0:.3f}'.format( tpr_unpriv))
        print('Eq. Opp : {0:.3f}'.format( abs(tpr_unpriv - tpr_priv)))
        print()
        print('overall FPR : {0:.3f}'.format( fpr_overall))
        print('priv FPR : {0:.3f}'.format( fpr_priv))
        print('unpriv FPR : {0:.3f}'.format( fpr_unpriv))
        print('diff FPR : {0:.3f}'.format( abs(fpr_unpriv-fpr_priv)))
        print()
        print('overall ACC : {0:.3f}'.format( acc_overall))
        print('priv ACC : {0:.3f}'.format( acc_priv))
        print('unpriv ACC : {0:.3f}'.format( acc_unpriv)) 
        print('diff ACC : {0:.3f}\n\n\n'.format( abs(acc_unpriv-acc_priv)))

    #     torch.save(generator.state_dict(), './FR-Train_on_poi_synthetic.pth')

    
tmp = test_model(generator, XS_test, y_test, s1_test)
test_result.append([lambda_f, lambda_r, tmp[0].item(), tmp[1]])
# Out:
# [Lambda: 0.150000] [Epoch 5/50] [D_F loss: 0.522253] [D_R loss: 50.000000] [G loss: 3.333333]
#
# overall TPR : 0.004
# priv TPR : 0.000
# unpriv TPR : 0.004
# Eq. Opp : 0.004
#
# overall FPR : 0.004
# priv FPR : 0.006
# unpriv FPR : 0.002
# diff FPR : 0.004
#
# overall ACC : 0.748
# priv ACC : 0.684
# unpriv ACC : 0.882
# diff ACC : 0.198
#
#
#
# [Lambda: 0.150000] [Epoch 10/50] [D_F loss: 0.877271] [D_R loss: 48.840309] [G loss: -30.585560]
#
# overall TPR : 0.005
# priv TPR : 0.004
# unpriv TPR : 0.006
# Eq. Opp : 0.002
#
# overall FPR : 0.009
# priv FPR : 0.010
# unpriv FPR : 0.007
# diff FPR : 0.003
#
# overall ACC : 0.748
# priv ACC : 0.684
# unpriv ACC : 0.880
# diff ACC : 0.196
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-018774572af1> in <module>()
#      14         x, s, y = x.cuda(), s.cuda(), y.cuda()
#      15         x_val, s_val, y_val = iter(validloader).next()
# ---> 16         x_val, s_val, y_val = x_val.cuda(), s_val.cuda(), y_val.cuda()
#      17         # -------------------
#      18         #  Forwards Generator
#
# KeyboardInterrupt:

# %%
class Generator(nn.Module):
    """FR-Train generator (classifier).
    
    This class is for defining the structure of FR-Train generator (classifier). 
    (ref: FR-Train paper, Section 3)

    Attributes:
        model: A model consisting of torch components.
    """
    
    def __init__(self, input_size, latent_size):
        """Initializes Generator with torch components."""
        
        super(Generator, self).__init__()

    
        def block(in_feat, out_feat, normalize=True):
            """Defines a block with torch components.
            
                Args:
                    in_feat: An integer value for the size of the input feature.
                    out_feat: An integer value for the size of the output feature.
                    normalize: A boolean indicating whether normalization is needed.
                    
                Returns:
                    The stacked layer.
            """
            
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(input_size, latent_size, normalize=True),
            *block(latent_size, latent_size, normalize=True),
            *block(latent_size, latent_size, normalize=True),
#             nn.Linear(32, 1),
#             nn.Tanh()
            nn.Linear(latent_size,1),
        )

    def forward(self, input_data):
        """Defines a forward operation of the model.
        
        Args: 
            input_data: The input data.
            
        Returns:
            The predicted label (y_hat) for the given input data.
        """
        
        output = self.model(input_data)
        return output


class DiscriminatorF(nn.Module):
    """FR-Train fairness discriminator.
    
    This class is for defining structure of FR-Train fairness discriminator. 
    (ref: FR-Train paper, Section 3)

    Attributes:
        model: A model consisting of torch components.
    """
    
    def __init__(self):
        """Initializes DiscriminatorF with torch components."""
        
        super(DiscriminatorF, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(1,1),
            nn.Sigmoid(),
        )

    def forward(self, input_data):
        """Defines a forward operation of the model.
        
        Args: 
            input_data: The input data.
            
        Returns:
            The predicted sensitive attribute for the given input data.
        """
        
        predicted_z = self.model(input_data)
        return predicted_z
    

class DiscriminatorR(nn.Module):
    """FR-Train robustness discriminator.
    
    This class is for defining the structure of FR-Train robustness discriminator. 
    (ref: FR-Train paper, Section 3)

    Attributes:
        model: A model consisting of torch components.
    """
    
    def __init__(self, input_size, latent_size):
        """Initializes DiscriminatorR with torch components."""
        
        super(DiscriminatorR, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(input_size + 1, latent_size),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(latent_size, latent_size),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(latent_size, 1),
            nn.Sigmoid(),
        )

    def forward(self, input_data):
        """Defines a forward operation of the model.
        
        Args: 
            input_data: The input data.
        
        Returns:
            The predicted indicator (whether the input data is clean or poisoned) 
            for the given input data.
        """
        
        validity = self.model(input_data)
        return validity
